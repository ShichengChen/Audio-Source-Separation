# %%
#import scipy
#rate,data = scipy.io.wavfile.read('./vocalSeparation/origin_mix.wav')
#scipy.io.wavfile.write('./vocalSeparation/morigin_mix.wav',rate,data)

# %%
#import soundfile as sf
#data, samplerate = sf.read('./vocalSeparation/pred_mix.wav', dtype='float32')
#data = librosa.resample(data.T, samplerate, 16000)

# %%
"""Training script for the WaveNet network on the VCTK corpus.

This script trains a network with the WaveNet using data from the VCTK corpus,
which can be freely downloaded at the following site (~10 GB):
http://homepages.inf.ed.ac.uk/jyamagis/page3/page58/page58.html
"""

from __future__ import print_function

import argparse
from datetime import datetime
import json
import os
import sys
import time
import numpy as np
import tensorflow as tf
from tensorflow.python.client import timeline
import soundfile as sf

from wavenetVS import WaveNetModel, AudioReader, optimizer_factory


'''import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"'''
# Out:
# 'import os\nos.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"\nos.environ["CUDA_VISIBLE_DEVICES"] = "0"'

# %%
BATCH_SIZE = 1
DATA_DIRECTORY = './vsCorpus'
LOGDIR_ROOT = './logdirVS'
CHECKPOINT_EVERY = 50
NUM_STEPS = int(1e5)
LEARNING_RATE = 1e-3
L2_REGULARIZATION_STRENGTH = 1e-5
WAVENET_PARAMS = './wavenet_params.json'
STARTED_DATESTRING = "{0:%Y-%m-%dT%H-%M-%S}".format(datetime.now())
SAMPLE_SIZE = 100000
#SILENCE_THRESHOLD = 0.3
SILENCE_THRESHOLD = 0
EPSILON = 0.001
MOMENTUM = 0.9
MAX_TO_KEEP = 5
METADATA = False

# %%
def get_arguments():
    def _str_to_bool(s):
        """Convert string to bool (in argparse context)."""
        if s.lower() not in ['true', 'false']:
            raise ValueError('Argument needs to be a '
                             'boolean, got {}'.format(s))
        return {'true': True, 'false': False}[s.lower()]

    parser = argparse.ArgumentParser(description='WaveNet example network')
    parser.add_argument('--batch_size', type=int, default=BATCH_SIZE,
                        help='How many wav files to process at once. Default: ' + str(BATCH_SIZE) + '.')
    parser.add_argument('--data_dir', type=str, default=DATA_DIRECTORY,
                        help='The directory containing the VCTK corpus.')
    parser.add_argument('--store_metadata', type=bool, default=METADATA,
                        help='Whether to store advanced debugging information '
                        '(execution time, memory consumption) for use with '
                        'TensorBoard. Default: ' + str(METADATA) + '.')
    parser.add_argument('--logdir', type=str, default=None,
                        help='Directory in which to store the logging '
                        'information for TensorBoard. '
                        'If the model already exists, it will restore '
                        'the state and will continue training. '
                        'Cannot use with --logdir_root and --restore_from.')
    parser.add_argument('--logdir_root', type=str, default=None,
                        help='Root directory to place the logging '
                        'output and generated model. These are stored '
                        'under the dated subdirectory of --logdir_root. '
                        'Cannot use with --logdir.')
    parser.add_argument('--restore_from', type=str, default=None,
                        help='Directory in which to restore the model from. '
                        'This creates the new model under the dated directory '
                        'in --logdir_root. '
                        'Cannot use with --logdir.')
    parser.add_argument('--checkpoint_every', type=int,
                        default=CHECKPOINT_EVERY,
                        help='How many steps to save each checkpoint after. Default: ' + str(CHECKPOINT_EVERY) + '.')
    parser.add_argument('--num_steps', type=int, default=NUM_STEPS,
                        help='Number of training steps. Default: ' + str(NUM_STEPS) + '.')
    parser.add_argument('--learning_rate', type=float, default=LEARNING_RATE,
                        help='Learning rate for training. Default: ' + str(LEARNING_RATE) + '.')
    parser.add_argument('--wavenet_params', type=str, default=WAVENET_PARAMS,
                        help='JSON file with the network parameters. Default: ' + WAVENET_PARAMS + '.')
    parser.add_argument('--sample_size', type=int, default=SAMPLE_SIZE,
                        help='Concatenate and cut audio samples to this many '
                        'samples. Default: ' + str(SAMPLE_SIZE) + '.')
    parser.add_argument('--l2_regularization_strength', type=float,
                        default=L2_REGULARIZATION_STRENGTH,
                        help='Coefficient in the L2 regularization. '
                        'Default: False')
    parser.add_argument('--silence_threshold', type=float,
                        default=SILENCE_THRESHOLD,
                        help='Volume threshold below which to trim the start '
                        'and the end from the training set samples. Default: ' + str(SILENCE_THRESHOLD) + '.')
    parser.add_argument('--optimizer', type=str, default='adam',
                        choices=optimizer_factory.keys(),
                        help='Select the optimizer specified by this option. Default: adam.')
    parser.add_argument('--momentum', type=float,
                        default=MOMENTUM, help='Specify the momentum to be '
                        'used by sgd or rmsprop optimizer. Ignored by the '
                        'adam optimizer. Default: ' + str(MOMENTUM) + '.')
    parser.add_argument('--histograms', type=_str_to_bool, default=False,
                        help='Whether to store histogram summaries. Default: False')
    parser.add_argument('--gc_channels', type=int, default=None,
                        help='Number of global condition channels. Default: None. Expecting: Int')
    parser.add_argument('--max_checkpoints', type=int, default=MAX_TO_KEEP,
                        help='Maximum amount of checkpoints that will be kept alive. Default: '
                             + str(MAX_TO_KEEP) + '.')
    return parser.parse_args([])

# %%
def save(saver, sess, logdir, step):
    model_name = 'model.ckpt'
    checkpoint_path = os.path.join(logdir, model_name)
    print('Storing checkpoint to {} ...'.format(logdir), end="")
    sys.stdout.flush()

    if not os.path.exists(logdir):
        os.makedirs(logdir)

    saver.save(sess, checkpoint_path, global_step=step)
    print(' Done.')

# %%
def load(saver, sess, logdir):
    print("Trying to restore saved checkpoints from {} ...".format(logdir),
          end="")

    ckpt = tf.train.get_checkpoint_state(logdir)
    if ckpt:
        print("  Checkpoint found: {}".format(ckpt.model_checkpoint_path))
        global_step = int(ckpt.model_checkpoint_path
                          .split('/')[-1]
                          .split('-')[-1])
        print("  Global step was: {}".format(global_step))
        print("  Restoring...", end="")
        saver.restore(sess, ckpt.model_checkpoint_path)
        print(" Done.")
        return global_step
    else:
        print(" No checkpoint found.")
        return None

# %%
def get_default_logdir(logdir_root):
    logdir = os.path.join(logdir_root, 'train', STARTED_DATESTRING)
    return logdir


def validate_directories(args):
    """Validate and arrange directory related arguments."""

    # Validation
    if args.logdir and args.logdir_root:
        raise ValueError("--logdir and --logdir_root cannot be "
                         "specified at the same time.")

    if args.logdir and args.restore_from:
        raise ValueError(
            "--logdir and --restore_from cannot be specified at the same "
            "time. This is to keep your previous model from unexpected "
            "overwrites.\n"
            "Use --logdir_root to specify the root of the directory which "
            "will be automatically created with current date and time, or use "
            "only --logdir to just continue the training from the last "
            "checkpoint.")

    # Arrangement
    logdir_root = args.logdir_root
    if logdir_root is None:
        logdir_root = LOGDIR_ROOT

    logdir = args.logdir
    if logdir is None:
        logdir = get_default_logdir(logdir_root)
        print('Using default logdir: {}'.format(logdir))

    restore_from = args.restore_from
    if restore_from is None:
        # args.logdir and args.restore_from are exclusive,
        # so it is guaranteed the logdir here is newly created.
        restore_from = logdir

    return {
        'logdir': logdir,
        'logdir_root': args.logdir_root,
        'restore_from': restore_from
    }

# %%
args = get_arguments()

try:
    directories = validate_directories(args)
except ValueError as e:
    print("Some arguments are wrong:")
    print(str(e))

logdir = directories['logdir']
restore_from = directories['restore_from']

# Even if we restored the model, we will treat it as new training
# if the trained model is written into an arbitrary location.
is_overwritten_training = logdir != restore_from

with open(args.wavenet_params, 'r') as f:
    wavenet_params = json.load(f)

# Create coordinator.
coord = tf.train.Coordinator()

# Load raw waveform from VCTK corpus.
with tf.name_scope('create_inputs'):
    # Allow silence trimming to be skipped by specifying a threshold near
    # zero.
    silence_threshold = args.silence_threshold if args.silence_threshold > \
                                                  EPSILON else None
    gc_enabled = args.gc_channels is not None
    reader = AudioReader(
        args.data_dir,
        coord,
        sample_rate=wavenet_params['sample_rate'],   #"sample_rate": 16000,
        gc_enabled=gc_enabled,
        receptive_field=WaveNetModel.calculate_receptive_field(wavenet_params["filter_width"],
                                                               wavenet_params["dilations"],
                                                               wavenet_params["scalar_input"],
                                                               wavenet_params["initial_filter_width"]),
        sample_size=args.sample_size,  #SAMPLE_SIZE = 100000
        silence_threshold=silence_threshold)
    traudio_batch = reader.trdequeue(args.batch_size)  #BATCH_SIZE = 1
    if gc_enabled:
        ##TODO train and val
        gc_id_batch = reader.dequeue_gc(args.batch_size)
    else:
        gc_id_batch = None

# Create network.
net = WaveNetModel(
    batch_size=args.batch_size,
    dilations=wavenet_params["dilations"],
    filter_width=wavenet_params["filter_width"],
    residual_channels=wavenet_params["residual_channels"],
    dilation_channels=wavenet_params["dilation_channels"],
    skip_channels=wavenet_params["skip_channels"],
    quantization_channels=wavenet_params["quantization_channels"],
    use_biases=wavenet_params["use_biases"],
    scalar_input=wavenet_params["scalar_input"],
    initial_filter_width=wavenet_params["initial_filter_width"],
    histograms=args.histograms,
    global_condition_channels=args.gc_channels,
    global_condition_cardinality=reader.gc_category_cardinality)

if args.l2_regularization_strength == 0:
    args.l2_regularization_strength = None
trloss = net.trloss(input_batch=traudio_batch,
                global_condition_batch=gc_id_batch,
                l2_regularization_strength=args.l2_regularization_strength)
optimizer = optimizer_factory[args.optimizer](
                learning_rate=args.learning_rate,
                momentum=args.momentum)
trainable = tf.trainable_variables()
optim = optimizer.minimize(trloss, var_list=trainable)

# Set up logging for TensorBoard.
writer = tf.summary.FileWriter(logdir)
writer.add_graph(tf.get_default_graph())
run_metadata = tf.RunMetadata()
summaries = tf.summary.merge_all()

# Set up session
config = tf.ConfigProto(log_device_placement=False)
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
#sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

vaudio_batch = reader.valbatch()
valloss = net.valloss(input_batch=vaudio_batch,
                global_condition_batch=gc_id_batch,
                l2_regularization_strength=args.l2_regularization_strength)
genfile = net.generateFile(input_batch=vaudio_batch,
                global_condition_batch=gc_id_batch,
                l2_regularization_strength=args.l2_regularization_strength)

init = tf.global_variables_initializer()
sess.run(init)

# Saver for storing checkpoints of the model.
saver = tf.train.Saver(var_list=tf.trainable_variables(), max_to_keep=args.max_checkpoints)

try:
    saved_global_step = load(saver, sess, restore_from)
    if is_overwritten_training or saved_global_step is None:
        # The first training step will be saved_global_step + 1,
        # therefore we put -1 here for new or overwritten trainings.
        saved_global_step = -1

except:
    print("Something went wrong while restoring checkpoint. "
          "We will terminate training to avoid accidentally overwriting "
          "the previous model.")
    raise

    
    
threads = tf.train.start_queue_runners(sess=sess, coord=coord)
reader.start_threads(sess)


step = None
last_saved_step = saved_global_step
minvalloss = 10000
try:
    for step in range(saved_global_step + 1, args.num_steps):
        start_time = time.time()
        if args.store_metadata and step % 50 == 0:
            # Slow run that stores extra information for debugging.
            print('Storing metadata')
            run_options = tf.RunOptions(
                trace_level=tf.RunOptions.FULL_TRACE)
            summary, trloss_value, _ = sess.run(
                [summaries, trloss, optim],
                options=run_options,
                run_metadata=run_metadata)
            writer.add_summary(summary, step)
            writer.add_run_metadata(run_metadata,
                                    'step_{:04d}'.format(step))
            tl = timeline.Timeline(run_metadata.step_stats)
            timeline_path = os.path.join(logdir, 'timeline.trace')
            with open(timeline_path, 'w') as f:
                f.write(tl.generate_chrome_trace_format(show_memory=True))
        else:
            summary, trloss_value, _ = sess.run([summaries, trloss, optim])
            writer.add_summary(summary, step)
        duration = time.time() - start_time
        print('step {:d} - trloss = {:.3f}, ({:.3f} sec/step)'
              .format(step, trloss_value, duration))
        
        
        if step % args.checkpoint_every == 0:
            ans = sess.run(genfile)
            #print(ans.shape)
            sf.write('./vsCorpus/ans/'+str(step)+'.wav',ans.reshape(-1),16000)
            print('stored done')
            valloss_value = sess.run(valloss)
            print('validateLoss = {:.3f}, ({:.3f} sec/step)'
              .format(valloss_value, duration))
            #if(valloss_value < minvalloss):
                #save(saver, sess, logdir, step)
                #last_saved_step = step
                #minvalloss = valloss_value

except KeyboardInterrupt:
    # Introduce a line break after ^C is displayed so save message
    # is on its own line.
    print()
finally:
    if step > last_saved_step:
        save(saver, sess, logdir, step)
    coord.request_stop()
    coord.join(threads)
# Out:
# Using default logdir: ./logdirVS/train/2018-06-05T22-18-18
# trdequeue
# val ['./vsCorpus/pred_mix.wav', './vsCorpus/pred_vocal.wav']
# raw_output Tensor("wavenet_2/postprocessing/Add_1:0", shape=(?, ?, 256), dtype=float32)
# ans0 (?,)
# Trying to restore saved checkpoints from ./logdirVS/train/2018-06-05T22-18-18 ... No checkpoint found.
# step 0 - trloss = 5.690, (19.421 sec/step)
# stored done
# validateLoss = 5.512, (19.421 sec/step)
# step 1 - trloss = 5.568, (2.489 sec/step)
# step 2 - trloss = 5.587, (2.484 sec/step)
# step 3 - trloss = 5.533, (2.484 sec/step)
# step 4 - trloss = 5.574, (2.485 sec/step)
# step 5 - trloss = 5.526, (2.488 sec/step)
# step 6 - trloss = 5.513, (2.487 sec/step)
# step 7 - trloss = 5.500, (2.487 sec/step)
# step 8 - trloss = 5.570, (2.487 sec/step)
# step 9 - trloss = 5.479, (2.497 sec/step)
# step 10 - trloss = 5.457, (2.486 sec/step)
# step 11 - trloss = 5.484, (2.489 sec/step)
# step 12 - trloss = 5.455, (2.492 sec/step)
# step 13 - trloss = 5.453, (2.491 sec/step)
# step 14 - trloss = 5.476, (2.489 sec/step)
# step 15 - trloss = 5.422, (2.492 sec/step)
# step 16 - trloss = 5.414, (2.491 sec/step)
# step 17 - trloss = 5.437, (2.493 sec/step)
# step 18 - trloss = 5.436, (2.494 sec/step)
# step 19 - trloss = 5.519, (2.494 sec/step)
# step 20 - trloss = 5.470, (2.495 sec/step)
# step 21 - trloss = 5.524, (2.494 sec/step)
# step 22 - trloss = 5.475, (2.495 sec/step)
# step 23 - trloss = 5.458, (2.496 sec/step)
# step 24 - trloss = 5.445, (2.494 sec/step)
# step 25 - trloss = 5.540, (2.496 sec/step)
# step 26 - trloss = 5.474, (2.497 sec/step)
# step 27 - trloss = 5.486, (2.498 sec/step)
# step 28 - trloss = 5.476, (2.497 sec/step)
# step 29 - trloss = 5.444, (2.497 sec/step)
# step 30 - trloss = 5.432, (2.498 sec/step)
# step 31 - trloss = 5.461, (2.499 sec/step)
# step 32 - trloss = 5.485, (2.499 sec/step)
# step 33 - trloss = 5.482, (2.500 sec/step)
# step 34 - trloss = 5.458, (2.501 sec/step)
# step 35 - trloss = 5.442, (2.500 sec/step)
# step 36 - trloss = 5.534, (2.497 sec/step)
# step 37 - trloss = 5.451, (2.499 sec/step)
# step 38 - trloss = 5.480, (2.498 sec/step)
# step 39 - trloss = 5.472, (2.499 sec/step)
# step 40 - trloss = 5.483, (2.499 sec/step)
# step 41 - trloss = 5.454, (2.500 sec/step)
# step 42 - trloss = 5.491, (2.498 sec/step)
# step 43 - trloss = 5.445, (2.499 sec/step)
# step 44 - trloss = 5.414, (2.497 sec/step)
# step 45 - trloss = 5.452, (2.496 sec/step)
# step 46 - trloss = 5.408, (2.498 sec/step)
# step 47 - trloss = 5.386, (2.497 sec/step)
# step 48 - trloss = 5.438, (2.494 sec/step)
# step 49 - trloss = 5.397, (2.495 sec/step)
# step 50 - trloss = 5.396, (2.497 sec/step)
# stored done
# validateLoss = 5.433, (2.497 sec/step)
# step 51 - trloss = 5.438, (2.494 sec/step)
# step 52 - trloss = 5.447, (2.495 sec/step)
# step 53 - trloss = 5.504, (2.502 sec/step)
# step 54 - trloss = 5.471, (2.496 sec/step)
# step 55 - trloss = 5.493, (2.496 sec/step)
# step 56 - trloss = 5.468, (2.495 sec/step)
# step 57 - trloss = 5.445, (2.494 sec/step)
# step 58 - trloss = 5.745, (2.499 sec/step)
# step 59 - trloss = 5.569, (2.496 sec/step)
# step 60 - trloss = 5.462, (2.496 sec/step)
# step 61 - trloss = 5.488, (2.500 sec/step)
# step 62 - trloss = 5.477, (2.497 sec/step)
# step 63 - trloss = 5.449, (2.499 sec/step)
# step 64 - trloss = 5.436, (2.499 sec/step)
# step 65 - trloss = 5.465, (2.500 sec/step)
# step 66 - trloss = 5.483, (2.500 sec/step)
# step 67 - trloss = 5.474, (2.499 sec/step)
# step 68 - trloss = 5.455, (2.500 sec/step)
# step 69 - trloss = 5.435, (2.502 sec/step)
# step 70 - trloss = 5.534, (2.502 sec/step)
# step 71 - trloss = 5.455, (2.501 sec/step)
# step 72 - trloss = 5.477, (2.502 sec/step)
# step 73 - trloss = 5.468, (2.500 sec/step)
# step 74 - trloss = 5.480, (2.500 sec/step)
# step 75 - trloss = 5.464, (2.501 sec/step)
# step 76 - trloss = 5.485, (2.500 sec/step)
# step 77 - trloss = 5.436, (2.499 sec/step)
# step 78 - trloss = 5.401, (2.501 sec/step)
# step 79 - trloss = 5.421, (2.501 sec/step)
# step 80 - trloss = 5.431, (2.502 sec/step)
# step 81 - trloss = 5.344, (2.498 sec/step)
# step 82 - trloss = 5.596, (2.497 sec/step)
# step 83 - trloss = 5.382, (2.499 sec/step)
# step 84 - trloss = 5.417, (2.500 sec/step)
# step 85 - trloss = 5.407, (2.499 sec/step)
# step 86 - trloss = 5.402, (2.500 sec/step)
# step 87 - trloss = 5.459, (2.502 sec/step)
# step 88 - trloss = 5.349, (2.500 sec/step)
# step 89 - trloss = 5.378, (2.499 sec/step)
# step 90 - trloss = 5.367, (2.499 sec/step)
# step 91 - trloss = 5.336, (2.501 sec/step)
# step 92 - trloss = 5.286, (2.499 sec/step)
# step 93 - trloss = 5.300, (2.501 sec/step)
# step 94 - trloss = 5.335, (2.499 sec/step)
# step 95 - trloss = 5.339, (2.499 sec/step)
# step 96 - trloss = 5.251, (2.499 sec/step)
# step 97 - trloss = 5.313, (2.500 sec/step)
# step 98 - trloss = 5.282, (2.499 sec/step)
# step 99 - trloss = 5.273, (2.499 sec/step)
# step 100 - trloss = 5.309, (2.501 sec/step)
# stored done
# validateLoss = 5.226, (2.501 sec/step)
# step 101 - trloss = 5.236, (2.498 sec/step)
# step 102 - trloss = 5.289, (2.499 sec/step)
# step 103 - trloss = 5.252, (2.499 sec/step)
# step 104 - trloss = 5.239, (2.498 sec/step)
# step 105 - trloss = 5.236, (2.497 sec/step)
# step 106 - trloss = 5.208, (2.497 sec/step)
# step 107 - trloss = 5.171, (2.499 sec/step)
# step 108 - trloss = 5.216, (2.499 sec/step)
# step 109 - trloss = 5.172, (2.498 sec/step)
# step 110 - trloss = 5.225, (2.510 sec/step)
# step 111 - trloss = 5.118, (2.496 sec/step)
# step 112 - trloss = 5.214, (2.496 sec/step)
# step 113 - trloss = 5.266, (2.498 sec/step)
# step 114 - trloss = 5.561, (2.497 sec/step)
# step 115 - trloss = 5.078, (2.497 sec/step)
# step 116 - trloss = 5.502, (2.497 sec/step)
# step 117 - trloss = 5.277, (2.495 sec/step)
# step 118 - trloss = 5.268, (2.497 sec/step)
# step 119 - trloss = 5.288, (2.496 sec/step)
# step 120 - trloss = 5.276, (2.497 sec/step)
# step 121 - trloss = 5.248, (2.494 sec/step)
# step 122 - trloss = 5.182, (2.496 sec/step)
# step 123 - trloss = 5.194, (2.496 sec/step)
# step 124 - trloss = 5.236, (2.497 sec/step)
# step 125 - trloss = 5.220, (2.497 sec/step)
# step 126 - trloss = 5.209, (2.496 sec/step)
# step 127 - trloss = 5.198, (2.496 sec/step)
# step 128 - trloss = 5.205, (2.499 sec/step)
# step 129 - trloss = 5.200, (2.497 sec/step)
# step 130 - trloss = 5.187, (2.498 sec/step)
# step 131 - trloss = 5.199, (2.496 sec/step)
# step 132 - trloss = 5.204, (2.498 sec/step)
# step 133 - trloss = 5.176, (2.498 sec/step)
# step 134 - trloss = 5.208, (2.498 sec/step)
# step 135 - trloss = 5.178, (2.498 sec/step)
# step 136 - trloss = 5.162, (2.506 sec/step)
# step 137 - trloss = 5.161, (2.498 sec/step)
# step 138 - trloss = 5.166, (2.497 sec/step)
# step 139 - trloss = 5.200, (2.497 sec/step)
# step 140 - trloss = 5.104, (2.497 sec/step)
# step 141 - trloss = 5.113, (2.498 sec/step)
# step 142 - trloss = 5.155, (2.500 sec/step)
# step 143 - trloss = 5.112, (2.499 sec/step)
# step 144 - trloss = 5.152, (2.498 sec/step)
# step 145 - trloss = 5.091, (2.497 sec/step)
# step 146 - trloss = 5.142, (2.498 sec/step)
# step 147 - trloss = 5.238, (2.496 sec/step)
# step 148 - trloss = 5.215, (2.495 sec/step)
# step 149 - trloss = 5.039, (2.496 sec/step)
# step 150 - trloss = 5.204, (2.495 sec/step)
# stored done
# validateLoss = 5.233, (2.495 sec/step)
# step 151 - trloss = 5.079, (2.497 sec/step)
# step 152 - trloss = 5.139, (2.507 sec/step)
# step 153 - trloss = 5.185, (2.496 sec/step)
# step 154 - trloss = 5.122, (2.497 sec/step)
# step 155 - trloss = 5.125, (2.498 sec/step)
# step 156 - trloss = 5.140, (2.496 sec/step)
# step 157 - trloss = 5.134, (2.496 sec/step)
# step 158 - trloss = 5.151, (2.500 sec/step)
# step 159 - trloss = 5.150, (2.496 sec/step)
# step 160 - trloss = 5.144, (2.497 sec/step)
# step 161 - trloss = 5.118, (2.496 sec/step)
# step 162 - trloss = 5.158, (2.498 sec/step)
# step 163 - trloss = 5.142, (2.497 sec/step)
# step 164 - trloss = 5.144, (2.499 sec/step)
# step 165 - trloss = 5.160, (2.499 sec/step)
# step 166 - trloss = 5.153, (2.500 sec/step)
# step 167 - trloss = 5.144, (2.498 sec/step)
# step 168 - trloss = 5.136, (2.499 sec/step)
# step 169 - trloss = 5.125, (2.498 sec/step)
# step 170 - trloss = 5.107, (2.499 sec/step)
# step 171 - trloss = 5.133, (2.500 sec/step)
# step 172 - trloss = 5.173, (2.498 sec/step)
# step 173 - trloss = 5.146, (2.501 sec/step)
# step 174 - trloss = 5.050, (2.500 sec/step)
# step 175 - trloss = 5.072, (2.501 sec/step)
# step 176 - trloss = 5.126, (2.499 sec/step)
# step 177 - trloss = 5.081, (2.499 sec/step)
# step 178 - trloss = 5.119, (2.499 sec/step)
# step 179 - trloss = 5.059, (2.501 sec/step)
# step 180 - trloss = 5.113, (2.499 sec/step)
# step 181 - trloss = 5.187, (2.501 sec/step)
# step 182 - trloss = 5.178, (2.506 sec/step)
# step 183 - trloss = 5.023, (2.501 sec/step)
# step 184 - trloss = 5.187, (2.499 sec/step)
# step 185 - trloss = 5.043, (2.499 sec/step)
# step 186 - trloss = 5.125, (2.499 sec/step)
# step 187 - trloss = 5.194, (2.498 sec/step)
# step 188 - trloss = 5.082, (2.498 sec/step)
# step 189 - trloss = 5.070, (2.500 sec/step)
# step 190 - trloss = 5.108, (2.499 sec/step)
# step 191 - trloss = 5.104, (2.498 sec/step)
# step 192 - trloss = 5.090, (2.499 sec/step)
# step 193 - trloss = 5.122, (2.499 sec/step)
# step 194 - trloss = 5.115, (2.500 sec/step)
# step 195 - trloss = 5.111, (2.499 sec/step)
# step 196 - trloss = 5.136, (2.500 sec/step)
# step 197 - trloss = 5.104, (2.499 sec/step)
# step 198 - trloss = 5.122, (2.498 sec/step)
# step 199 - trloss = 5.133, (2.500 sec/step)
# step 200 - trloss = 5.120, (2.498 sec/step)
# stored done
# validateLoss = 5.220, (2.498 sec/step)
# step 201 - trloss = 5.102, (2.500 sec/step)
# step 202 - trloss = 5.120, (2.499 sec/step)
# step 203 - trloss = 5.099, (2.500 sec/step)
# step 204 - trloss = 5.059, (2.501 sec/step)
# step 205 - trloss = 5.073, (2.500 sec/step)
# step 206 - trloss = 5.101, (2.500 sec/step)
# step 207 - trloss = 5.094, (2.501 sec/step)
# step 208 - trloss = 5.003, (2.500 sec/step)
# step 209 - trloss = 5.004, (2.501 sec/step)
# step 210 - trloss = 5.016, (2.501 sec/step)
# step 211 - trloss = 5.014, (2.501 sec/step)
# step 212 - trloss = 5.038, (2.500 sec/step)
# step 213 - trloss = 4.989, (2.502 sec/step)
# step 214 - trloss = 5.042, (2.511 sec/step)
# step 215 - trloss = 5.102, (2.502 sec/step)
# step 216 - trloss = 5.218, (2.503 sec/step)
# step 217 - trloss = 4.954, (2.501 sec/step)
# step 218 - trloss = 5.122, (2.502 sec/step)
# step 219 - trloss = 5.004, (2.502 sec/step)
# step 220 - trloss = 5.054, (2.501 sec/step)
# step 221 - trloss = 5.085, (2.501 sec/step)
# step 222 - trloss = 5.018, (2.500 sec/step)
# step 223 - trloss = 4.997, (2.500 sec/step)
# step 224 - trloss = 5.034, (2.501 sec/step)
# step 225 - trloss = 4.990, (2.500 sec/step)
# step 226 - trloss = 5.010, (2.501 sec/step)
# step 227 - trloss = 5.062, (2.449 sec/step)
# step 228 - trloss = 5.053, (2.514 sec/step)
# step 229 - trloss = 4.974, (2.509 sec/step)
# step 230 - trloss = 5.036, (2.507 sec/step)
# step 231 - trloss = 5.008, (2.503 sec/step)
# step 232 - trloss = 4.992, (2.504 sec/step)
# step 233 - trloss = 5.003, (2.502 sec/step)
# step 234 - trloss = 4.997, (2.504 sec/step)
# step 235 - trloss = 5.011, (2.500 sec/step)
# step 236 - trloss = 4.984, (2.499 sec/step)
# step 237 - trloss = 4.978, (2.499 sec/step)
# step 238 - trloss = 4.930, (2.500 sec/step)
# step 239 - trloss = 4.934, (2.497 sec/step)
# step 240 - trloss = 5.043, (2.497 sec/step)
# step 241 - trloss = 4.924, (2.497 sec/step)
# step 242 - trloss = 4.886, (2.498 sec/step)
# step 243 - trloss = 4.892, (2.499 sec/step)
# step 244 - trloss = 4.869, (2.498 sec/step)
# step 245 - trloss = 4.901, (2.503 sec/step)
# step 246 - trloss = 4.868, (2.497 sec/step)
# step 247 - trloss = 4.900, (2.502 sec/step)
# step 248 - trloss = 4.939, (2.500 sec/step)
# step 249 - trloss = 4.947, (2.501 sec/step)
# step 250 - trloss = 5.041, (2.501 sec/step)
# stored done
# validateLoss = 4.907, (2.501 sec/step)
# step 251 - trloss = 4.895, (2.503 sec/step)
# step 252 - trloss = 4.963, (2.498 sec/step)
# step 253 - trloss = 4.889, (2.506 sec/step)
# step 254 - trloss = 4.941, (2.503 sec/step)
# step 255 - trloss = 4.979, (2.499 sec/step)
# step 256 - trloss = 4.828, (2.501 sec/step)
# step 257 - trloss = 4.828, (2.500 sec/step)
# step 258 - trloss = 4.914, (2.502 sec/step)
# step 259 - trloss = 4.831, (2.508 sec/step)
# step 260 - trloss = 4.835, (2.502 sec/step)
# step 261 - trloss = 4.949, (2.502 sec/step)
# step 262 - trloss = 4.905, (2.505 sec/step)
# step 263 - trloss = 4.845, (2.502 sec/step)
# step 264 - trloss = 4.897, (2.505 sec/step)
# step 265 - trloss = 4.886, (2.502 sec/step)
# step 266 - trloss = 4.873, (2.513 sec/step)
# step 267 - trloss = 4.882, (2.502 sec/step)
# step 268 - trloss = 4.835, (2.499 sec/step)
# step 269 - trloss = 4.892, (2.513 sec/step)
# step 270 - trloss = 4.848, (2.502 sec/step)
# step 271 - trloss = 4.863, (2.500 sec/step)
# step 272 - trloss = 4.812, (2.502 sec/step)
# step 273 - trloss = 4.788, (2.503 sec/step)
# step 274 - trloss = 4.968, (2.505 sec/step)
# step 275 - trloss = 4.810, (2.501 sec/step)
# step 276 - trloss = 4.784, (2.503 sec/step)
# step 277 - trloss = 4.797, (2.502 sec/step)
# step 278 - trloss = 4.792, (2.509 sec/step)
# step 279 - trloss = 4.824, (2.501 sec/step)
# step 280 - trloss = 4.783, (2.502 sec/step)
# step 281 - trloss = 4.786, (2.501 sec/step)
# step 282 - trloss = 4.821, (2.501 sec/step)
# step 283 - trloss = 4.846, (2.503 sec/step)
# step 284 - trloss = 4.939, (2.503 sec/step)
# step 285 - trloss = 4.777, (2.504 sec/step)
# step 286 - trloss = 4.962, (2.505 sec/step)
# step 287 - trloss = 4.829, (2.503 sec/step)
# step 288 - trloss = 4.899, (2.500 sec/step)
# step 289 - trloss = 4.859, (2.501 sec/step)
# step 290 - trloss = 4.760, (2.501 sec/step)
# step 291 - trloss = 4.759, (2.500 sec/step)
# step 292 - trloss = 4.890, (2.498 sec/step)
# step 293 - trloss = 4.816, (2.500 sec/step)
# step 294 - trloss = 4.780, (2.503 sec/step)
# step 295 - trloss = 4.906, (2.500 sec/step)
# step 296 - trloss = 4.899, (2.500 sec/step)
# step 297 - trloss = 4.826, (2.503 sec/step)
# step 298 - trloss = 4.852, (2.500 sec/step)
# step 299 - trloss = 4.863, (2.499 sec/step)
# step 300 - trloss = 4.833, (2.503 sec/step)
# stored done
# validateLoss = 4.747, (2.503 sec/step)
# step 301 - trloss = 4.849, (2.503 sec/step)
# step 302 - trloss = 4.789, (2.501 sec/step)
# step 303 - trloss = 4.857, (2.502 sec/step)
# step 304 - trloss = 4.845, (2.501 sec/step)
# step 305 - trloss = 4.822, (2.503 sec/step)
# step 306 - trloss = 4.750, (2.501 sec/step)
# step 307 - trloss = 4.750, (2.504 sec/step)
# step 308 - trloss = 4.904, (2.509 sec/step)
# step 309 - trloss = 4.744, (2.505 sec/step)
# step 310 - trloss = 4.736, (2.504 sec/step)
# step 311 - trloss = 4.739, (2.505 sec/step)
# step 312 - trloss = 4.758, (2.504 sec/step)
# step 313 - trloss = 4.764, (2.504 sec/step)
# step 314 - trloss = 4.717, (2.503 sec/step)
# step 315 - trloss = 4.725, (2.506 sec/step)
# step 316 - trloss = 4.777, (2.504 sec/step)
# step 317 - trloss = 4.809, (2.501 sec/step)
# step 318 - trloss = 4.895, (2.501 sec/step)
# step 319 - trloss = 4.751, (2.502 sec/step)
# step 320 - trloss = 4.881, (2.501 sec/step)
# step 321 - trloss = 4.803, (2.502 sec/step)
# step 322 - trloss = 4.881, (2.501 sec/step)
# step 323 - trloss = 4.873, (2.505 sec/step)
# step 324 - trloss = 4.741, (2.500 sec/step)
# step 325 - trloss = 4.689, (2.500 sec/step)
# step 326 - trloss = 4.855, (2.501 sec/step)
# step 327 - trloss = 4.763, (2.511 sec/step)
# step 328 - trloss = 4.741, (2.499 sec/step)
# step 329 - trloss = 4.849, (2.499 sec/step)
# step 330 - trloss = 4.827, (2.498 sec/step)
# step 331 - trloss = 4.780, (2.498 sec/step)
# step 332 - trloss = 4.814, (2.498 sec/step)
# step 333 - trloss = 4.815, (2.499 sec/step)
# step 334 - trloss = 4.779, (2.497 sec/step)
# step 335 - trloss = 4.819, (2.499 sec/step)
# step 336 - trloss = 4.760, (2.500 sec/step)
# step 337 - trloss = 4.810, (2.497 sec/step)
# step 338 - trloss = 4.776, (2.498 sec/step)
# step 339 - trloss = 4.784, (2.498 sec/step)
# step 340 - trloss = 4.708, (2.497 sec/step)
# step 341 - trloss = 4.709, (2.499 sec/step)
# step 342 - trloss = 4.847, (2.499 sec/step)
# step 343 - trloss = 4.697, (2.498 sec/step)
# step 344 - trloss = 4.698, (2.498 sec/step)
# step 345 - trloss = 4.695, (2.498 sec/step)
# step 346 - trloss = 4.716, (2.496 sec/step)
# step 347 - trloss = 4.726, (2.499 sec/step)
# step 348 - trloss = 4.681, (2.498 sec/step)
# step 349 - trloss = 4.681, (2.499 sec/step)
# step 350 - trloss = 4.740, (2.498 sec/step)
# stored done
# validateLoss = 4.733, (2.498 sec/step)
# step 351 - trloss = 4.765, (2.498 sec/step)
# step 352 - trloss = 4.856, (2.498 sec/step)
# step 353 - trloss = 4.753, (2.496 sec/step)
# step 354 - trloss = 4.824, (2.497 sec/step)
# step 355 - trloss = 4.755, (2.498 sec/step)
# step 356 - trloss = 4.828, (2.497 sec/step)
# step 357 - trloss = 4.835, (2.496 sec/step)
# step 358 - trloss = 4.701, (2.497 sec/step)
# step 359 - trloss = 4.673, (2.498 sec/step)
# step 360 - trloss = 4.834, (2.497 sec/step)
# step 361 - trloss = 4.724, (2.496 sec/step)
# step 362 - trloss = 4.711, (2.498 sec/step)
# step 363 - trloss = 4.828, (2.496 sec/step)
# step 364 - trloss = 4.790, (2.496 sec/step)
# step 365 - trloss = 4.772, (2.499 sec/step)
# step 366 - trloss = 4.794, (2.498 sec/step)
# step 367 - trloss = 4.798, (2.499 sec/step)
# step 368 - trloss = 4.746, (2.499 sec/step)
# step 369 - trloss = 4.805, (2.499 sec/step)
# step 370 - trloss = 4.743, (2.497 sec/step)
# step 371 - trloss = 4.793, (2.498 sec/step)
# step 372 - trloss = 4.742, (2.499 sec/step)
# step 373 - trloss = 4.762, (2.498 sec/step)
# step 374 - trloss = 4.696, (2.497 sec/step)
# step 375 - trloss = 4.700, (2.499 sec/step)
# step 376 - trloss = 4.836, (2.497 sec/step)
# step 377 - trloss = 4.660, (2.499 sec/step)
# step 378 - trloss = 4.679, (2.498 sec/step)
# step 379 - trloss = 4.690, (2.497 sec/step)
# step 380 - trloss = 4.696, (2.496 sec/step)
# step 381 - trloss = 4.706, (2.496 sec/step)
# step 382 - trloss = 4.663, (2.496 sec/step)
# step 383 - trloss = 4.676, (2.495 sec/step)
# step 384 - trloss = 4.708, (2.496 sec/step)
# step 385 - trloss = 4.755, (2.496 sec/step)
# step 386 - trloss = 4.805, (2.497 sec/step)
# step 387 - trloss = 4.696, (2.497 sec/step)
# step 388 - trloss = 4.744, (2.497 sec/step)
# step 389 - trloss = 4.732, (2.497 sec/step)
# step 390 - trloss = 4.793, (2.495 sec/step)
# step 391 - trloss = 4.815, (2.496 sec/step)
# step 392 - trloss = 4.672, (2.496 sec/step)
# step 393 - trloss = 4.629, (2.498 sec/step)
# step 394 - trloss = 4.836, (2.497 sec/step)
# step 395 - trloss = 4.709, (2.498 sec/step)
# step 396 - trloss = 4.690, (2.498 sec/step)
# step 397 - trloss = 4.793, (2.499 sec/step)
# step 398 - trloss = 4.748, (2.498 sec/step)
# step 399 - trloss = 4.728, (2.498 sec/step)
# step 400 - trloss = 4.759, (2.497 sec/step)
# stored done
# validateLoss = 4.714, (2.497 sec/step)
# step 401 - trloss = 4.763, (2.498 sec/step)
# step 402 - trloss = 4.726, (2.497 sec/step)
# step 403 - trloss = 4.766, (2.498 sec/step)
# step 404 - trloss = 4.705, (2.497 sec/step)
# step 405 - trloss = 4.765, (2.497 sec/step)
# step 406 - trloss = 4.695, (2.497 sec/step)
# step 407 - trloss = 4.725, (2.504 sec/step)
# step 408 - trloss = 4.651, (2.499 sec/step)
# step 409 - trloss = 4.643, (2.499 sec/step)
# step 410 - trloss = 4.800, (2.498 sec/step)
# step 411 - trloss = 4.635, (2.500 sec/step)
# step 412 - trloss = 4.639, (2.498 sec/step)
# step 413 - trloss = 4.656, (2.499 sec/step)
# step 414 - trloss = 4.654, (2.494 sec/step)
# step 415 - trloss = 4.651, (2.495 sec/step)
# step 416 - trloss = 4.641, (2.495 sec/step)
# step 417 - trloss = 4.664, (2.497 sec/step)
# step 418 - trloss = 4.679, (2.496 sec/step)
# step 419 - trloss = 4.717, (2.496 sec/step)
# step 420 - trloss = 4.769, (2.495 sec/step)
# step 421 - trloss = 4.649, (2.497 sec/step)
# step 422 - trloss = 4.748, (2.498 sec/step)
# step 423 - trloss = 4.714, (2.496 sec/step)
# step 424 - trloss = 4.774, (2.496 sec/step)
# step 425 - trloss = 4.759, (2.496 sec/step)
# step 426 - trloss = 4.648, (2.495 sec/step)
# step 427 - trloss = 4.619, (2.498 sec/step)
# step 428 - trloss = 4.804, (2.495 sec/step)
# step 429 - trloss = 4.680, (2.496 sec/step)
# step 430 - trloss = 4.683, (2.497 sec/step)
# step 431 - trloss = 4.785, (2.497 sec/step)
# step 432 - trloss = 4.728, (2.498 sec/step)
# step 433 - trloss = 4.700, (2.497 sec/step)
# step 434 - trloss = 4.768, (2.499 sec/step)
# step 435 - trloss = 4.745, (2.498 sec/step)
# step 436 - trloss = 4.718, (2.497 sec/step)
# step 437 - trloss = 4.764, (2.499 sec/step)
# step 438 - trloss = 4.710, (2.499 sec/step)
# step 439 - trloss = 4.753, (2.498 sec/step)
# step 440 - trloss = 4.686, (2.500 sec/step)
# step 441 - trloss = 4.719, (2.499 sec/step)
# step 442 - trloss = 4.645, (2.500 sec/step)
# step 443 - trloss = 4.622, (2.499 sec/step)
# step 444 - trloss = 4.772, (2.499 sec/step)
# step 445 - trloss = 4.609, (2.499 sec/step)
# step 446 - trloss = 4.629, (2.501 sec/step)
# step 447 - trloss = 4.644, (2.498 sec/step)
# step 448 - trloss = 4.644, (2.499 sec/step)
# step 449 - trloss = 4.649, (2.500 sec/step)
# step 450 - trloss = 4.645, (2.501 sec/step)
# stored done
# validateLoss = 4.640, (2.501 sec/step)
# step 451 - trloss = 4.622, (2.499 sec/step)
# step 452 - trloss = 4.684, (2.499 sec/step)
# step 453 - trloss = 4.703, (2.499 sec/step)
# step 454 - trloss = 4.752, (2.499 sec/step)
# step 455 - trloss = 4.642, (2.500 sec/step)
# step 456 - trloss = 4.721, (2.500 sec/step)
# step 457 - trloss = 4.702, (2.500 sec/step)
# step 458 - trloss = 4.763, (2.499 sec/step)
# step 459 - trloss = 4.757, (2.501 sec/step)
# step 460 - trloss = 4.647, (2.500 sec/step)
# step 461 - trloss = 4.593, (2.500 sec/step)
# step 462 - trloss = 4.779, (2.501 sec/step)
# step 463 - trloss = 4.669, (2.500 sec/step)
# step 464 - trloss = 4.653, (2.502 sec/step)
# step 465 - trloss = 4.793, (2.501 sec/step)
# step 466 - trloss = 4.709, (2.511 sec/step)
# step 467 - trloss = 4.688, (2.501 sec/step)
# step 468 - trloss = 4.735, (2.501 sec/step)
# step 469 - trloss = 4.726, (2.500 sec/step)
# step 470 - trloss = 4.696, (2.500 sec/step)
# step 471 - trloss = 4.736, (2.500 sec/step)
# step 472 - trloss = 4.707, (2.500 sec/step)
# step 473 - trloss = 4.754, (2.499 sec/step)
# step 474 - trloss = 4.658, (2.500 sec/step)
# step 475 - trloss = 4.702, (2.500 sec/step)
# step 476 - trloss = 4.623, (2.500 sec/step)
# step 477 - trloss = 4.598, (2.500 sec/step)
# step 478 - trloss = 4.757, (2.498 sec/step)
# step 479 - trloss = 4.591, (2.500 sec/step)
# step 480 - trloss = 4.617, (2.498 sec/step)
# step 481 - trloss = 4.614, (2.499 sec/step)
# step 482 - trloss = 4.619, (2.499 sec/step)
# step 483 - trloss = 4.631, (2.501 sec/step)
# step 484 - trloss = 4.614, (2.500 sec/step)
# step 485 - trloss = 4.609, (2.501 sec/step)
# step 486 - trloss = 4.642, (2.500 sec/step)
# step 487 - trloss = 4.691, (2.501 sec/step)
# step 488 - trloss = 4.722, (2.500 sec/step)
# step 489 - trloss = 4.633, (2.501 sec/step)
# step 490 - trloss = 4.705, (2.501 sec/step)
# step 491 - trloss = 4.690, (2.501 sec/step)
# step 492 - trloss = 4.735, (2.501 sec/step)
# step 493 - trloss = 4.731, (2.501 sec/step)
# step 494 - trloss = 4.653, (2.501 sec/step)
# step 495 - trloss = 4.578, (2.501 sec/step)
# step 496 - trloss = 4.758, (2.500 sec/step)
# step 497 - trloss = 4.664, (2.501 sec/step)
# step 498 - trloss = 4.644, (2.500 sec/step)
# step 499 - trloss = 4.765, (2.502 sec/step)
# step 500 - trloss = 4.697, (2.501 sec/step)
# stored done
# validateLoss = 4.791, (2.501 sec/step)
# step 501 - trloss = 4.686, (2.501 sec/step)
# step 502 - trloss = 4.730, (2.501 sec/step)
# step 503 - trloss = 4.709, (2.499 sec/step)
# step 504 - trloss = 4.689, (2.500 sec/step)
# step 505 - trloss = 4.725, (2.500 sec/step)
# step 506 - trloss = 4.672, (2.498 sec/step)
# step 507 - trloss = 4.729, (2.500 sec/step)
# step 508 - trloss = 4.669, (2.500 sec/step)
# step 509 - trloss = 4.699, (2.500 sec/step)
# step 510 - trloss = 4.631, (2.501 sec/step)
# step 511 - trloss = 4.590, (2.501 sec/step)
# step 512 - trloss = 4.726, (2.501 sec/step)
# step 513 - trloss = 4.581, (2.500 sec/step)
# step 514 - trloss = 4.602, (2.501 sec/step)
# step 515 - trloss = 4.595, (2.499 sec/step)
# step 516 - trloss = 4.591, (2.500 sec/step)
# step 517 - trloss = 4.597, (2.500 sec/step)
# step 518 - trloss = 4.605, (2.501 sec/step)
# step 519 - trloss = 4.601, (2.501 sec/step)
# step 520 - trloss = 4.619, (2.500 sec/step)
# step 521 - trloss = 4.680, (2.499 sec/step)
# step 522 - trloss = 4.713, (2.501 sec/step)
# step 523 - trloss = 4.605, (2.501 sec/step)
# step 524 - trloss = 4.679, (2.499 sec/step)
# step 525 - trloss = 4.673, (2.499 sec/step)
# step 526 - trloss = 4.735, (2.498 sec/step)
# step 527 - trloss = 4.770, (2.499 sec/step)
# step 528 - trloss = 4.629, (2.499 sec/step)
# step 529 - trloss = 4.579, (2.499 sec/step)
# step 530 - trloss = 4.805, (2.499 sec/step)
# step 531 - trloss = 4.657, (2.499 sec/step)
# step 532 - trloss = 4.668, (2.498 sec/step)
# step 533 - trloss = 4.789, (2.498 sec/step)
# step 534 - trloss = 4.705, (2.498 sec/step)
# step 535 - trloss = 4.693, (2.505 sec/step)
# step 536 - trloss = 4.729, (2.498 sec/step)
# step 537 - trloss = 4.719, (2.497 sec/step)
# step 538 - trloss = 4.689, (2.498 sec/step)
# step 539 - trloss = 4.731, (2.496 sec/step)
# step 540 - trloss = 4.694, (2.496 sec/step)
# step 541 - trloss = 4.754, (2.497 sec/step)
# step 542 - trloss = 4.653, (2.497 sec/step)
# step 543 - trloss = 4.680, (2.497 sec/step)
# step 544 - trloss = 4.625, (2.496 sec/step)
# step 545 - trloss = 4.611, (2.497 sec/step)
# step 546 - trloss = 4.756, (2.497 sec/step)
# step 547 - trloss = 4.576, (2.498 sec/step)
# step 548 - trloss = 4.612, (2.497 sec/step)
# step 549 - trloss = 4.603, (2.498 sec/step)
# step 550 - trloss = 4.613, (2.498 sec/step)
# stored done
# validateLoss = 4.656, (2.498 sec/step)
# step 551 - trloss = 4.617, (2.498 sec/step)
# step 552 - trloss = 4.607, (2.498 sec/step)
# step 553 - trloss = 4.609, (2.498 sec/step)
# step 554 - trloss = 4.624, (2.499 sec/step)
# step 555 - trloss = 4.656, (2.498 sec/step)
# step 556 - trloss = 4.704, (2.496 sec/step)
# step 557 - trloss = 4.618, (2.497 sec/step)
# step 558 - trloss = 4.667, (2.498 sec/step)
# step 559 - trloss = 4.670, (2.499 sec/step)
# step 560 - trloss = 4.697, (2.499 sec/step)
# step 561 - trloss = 4.690, (2.500 sec/step)
# step 562 - trloss = 4.662, (2.500 sec/step)
# step 563 - trloss = 4.563, (2.500 sec/step)
# step 564 - trloss = 4.750, (2.499 sec/step)
# step 565 - trloss = 4.656, (2.501 sec/step)
# step 566 - trloss = 4.618, (2.500 sec/step)
# step 567 - trloss = 4.750, (2.499 sec/step)
# step 568 - trloss = 4.680, (2.500 sec/step)
# step 569 - trloss = 4.676, (2.498 sec/step)
# step 570 - trloss = 4.705, (2.499 sec/step)
# step 571 - trloss = 4.688, (2.500 sec/step)
# step 572 - trloss = 4.660, (2.500 sec/step)
# step 573 - trloss = 4.712, (2.498 sec/step)
# step 574 - trloss = 4.649, (2.500 sec/step)
# step 575 - trloss = 4.703, (2.498 sec/step)
# step 576 - trloss = 4.641, (2.497 sec/step)
# step 577 - trloss = 4.674, (2.498 sec/step)
# step 578 - trloss = 4.580, (2.499 sec/step)
# step 579 - trloss = 4.564, (2.500 sec/step)
# step 580 - trloss = 4.684, (2.499 sec/step)
# step 581 - trloss = 4.552, (2.501 sec/step)
# step 582 - trloss = 4.560, (2.500 sec/step)
# step 583 - trloss = 4.562, (2.501 sec/step)
# step 584 - trloss = 4.567, (2.501 sec/step)
# step 585 - trloss = 4.573, (2.500 sec/step)
# step 586 - trloss = 4.557, (2.501 sec/step)
# step 587 - trloss = 4.572, (2.502 sec/step)
# step 588 - trloss = 4.593, (2.502 sec/step)
# step 589 - trloss = 4.648, (2.502 sec/step)
# step 590 - trloss = 4.674, (2.502 sec/step)
# step 591 - trloss = 4.595, (2.502 sec/step)
# step 592 - trloss = 4.623, (2.503 sec/step)
# step 593 - trloss = 4.659, (2.503 sec/step)
# step 594 - trloss = 4.683, (2.501 sec/step)
# step 595 - trloss = 4.769, (2.502 sec/step)
# step 596 - trloss = 4.626, (2.501 sec/step)
# step 597 - trloss = 4.563, (2.502 sec/step)
# step 598 - trloss = 4.777, (2.501 sec/step)
# step 599 - trloss = 4.667, (2.504 sec/step)
# step 600 - trloss = 4.634, (2.500 sec/step)
# stored done
# validateLoss = 4.739, (2.500 sec/step)
# step 601 - trloss = 4.747, (2.501 sec/step)
# step 602 - trloss = 4.711, (2.501 sec/step)
# step 603 - trloss = 4.667, (2.502 sec/step)
# step 604 - trloss = 4.696, (2.502 sec/step)
# step 605 - trloss = 4.701, (2.501 sec/step)
# step 606 - trloss = 4.664, (2.500 sec/step)
# step 607 - trloss = 4.712, (2.500 sec/step)
# step 608 - trloss = 4.660, (2.499 sec/step)
# step 609 - trloss = 4.725, (2.499 sec/step)
# step 610 - trloss = 4.627, (2.501 sec/step)
# step 611 - trloss = 4.654, (2.502 sec/step)
# step 612 - trloss = 4.593, (2.500 sec/step)
# step 613 - trloss = 4.584, (2.499 sec/step)
# step 614 - trloss = 4.715, (2.501 sec/step)
# step 615 - trloss = 4.549, (2.501 sec/step)
# step 616 - trloss = 4.565, (2.500 sec/step)
# step 617 - trloss = 4.580, (2.502 sec/step)
# step 618 - trloss = 4.606, (2.501 sec/step)
# step 619 - trloss = 4.588, (2.500 sec/step)
# step 620 - trloss = 4.565, (2.500 sec/step)
# step 621 - trloss = 4.565, (2.499 sec/step)
# step 622 - trloss = 4.592, (2.501 sec/step)
# step 623 - trloss = 4.624, (2.499 sec/step)
# step 624 - trloss = 4.658, (2.500 sec/step)
# step 625 - trloss = 4.584, (2.499 sec/step)
# step 626 - trloss = 4.627, (2.499 sec/step)
# step 627 - trloss = 4.653, (2.498 sec/step)
# step 628 - trloss = 4.689, (2.498 sec/step)
# step 629 - trloss = 4.663, (2.497 sec/step)
# step 630 - trloss = 4.633, (2.498 sec/step)
# step 631 - trloss = 4.538, (2.498 sec/step)
# step 632 - trloss = 4.738, (2.498 sec/step)
# step 633 - trloss = 4.627, (2.498 sec/step)
# step 634 - trloss = 4.599, (2.498 sec/step)
# step 635 - trloss = 4.720, (2.499 sec/step)
# step 636 - trloss = 4.668, (2.498 sec/step)
# step 637 - trloss = 4.681, (2.498 sec/step)
# step 638 - trloss = 4.688, (2.500 sec/step)
# step 639 - trloss = 4.678, (2.497 sec/step)
# step 640 - trloss = 4.643, (2.498 sec/step)
# step 641 - trloss = 4.684, (2.498 sec/step)
# step 642 - trloss = 4.646, (2.498 sec/step)
# step 643 - trloss = 4.703, (2.498 sec/step)
# step 644 - trloss = 4.624, (2.498 sec/step)
# step 645 - trloss = 4.676, (2.497 sec/step)
# step 646 - trloss = 4.555, (2.497 sec/step)
# step 647 - trloss = 4.543, (2.497 sec/step)
# step 648 - trloss = 4.662, (2.497 sec/step)
# step 649 - trloss = 4.524, (2.495 sec/step)
# step 650 - trloss = 4.535, (2.497 sec/step)
# stored done
# validateLoss = 4.746, (2.497 sec/step)
# step 651 - trloss = 4.540, (2.497 sec/step)
# step 652 - trloss = 4.561, (2.496 sec/step)
# step 653 - trloss = 4.573, (2.494 sec/step)
# step 654 - trloss = 4.540, (2.496 sec/step)
# step 655 - trloss = 4.536, (2.497 sec/step)
# step 656 - trloss = 4.569, (2.496 sec/step)
# step 657 - trloss = 4.611, (2.496 sec/step)
# step 658 - trloss = 4.645, (2.496 sec/step)
# step 659 - trloss = 4.563, (2.496 sec/step)
# step 660 - trloss = 4.592, (2.495 sec/step)
# step 661 - trloss = 4.627, (2.496 sec/step)
# step 662 - trloss = 4.670, (2.497 sec/step)
# step 663 - trloss = 4.689, (2.496 sec/step)
# step 664 - trloss = 4.600, (2.497 sec/step)
# step 665 - trloss = 4.531, (2.496 sec/step)
# step 666 - trloss = 4.739, (2.497 sec/step)
# step 667 - trloss = 4.617, (2.497 sec/step)
# step 668 - trloss = 4.578, (2.497 sec/step)
# step 669 - trloss = 4.716, (2.497 sec/step)
# step 670 - trloss = 4.675, (2.496 sec/step)
# step 671 - trloss = 4.627, (2.497 sec/step)
# step 672 - trloss = 4.674, (2.497 sec/step)
# step 673 - trloss = 4.668, (2.498 sec/step)
# step 674 - trloss = 4.619, (2.498 sec/step)
# step 675 - trloss = 4.697, (2.497 sec/step)
# step 676 - trloss = 4.622, (2.497 sec/step)
# step 677 - trloss = 4.664, (2.496 sec/step)
# step 678 - trloss = 4.635, (2.498 sec/step)
# step 679 - trloss = 4.637, (2.494 sec/step)
# step 680 - trloss = 4.554, (2.498 sec/step)
# step 681 - trloss = 4.554, (2.498 sec/step)
# step 682 - trloss = 4.655, (2.498 sec/step)
# step 683 - trloss = 4.540, (2.498 sec/step)
# step 684 - trloss = 4.533, (2.497 sec/step)
# step 685 - trloss = 4.546, (2.500 sec/step)
# step 686 - trloss = 4.545, (2.508 sec/step)
# step 687 - trloss = 4.567, (2.497 sec/step)
# step 688 - trloss = 4.524, (2.500 sec/step)
# step 689 - trloss = 4.534, (2.500 sec/step)
# step 690 - trloss = 4.570, (2.500 sec/step)
# step 691 - trloss = 4.600, (2.499 sec/step)
# step 692 - trloss = 4.637, (2.498 sec/step)
# step 693 - trloss = 4.555, (2.499 sec/step)
# step 694 - trloss = 4.567, (2.500 sec/step)
# step 695 - trloss = 4.626, (2.499 sec/step)
# step 696 - trloss = 4.665, (2.498 sec/step)
# step 697 - trloss = 4.683, (2.498 sec/step)
# step 698 - trloss = 4.584, (2.500 sec/step)
# step 699 - trloss = 4.537, (2.500 sec/step)
# step 700 - trloss = 4.734, (2.500 sec/step)
# stored done
# validateLoss = 4.615, (2.500 sec/step)
# step 701 - trloss = 4.646, (2.498 sec/step)
# step 702 - trloss = 4.598, (2.501 sec/step)
# step 703 - trloss = 4.704, (2.498 sec/step)
# step 704 - trloss = 4.672, (2.500 sec/step)
# step 705 - trloss = 4.646, (2.498 sec/step)
# step 706 - trloss = 4.669, (2.498 sec/step)
# step 707 - trloss = 4.661, (2.499 sec/step)
# step 708 - trloss = 4.623, (2.498 sec/step)
# step 709 - trloss = 4.663, (2.497 sec/step)
# step 710 - trloss = 4.646, (2.496 sec/step)
# step 711 - trloss = 4.685, (2.496 sec/step)
# step 712 - trloss = 4.611, (2.496 sec/step)
# step 713 - trloss = 4.652, (2.495 sec/step)
# step 714 - trloss = 4.543, (2.496 sec/step)
# step 715 - trloss = 4.542, (2.497 sec/step)
# step 716 - trloss = 4.636, (2.496 sec/step)
# step 717 - trloss = 4.548, (2.495 sec/step)
# step 718 - trloss = 4.535, (2.496 sec/step)
# step 719 - trloss = 4.540, (2.496 sec/step)
# step 720 - trloss = 4.542, (2.495 sec/step)
# step 721 - trloss = 4.559, (2.495 sec/step)
# step 722 - trloss = 4.511, (2.496 sec/step)
# step 723 - trloss = 4.532, (2.496 sec/step)
# step 724 - trloss = 4.566, (2.496 sec/step)
# step 725 - trloss = 4.603, (2.495 sec/step)
# step 726 - trloss = 4.628, (2.495 sec/step)
# step 727 - trloss = 4.569, (2.495 sec/step)
# step 728 - trloss = 4.567, (2.494 sec/step)
# step 729 - trloss = 4.614, (2.494 sec/step)
# step 730 - trloss = 4.659, (2.495 sec/step)
# step 731 - trloss = 4.672, (2.495 sec/step)
# step 732 - trloss = 4.577, (2.495 sec/step)
# step 733 - trloss = 4.538, (2.496 sec/step)
# step 734 - trloss = 4.744, (2.496 sec/step)
# step 735 - trloss = 4.631, (2.498 sec/step)
# step 736 - trloss = 4.607, (2.497 sec/step)
# step 737 - trloss = 4.685, (2.499 sec/step)
# step 738 - trloss = 4.674, (2.498 sec/step)
# step 739 - trloss = 4.649, (2.499 sec/step)
# step 740 - trloss = 4.675, (2.497 sec/step)
# step 741 - trloss = 4.678, (2.500 sec/step)
# step 742 - trloss = 4.620, (2.500 sec/step)
# step 743 - trloss = 4.676, (2.499 sec/step)
# step 744 - trloss = 4.625, (2.499 sec/step)
# step 745 - trloss = 4.697, (2.499 sec/step)
# step 746 - trloss = 4.574, (2.499 sec/step)
# step 747 - trloss = 4.639, (2.500 sec/step)
# step 748 - trloss = 4.571, (2.500 sec/step)
# step 749 - trloss = 4.527, (2.500 sec/step)
# step 750 - trloss = 4.635, (2.500 sec/step)
# stored done
# validateLoss = 4.681, (2.500 sec/step)
# step 751 - trloss = 4.535, (2.499 sec/step)
# step 752 - trloss = 4.528, (2.498 sec/step)
# step 753 - trloss = 4.537, (2.499 sec/step)
# step 754 - trloss = 4.523, (2.497 sec/step)
# step 755 - trloss = 4.562, (2.500 sec/step)
# step 756 - trloss = 4.503, (2.498 sec/step)
# step 757 - trloss = 4.542, (2.498 sec/step)
# step 758 - trloss = 4.556, (2.498 sec/step)
# step 759 - trloss = 4.616, (2.498 sec/step)
# step 760 - trloss = 4.622, (2.499 sec/step)
# step 761 - trloss = 4.557, (2.499 sec/step)
# step 762 - trloss = 4.555, (2.499 sec/step)
# step 763 - trloss = 4.635, (2.498 sec/step)
# step 764 - trloss = 4.655, (2.499 sec/step)
# step 765 - trloss = 4.689, (2.499 sec/step)
# step 766 - trloss = 4.581, (2.498 sec/step)
# step 767 - trloss = 4.536, (2.498 sec/step)
# step 768 - trloss = 4.761, (2.498 sec/step)
# step 769 - trloss = 4.608, (2.498 sec/step)
# step 770 - trloss = 4.604, (2.497 sec/step)
# step 771 - trloss = 4.727, (2.498 sec/step)
# step 772 - trloss = 4.696, (2.499 sec/step)
# step 773 - trloss = 4.644, (2.498 sec/step)
# step 774 - trloss = 4.697, (2.498 sec/step)
# step 775 - trloss = 4.677, (2.497 sec/step)
# step 776 - trloss = 4.645, (2.497 sec/step)
# step 777 - trloss = 4.684, (2.498 sec/step)
# step 778 - trloss = 4.621, (2.498 sec/step)
# step 779 - trloss = 4.702, (2.499 sec/step)
# step 780 - trloss = 4.593, (2.497 sec/step)
# step 781 - trloss = 4.663, (2.498 sec/step)
# step 782 - trloss = 4.619, (2.512 sec/step)
# step 783 - trloss = 4.550, (2.497 sec/step)
# step 784 - trloss = 4.670, (2.499 sec/step)
# step 785 - trloss = 4.513, (2.499 sec/step)
# step 786 - trloss = 4.534, (2.499 sec/step)
# step 787 - trloss = 4.553, (2.498 sec/step)
# step 788 - trloss = 4.561, (2.496 sec/step)
# step 789 - trloss = 4.564, (2.498 sec/step)
# step 790 - trloss = 4.505, (2.497 sec/step)
# step 791 - trloss = 4.564, (2.502 sec/step)
# step 792 - trloss = 4.556, (2.508 sec/step)
# step 793 - trloss = 4.589, (2.496 sec/step)
# step 794 - trloss = 4.629, (2.496 sec/step)
# step 795 - trloss = 4.558, (2.496 sec/step)
# step 796 - trloss = 4.562, (2.495 sec/step)
# step 797 - trloss = 4.614, (2.495 sec/step)
# step 798 - trloss = 4.657, (2.495 sec/step)
# step 799 - trloss = 4.644, (2.495 sec/step)
# step 800 - trloss = 4.563, (2.496 sec/step)
# stored done
# validateLoss = 4.684, (2.496 sec/step)
# step 801 - trloss = 4.505, (2.498 sec/step)
# step 802 - trloss = 4.739, (2.509 sec/step)
# step 803 - trloss = 4.601, (2.496 sec/step)
# step 804 - trloss = 4.551, (2.496 sec/step)
# step 805 - trloss = 4.701, (2.496 sec/step)
# step 806 - trloss = 4.652, (2.496 sec/step)
# step 807 - trloss = 4.646, (2.498 sec/step)
# step 808 - trloss = 4.660, (2.497 sec/step)
# step 809 - trloss = 4.653, (2.499 sec/step)
# step 810 - trloss = 4.616, (2.498 sec/step)
# step 811 - trloss = 4.674, (2.499 sec/step)
# step 812 - trloss = 4.618, (2.500 sec/step)
# step 813 - trloss = 4.673, (2.499 sec/step)
# step 814 - trloss = 4.575, (2.500 sec/step)
# step 815 - trloss = 4.633, (2.499 sec/step)
# step 816 - trloss = 4.530, (2.499 sec/step)
# step 817 - trloss = 4.503, (2.501 sec/step)
# step 818 - trloss = 4.596, (2.500 sec/step)
# step 819 - trloss = 4.477, (2.502 sec/step)
# step 820 - trloss = 4.497, (2.501 sec/step)
# step 821 - trloss = 4.494, (2.499 sec/step)
# step 822 - trloss = 4.511, (2.502 sec/step)
# step 823 - trloss = 4.537, (2.501 sec/step)
# step 824 - trloss = 4.475, (2.501 sec/step)
# step 825 - trloss = 4.497, (2.499 sec/step)
# step 826 - trloss = 4.529, (2.501 sec/step)
# step 827 - trloss = 4.565, (2.502 sec/step)
# step 828 - trloss = 4.595, (2.503 sec/step)
# step 829 - trloss = 4.533, (2.500 sec/step)
# step 830 - trloss = 4.532, (2.500 sec/step)
# step 831 - trloss = 4.652, (2.502 sec/step)
# step 832 - trloss = 4.622, (2.501 sec/step)
# step 833 - trloss = 4.680, (2.502 sec/step)
# step 834 - trloss = 4.564, (2.510 sec/step)
# step 835 - trloss = 4.522, (2.503 sec/step)
# step 836 - trloss = 4.795, (2.502 sec/step)
# step 837 - trloss = 4.594, (2.501 sec/step)
# step 838 - trloss = 4.602, (2.502 sec/step)
# step 839 - trloss = 4.699, (2.502 sec/step)
# step 840 - trloss = 4.660, (2.501 sec/step)
# step 841 - trloss = 4.695, (2.502 sec/step)
# step 842 - trloss = 4.676, (2.506 sec/step)
# step 843 - trloss = 4.655, (2.501 sec/step)
# step 844 - trloss = 4.602, (2.501 sec/step)
# step 845 - trloss = 4.666, (2.501 sec/step)
# step 846 - trloss = 4.600, (2.501 sec/step)
# step 847 - trloss = 4.683, (2.501 sec/step)
# step 848 - trloss = 4.560, (2.501 sec/step)
# step 849 - trloss = 4.611, (2.500 sec/step)
# step 850 - trloss = 4.589, (2.499 sec/step)
# stored done
# validateLoss = 4.696, (2.499 sec/step)
# step 851 - trloss = 4.529, (2.500 sec/step)
# step 852 - trloss = 4.674, (2.500 sec/step)
# step 853 - trloss = 4.491, (2.499 sec/step)
# step 854 - trloss = 4.516, (2.498 sec/step)
# step 855 - trloss = 4.514, (2.498 sec/step)
# step 856 - trloss = 4.503, (2.499 sec/step)
# step 857 - trloss = 4.551, (2.496 sec/step)
# step 858 - trloss = 4.468, (2.497 sec/step)
# step 859 - trloss = 4.490, (2.498 sec/step)
# step 860 - trloss = 4.542, (2.498 sec/step)
# step 861 - trloss = 4.566, (2.496 sec/step)
# step 862 - trloss = 4.603, (2.497 sec/step)
# step 863 - trloss = 4.548, (2.497 sec/step)
# step 864 - trloss = 4.518, (2.497 sec/step)
# step 865 - trloss = 4.601, (2.497 sec/step)
# step 866 - trloss = 4.651, (2.495 sec/step)
# step 867 - trloss = 4.604, (2.496 sec/step)
# step 868 - trloss = 4.552, (2.496 sec/step)
# step 869 - trloss = 4.506, (2.495 sec/step)
# step 870 - trloss = 4.711, (2.495 sec/step)
# step 871 - trloss = 4.593, (2.495 sec/step)
# step 872 - trloss = 4.543, (2.497 sec/step)
# step 873 - trloss = 4.680, (2.497 sec/step)
# step 874 - trloss = 4.672, (2.497 sec/step)
# step 875 - trloss = 4.615, (2.497 sec/step)
# step 876 - trloss = 4.662, (2.498 sec/step)
# step 877 - trloss = 4.673, (2.499 sec/step)
# step 878 - trloss = 4.594, (2.498 sec/step)
# step 879 - trloss = 4.640, (2.497 sec/step)
# step 880 - trloss = 4.593, (2.500 sec/step)
# step 881 - trloss = 4.659, (2.500 sec/step)
# step 882 - trloss = 4.547, (2.502 sec/step)
# step 883 - trloss = 4.599, (2.501 sec/step)
# step 884 - trloss = 4.558, (2.500 sec/step)
# step 885 - trloss = 4.519, (2.502 sec/step)
# step 886 - trloss = 4.628, (2.502 sec/step)
# step 887 - trloss = 4.493, (2.502 sec/step)
# step 888 - trloss = 4.486, (2.502 sec/step)
# step 889 - trloss = 4.511, (2.503 sec/step)
# step 890 - trloss = 4.485, (2.505 sec/step)
# step 891 - trloss = 4.512, (2.502 sec/step)
# step 892 - trloss = 4.447, (2.502 sec/step)
# step 893 - trloss = 4.488, (2.502 sec/step)
# step 894 - trloss = 4.512, (2.502 sec/step)
# step 895 - trloss = 4.535, (2.503 sec/step)
# step 896 - trloss = 4.562, (2.502 sec/step)
# step 897 - trloss = 4.518, (2.502 sec/step)
# step 898 - trloss = 4.494, (2.502 sec/step)
# step 899 - trloss = 4.589, (2.502 sec/step)
# step 900 - trloss = 4.614, (2.502 sec/step)
# stored done
# validateLoss = 4.579, (2.502 sec/step)
# step 901 - trloss = 4.570, (2.502 sec/step)
# step 902 - trloss = 4.536, (2.501 sec/step)
# step 903 - trloss = 4.487, (2.500 sec/step)
# step 904 - trloss = 4.721, (2.501 sec/step)
# step 905 - trloss = 4.588, (2.501 sec/step)
# step 906 - trloss = 4.540, (2.502 sec/step)
# step 907 - trloss = 4.680, (2.500 sec/step)
# step 908 - trloss = 4.689, (2.499 sec/step)
# step 909 - trloss = 4.609, (2.500 sec/step)
# step 910 - trloss = 4.651, (2.501 sec/step)
# step 911 - trloss = 4.673, (2.500 sec/step)
# step 912 - trloss = 4.606, (2.501 sec/step)
# step 913 - trloss = 4.625, (2.499 sec/step)
# step 914 - trloss = 4.566, (2.501 sec/step)
# step 915 - trloss = 4.639, (2.500 sec/step)
# step 916 - trloss = 4.532, (2.500 sec/step)
# step 917 - trloss = 4.575, (2.501 sec/step)
# step 918 - trloss = 4.510, (2.500 sec/step)
# step 919 - trloss = 4.491, (2.501 sec/step)
# step 920 - trloss = 4.649, (2.500 sec/step)
# step 921 - trloss = 4.464, (2.501 sec/step)
# step 922 - trloss = 4.461, (2.501 sec/step)
# step 923 - trloss = 4.485, (2.501 sec/step)
# step 924 - trloss = 4.483, (2.500 sec/step)
# step 925 - trloss = 4.515, (2.500 sec/step)
# step 926 - trloss = 4.426, (2.501 sec/step)
# step 927 - trloss = 4.469, (2.500 sec/step)
# step 928 - trloss = 4.505, (2.500 sec/step)
# step 929 - trloss = 4.522, (2.500 sec/step)
# step 930 - trloss = 4.549, (2.499 sec/step)
# step 931 - trloss = 4.516, (2.500 sec/step)
# step 932 - trloss = 4.489, (2.500 sec/step)
# step 933 - trloss = 4.577, (2.500 sec/step)
# step 934 - trloss = 4.594, (2.500 sec/step)
# step 935 - trloss = 4.555, (2.500 sec/step)
# step 936 - trloss = 4.544, (2.499 sec/step)
# step 937 - trloss = 4.478, (2.499 sec/step)
# step 938 - trloss = 4.694, (2.500 sec/step)
# step 939 - trloss = 4.566, (2.500 sec/step)
# step 940 - trloss = 4.521, (2.499 sec/step)
# step 941 - trloss = 4.649, (2.498 sec/step)
# step 942 - trloss = 4.624, (2.499 sec/step)
# step 943 - trloss = 4.601, (2.498 sec/step)
# step 944 - trloss = 4.640, (2.499 sec/step)
# step 945 - trloss = 4.631, (2.499 sec/step)
# step 946 - trloss = 4.576, (2.499 sec/step)
# step 947 - trloss = 4.596, (2.498 sec/step)
# step 948 - trloss = 4.534, (2.498 sec/step)
# step 949 - trloss = 4.595, (2.498 sec/step)
# step 950 - trloss = 4.511, (2.498 sec/step)
# stored done
# validateLoss = 4.810, (2.498 sec/step)
# step 951 - trloss = 4.565, (2.498 sec/step)
# step 952 - trloss = 4.484, (2.498 sec/step)
# step 953 - trloss = 4.451, (2.499 sec/step)
# step 954 - trloss = 4.551, (2.498 sec/step)
# step 955 - trloss = 4.436, (2.499 sec/step)
# step 956 - trloss = 4.441, (2.497 sec/step)
# step 957 - trloss = 4.467, (2.499 sec/step)
# step 958 - trloss = 4.455, (2.499 sec/step)
# step 959 - trloss = 4.506, (2.508 sec/step)
# step 960 - trloss = 4.398, (2.498 sec/step)
# step 961 - trloss = 4.453, (2.497 sec/step)
# step 962 - trloss = 4.496, (2.501 sec/step)
# step 963 - trloss = 4.525, (2.497 sec/step)
# step 964 - trloss = 4.549, (2.497 sec/step)
# step 965 - trloss = 4.496, (2.498 sec/step)
# step 966 - trloss = 4.476, (2.500 sec/step)
# step 967 - trloss = 4.565, (2.499 sec/step)
# step 968 - trloss = 4.611, (2.499 sec/step)
# step 969 - trloss = 4.546, (2.499 sec/step)
# step 970 - trloss = 4.496, (2.500 sec/step)
# step 971 - trloss = 4.458, (2.500 sec/step)
# step 972 - trloss = 4.670, (2.500 sec/step)
# step 973 - trloss = 4.552, (2.501 sec/step)
# step 974 - trloss = 4.506, (2.500 sec/step)
# step 975 - trloss = 4.623, (2.501 sec/step)
# step 976 - trloss = 4.598, (2.502 sec/step)
# step 977 - trloss = 4.591, (2.501 sec/step)
# step 978 - trloss = 4.629, (2.502 sec/step)
# step 979 - trloss = 4.600, (2.503 sec/step)
# step 980 - trloss = 4.558, (2.503 sec/step)
# step 981 - trloss = 4.602, (2.501 sec/step)
# step 982 - trloss = 4.505, (2.503 sec/step)
# step 983 - trloss = 4.583, (2.503 sec/step)
# step 984 - trloss = 4.506, (2.502 sec/step)
# step 985 - trloss = 4.540, (2.503 sec/step)
# step 986 - trloss = 4.461, (2.504 sec/step)
# step 987 - trloss = 4.442, (2.503 sec/step)
# step 988 - trloss = 4.538, (2.501 sec/step)
# step 989 - trloss = 4.438, (2.503 sec/step)
# step 990 - trloss = 4.422, (2.501 sec/step)
# step 991 - trloss = 4.446, (2.502 sec/step)
# step 992 - trloss = 4.437, (2.511 sec/step)
# step 993 - trloss = 4.500, (2.503 sec/step)
# step 994 - trloss = 4.383, (2.501 sec/step)
# step 995 - trloss = 4.424, (2.501 sec/step)
# step 996 - trloss = 4.472, (2.500 sec/step)
# step 997 - trloss = 4.508, (2.499 sec/step)
# step 998 - trloss = 4.528, (2.500 sec/step)
# step 999 - trloss = 4.517, (2.500 sec/step)
# step 1000 - trloss = 4.489, (2.499 sec/step)
# stored done
# validateLoss = 4.607, (2.499 sec/step)
# step 1001 - trloss = 4.561, (2.498 sec/step)
# step 1002 - trloss = 4.618, (2.499 sec/step)
# step 1003 - trloss = 4.532, (2.498 sec/step)
# step 1004 - trloss = 4.496, (2.497 sec/step)
# step 1005 - trloss = 4.475, (2.498 sec/step)
# step 1006 - trloss = 4.667, (2.495 sec/step)
# step 1007 - trloss = 4.561, (2.496 sec/step)
# step 1008 - trloss = 4.499, (2.496 sec/step)
# step 1009 - trloss = 4.637, (2.498 sec/step)
# step 1010 - trloss = 4.590, (2.496 sec/step)
# step 1011 - trloss = 4.583, (2.496 sec/step)
# step 1012 - trloss = 4.636, (2.497 sec/step)
# step 1013 - trloss = 4.630, (2.495 sec/step)
# step 1014 - trloss = 4.566, (2.497 sec/step)
# step 1015 - trloss = 4.682, (2.497 sec/step)
# step 1016 - trloss = 4.531, (2.496 sec/step)
# step 1017 - trloss = 4.582, (2.498 sec/step)
# step 1018 - trloss = 4.553, (2.498 sec/step)
# step 1019 - trloss = 4.572, (2.497 sec/step)
# step 1020 - trloss = 4.452, (2.498 sec/step)
# step 1021 - trloss = 4.454, (2.498 sec/step)
# step 1022 - trloss = 4.546, (2.501 sec/step)
# step 1023 - trloss = 4.466, (2.499 sec/step)
# step 1024 - trloss = 4.421, (2.499 sec/step)
# step 1025 - trloss = 4.458, (2.498 sec/step)
# step 1026 - trloss = 4.437, (2.498 sec/step)
# step 1027 - trloss = 4.510, (2.500 sec/step)
# step 1028 - trloss = 4.396, (2.499 sec/step)
# step 1029 - trloss = 4.428, (2.499 sec/step)
# step 1030 - trloss = 4.478, (2.500 sec/step)
# step 1031 - trloss = 4.528, (2.500 sec/step)
# step 1032 - trloss = 4.534, (2.498 sec/step)
# step 1033 - trloss = 4.515, (2.501 sec/step)
# step 1034 - trloss = 4.481, (2.500 sec/step)
# step 1035 - trloss = 4.544, (2.500 sec/step)
# step 1036 - trloss = 4.596, (2.499 sec/step)
# step 1037 - trloss = 4.540, (2.499 sec/step)
# step 1038 - trloss = 4.487, (2.500 sec/step)
# step 1039 - trloss = 4.465, (2.500 sec/step)
# step 1040 - trloss = 4.682, (2.502 sec/step)
# step 1041 - trloss = 4.544, (2.500 sec/step)
# step 1042 - trloss = 4.491, (2.502 sec/step)
# step 1043 - trloss = 4.624, (2.501 sec/step)
# step 1044 - trloss = 4.591, (2.498 sec/step)
# step 1045 - trloss = 4.574, (2.500 sec/step)
# step 1046 - trloss = 4.619, (2.500 sec/step)
# step 1047 - trloss = 4.606, (2.500 sec/step)
# step 1048 - trloss = 4.559, (2.498 sec/step)
# step 1049 - trloss = 4.584, (2.499 sec/step)
# step 1050 - trloss = 4.573, (2.497 sec/step)
# stored done
# validateLoss = 4.706, (2.497 sec/step)
# step 1051 - trloss = 4.629, (2.499 sec/step)
# step 1052 - trloss = 4.508, (2.497 sec/step)
# step 1053 - trloss = 4.622, (2.498 sec/step)
# step 1054 - trloss = 4.492, (2.498 sec/step)
# step 1055 - trloss = 4.445, (2.498 sec/step)
# step 1056 - trloss = 4.583, (2.498 sec/step)
# step 1057 - trloss = 4.481, (2.497 sec/step)
# step 1058 - trloss = 4.432, (2.497 sec/step)
# step 1059 - trloss = 4.482, (2.495 sec/step)
# step 1060 - trloss = 4.446, (2.498 sec/step)
# step 1061 - trloss = 4.505, (2.495 sec/step)
# step 1062 - trloss = 4.406, (2.495 sec/step)
# step 1063 - trloss = 4.438, (2.495 sec/step)
# step 1064 - trloss = 4.462, (2.496 sec/step)
# step 1065 - trloss = 4.512, (2.496 sec/step)
# step 1066 - trloss = 4.554, (2.496 sec/step)
# step 1067 - trloss = 4.496, (2.497 sec/step)
# step 1068 - trloss = 4.450, (2.496 sec/step)
# step 1069 - trloss = 4.606, (2.497 sec/step)
# step 1070 - trloss = 4.571, (2.496 sec/step)
# step 1071 - trloss = 4.606, (2.497 sec/step)
# step 1072 - trloss = 4.508, (2.497 sec/step)
# step 1073 - trloss = 4.476, (2.495 sec/step)
# step 1074 - trloss = 4.760, (2.497 sec/step)
# step 1075 - trloss = 4.561, (2.496 sec/step)
# step 1076 - trloss = 4.536, (2.496 sec/step)
# step 1077 - trloss = 4.654, (2.497 sec/step)
# step 1078 - trloss = 4.624, (2.497 sec/step)
# step 1079 - trloss = 4.600, (2.496 sec/step)
# step 1080 - trloss = 4.641, (2.496 sec/step)
# step 1081 - trloss = 4.660, (2.496 sec/step)
# step 1082 - trloss = 4.568, (2.496 sec/step)
# step 1083 - trloss = 4.657, (2.497 sec/step)
# step 1084 - trloss = 4.598, (2.497 sec/step)
# step 1085 - trloss = 4.627, (2.495 sec/step)
# step 1086 - trloss = 4.539, (2.497 sec/step)
# step 1087 - trloss = 4.589, (2.496 sec/step)
# step 1088 - trloss = 4.497, (2.497 sec/step)
# step 1089 - trloss = 4.487, (2.498 sec/step)
# step 1090 - trloss = 4.638, (2.496 sec/step)
# step 1091 - trloss = 4.439, (2.498 sec/step)
# step 1092 - trloss = 4.455, (2.497 sec/step)
# step 1093 - trloss = 4.482, (2.499 sec/step)
# step 1094 - trloss = 4.479, (2.498 sec/step)
# step 1095 - trloss = 4.513, (2.498 sec/step)
# step 1096 - trloss = 4.408, (2.499 sec/step)
# step 1097 - trloss = 4.470, (2.498 sec/step)
# step 1098 - trloss = 4.511, (2.499 sec/step)
# step 1099 - trloss = 4.498, (2.499 sec/step)
# step 1100 - trloss = 4.545, (2.498 sec/step)
# stored done
# validateLoss = 4.651, (2.498 sec/step)
# step 1101 - trloss = 4.509, (2.499 sec/step)
# step 1102 - trloss = 4.464, (2.498 sec/step)
# step 1103 - trloss = 4.578, (2.498 sec/step)
# step 1104 - trloss = 4.586, (2.498 sec/step)
# step 1105 - trloss = 4.528, (2.498 sec/step)
# step 1106 - trloss = 4.489, (2.498 sec/step)
# step 1107 - trloss = 4.470, (2.496 sec/step)
# step 1108 - trloss = 4.684, (2.495 sec/step)
# step 1109 - trloss = 4.550, (2.495 sec/step)
# step 1110 - trloss = 4.508, (2.495 sec/step)
# step 1111 - trloss = 4.654, (2.497 sec/step)
# step 1112 - trloss = 4.638, (2.498 sec/step)
# step 1113 - trloss = 4.578, (2.498 sec/step)
# step 1114 - trloss = 4.618, (2.498 sec/step)
# step 1115 - trloss = 4.614, (2.498 sec/step)
# step 1116 - trloss = 4.589, (2.499 sec/step)
# step 1117 - trloss = 4.599, (2.500 sec/step)
# step 1118 - trloss = 4.524, (2.499 sec/step)
# step 1119 - trloss = 4.634, (2.499 sec/step)
# step 1120 - trloss = 4.494, (2.498 sec/step)
# step 1121 - trloss = 4.532, (2.499 sec/step)
# step 1122 - trloss = 4.460, (2.500 sec/step)
# step 1123 - trloss = 4.443, (2.499 sec/step)
# step 1124 - trloss = 4.622, (2.499 sec/step)
# step 1125 - trloss = 4.409, (2.500 sec/step)
# step 1126 - trloss = 4.429, (2.500 sec/step)
# step 1127 - trloss = 4.454, (2.499 sec/step)
# step 1128 - trloss = 4.444, (2.500 sec/step)
# step 1129 - trloss = 4.491, (2.501 sec/step)
# step 1130 - trloss = 4.407, (2.499 sec/step)
# step 1131 - trloss = 4.454, (2.502 sec/step)
# step 1132 - trloss = 4.481, (2.501 sec/step)
# step 1133 - trloss = 4.501, (2.508 sec/step)
# step 1134 - trloss = 4.535, (2.501 sec/step)
# step 1135 - trloss = 4.504, (2.500 sec/step)
# step 1136 - trloss = 4.458, (2.501 sec/step)
# step 1137 - trloss = 4.548, (2.501 sec/step)
# step 1138 - trloss = 4.563, (2.499 sec/step)
# step 1139 - trloss = 4.531, (2.500 sec/step)
# step 1140 - trloss = 4.471, (2.501 sec/step)
# step 1141 - trloss = 4.454, (2.500 sec/step)
# step 1142 - trloss = 4.648, (2.499 sec/step)
# step 1143 - trloss = 4.518, (2.500 sec/step)
# step 1144 - trloss = 4.476, (2.499 sec/step)
# step 1145 - trloss = 4.619, (2.499 sec/step)
# step 1146 - trloss = 4.613, (2.499 sec/step)
# step 1147 - trloss = 4.577, (2.498 sec/step)
# step 1148 - trloss = 4.618, (2.498 sec/step)
# step 1149 - trloss = 4.617, (2.496 sec/step)
# step 1150 - trloss = 4.547, (2.498 sec/step)
# stored done
# validateLoss = 4.672, (2.498 sec/step)
# step 1151 - trloss = 4.590, (2.497 sec/step)
# step 1152 - trloss = 4.529, (2.498 sec/step)
# step 1153 - trloss = 4.573, (2.496 sec/step)
# step 1154 - trloss = 4.496, (2.497 sec/step)
# step 1155 - trloss = 4.542, (2.497 sec/step)
# step 1156 - trloss = 4.436, (2.496 sec/step)
# step 1157 - trloss = 4.416, (2.496 sec/step)
# step 1158 - trloss = 4.544, (2.495 sec/step)
# step 1159 - trloss = 4.411, (2.494 sec/step)
# step 1160 - trloss = 4.394, (2.495 sec/step)
# step 1161 - trloss = 4.425, (2.494 sec/step)
# step 1162 - trloss = 4.412, (2.495 sec/step)
# step 1163 - trloss = 4.478, (2.495 sec/step)
# step 1164 - trloss = 4.365, (2.495 sec/step)
# step 1165 - trloss = 4.414, (2.496 sec/step)
# step 1166 - trloss = 4.442, (2.497 sec/step)
# step 1167 - trloss = 4.480, (2.497 sec/step)
# step 1168 - trloss = 4.516, (2.495 sec/step)
# step 1169 - trloss = 4.483, (2.497 sec/step)
# step 1170 - trloss = 4.425, (2.498 sec/step)
# step 1171 - trloss = 4.525, (2.497 sec/step)
# step 1172 - trloss = 4.529, (2.498 sec/step)
# step 1173 - trloss = 4.495, (2.499 sec/step)
# step 1174 - trloss = 4.443, (2.498 sec/step)
# step 1175 - trloss = 4.438, (2.499 sec/step)
# step 1176 - trloss = 4.635, (2.499 sec/step)
# step 1177 - trloss = 4.507, (2.498 sec/step)
# step 1178 - trloss = 4.456, (2.499 sec/step)
# step 1179 - trloss = 4.601, (2.499 sec/step)
# step 1180 - trloss = 4.589, (2.499 sec/step)
# step 1181 - trloss = 4.572, (2.499 sec/step)
# step 1182 - trloss = 4.590, (2.500 sec/step)
# step 1183 - trloss = 4.580, (2.499 sec/step)
# step 1184 - trloss = 4.533, (2.498 sec/step)
# step 1185 - trloss = 4.575, (2.500 sec/step)
# step 1186 - trloss = 4.501, (2.499 sec/step)
# step 1187 - trloss = 4.584, (2.499 sec/step)
# step 1188 - trloss = 4.478, (2.500 sec/step)
# step 1189 - trloss = 4.535, (2.499 sec/step)
# step 1190 - trloss = 4.401, (2.498 sec/step)
# step 1191 - trloss = 4.401, (2.499 sec/step)
# step 1192 - trloss = 4.503, (2.498 sec/step)
# step 1193 - trloss = 4.395, (2.498 sec/step)
# step 1194 - trloss = 4.374, (2.500 sec/step)
# step 1195 - trloss = 4.398, (2.499 sec/step)
# step 1196 - trloss = 4.373, (2.499 sec/step)
# step 1197 - trloss = 4.455, (2.500 sec/step)
# step 1198 - trloss = 4.346, (2.497 sec/step)
# step 1199 - trloss = 4.400, (2.498 sec/step)
# step 1200 - trloss = 4.429, (2.499 sec/step)
# stored done
# validateLoss = 4.828, (2.499 sec/step)
# step 1201 - trloss = 4.474, (2.500 sec/step)
# step 1202 - trloss = 4.497, (2.499 sec/step)
# step 1203 - trloss = 4.456, (2.499 sec/step)
# step 1204 - trloss = 4.421, (2.498 sec/step)
# step 1205 - trloss = 4.523, (2.500 sec/step)
# step 1206 - trloss = 4.531, (2.498 sec/step)
# step 1207 - trloss = 4.497, (2.497 sec/step)
# step 1208 - trloss = 4.441, (2.497 sec/step)
# step 1209 - trloss = 4.433, (2.496 sec/step)
# step 1210 - trloss = 4.640, (2.496 sec/step)
# step 1211 - trloss = 4.498, (2.496 sec/step)
# step 1212 - trloss = 4.459, (2.496 sec/step)
# step 1213 - trloss = 4.581, (2.497 sec/step)
# step 1214 - trloss = 4.565, (2.498 sec/step)
# step 1215 - trloss = 4.533, (2.499 sec/step)
# step 1216 - trloss = 4.587, (2.497 sec/step)
# step 1217 - trloss = 4.568, (2.498 sec/step)
# step 1218 - trloss = 4.515, (2.499 sec/step)
# step 1219 - trloss = 4.565, (2.499 sec/step)
# step 1220 - trloss = 4.469, (2.501 sec/step)
# step 1221 - trloss = 4.550, (2.500 sec/step)
# step 1222 - trloss = 4.477, (2.498 sec/step)
# step 1223 - trloss = 4.499, (2.499 sec/step)
# step 1224 - trloss = 4.400, (2.500 sec/step)
# step 1225 - trloss = 4.399, (2.499 sec/step)
# step 1226 - trloss = 4.488, (2.498 sec/step)
# step 1227 - trloss = 4.382, (2.499 sec/step)
# step 1228 - trloss = 4.367, (2.499 sec/step)
# step 1229 - trloss = 4.401, (2.498 sec/step)
# step 1230 - trloss = 4.375, (2.499 sec/step)
# step 1231 - trloss = 4.450, (2.498 sec/step)
# step 1232 - trloss = 4.346, (2.500 sec/step)
# step 1233 - trloss = 4.395, (2.499 sec/step)
# step 1234 - trloss = 4.415, (2.498 sec/step)
# step 1235 - trloss = 4.469, (2.499 sec/step)
# step 1236 - trloss = 4.503, (2.500 sec/step)
# step 1237 - trloss = 4.442, (2.500 sec/step)
# step 1238 - trloss = 4.413, (2.501 sec/step)
# step 1239 - trloss = 4.540, (2.499 sec/step)
# step 1240 - trloss = 4.534, (2.500 sec/step)
# step 1241 - trloss = 4.533, (2.500 sec/step)
# step 1242 - trloss = 4.449, (2.501 sec/step)
# step 1243 - trloss = 4.459, (2.500 sec/step)
# step 1244 - trloss = 4.653, (2.499 sec/step)
# step 1245 - trloss = 4.517, (2.500 sec/step)
# step 1246 - trloss = 4.465, (2.499 sec/step)
# step 1247 - trloss = 4.589, (2.499 sec/step)
# step 1248 - trloss = 4.588, (2.500 sec/step)
# step 1249 - trloss = 4.588, (2.500 sec/step)
# step 1250 - trloss = 4.598, (2.500 sec/step)
# stored done
# validateLoss = 4.709, (2.500 sec/step)
# step 1251 - trloss = 4.580, (2.501 sec/step)
# step 1252 - trloss = 4.534, (2.500 sec/step)
# step 1253 - trloss = 4.563, (2.497 sec/step)
# step 1254 - trloss = 4.493, (2.498 sec/step)
# step 1255 - trloss = 4.560, (2.499 sec/step)
# step 1256 - trloss = 4.490, (2.499 sec/step)
# step 1257 - trloss = 4.522, (2.497 sec/step)
# step 1258 - trloss = 4.429, (2.499 sec/step)
# step 1259 - trloss = 4.407, (2.501 sec/step)
# step 1260 - trloss = 4.546, (2.500 sec/step)
# step 1261 - trloss = 4.398, (2.500 sec/step)
# step 1262 - trloss = 4.388, (2.499 sec/step)
# step 1263 - trloss = 4.424, (2.499 sec/step)
# step 1264 - trloss = 4.415, (2.497 sec/step)
# step 1265 - trloss = 4.477, (2.498 sec/step)
# step 1266 - trloss = 4.375, (2.499 sec/step)
# step 1267 - trloss = 4.402, (2.498 sec/step)
# step 1268 - trloss = 4.430, (2.509 sec/step)
# step 1269 - trloss = 4.468, (2.500 sec/step)
# step 1270 - trloss = 4.518, (2.499 sec/step)
# step 1271 - trloss = 4.467, (2.499 sec/step)
# step 1272 - trloss = 4.423, (2.498 sec/step)
# step 1273 - trloss = 4.510, (2.498 sec/step)
# step 1274 - trloss = 4.557, (2.500 sec/step)
# step 1275 - trloss = 4.504, (2.498 sec/step)
# step 1276 - trloss = 4.477, (2.499 sec/step)
# step 1277 - trloss = 4.473, (2.500 sec/step)
# step 1278 - trloss = 4.727, (2.502 sec/step)
# step 1279 - trloss = 4.519, (2.499 sec/step)
# step 1280 - trloss = 4.483, (2.500 sec/step)
# step 1281 - trloss = 4.619, (2.500 sec/step)
# step 1282 - trloss = 4.591, (2.501 sec/step)
# step 1283 - trloss = 4.554, (2.498 sec/step)
# step 1284 - trloss = 4.616, (2.501 sec/step)
# step 1285 - trloss = 4.606, (2.501 sec/step)
# step 1286 - trloss = 4.522, (2.499 sec/step)
# step 1287 - trloss = 4.578, (2.502 sec/step)
# step 1288 - trloss = 4.518, (2.499 sec/step)
# step 1289 - trloss = 4.571, (2.500 sec/step)
# step 1290 - trloss = 4.485, (2.500 sec/step)
# step 1291 - trloss = 4.527, (2.500 sec/step)
# step 1292 - trloss = 4.425, (2.500 sec/step)
# step 1293 - trloss = 4.404, (2.499 sec/step)
# step 1294 - trloss = 4.526, (2.499 sec/step)
# step 1295 - trloss = 4.404, (2.500 sec/step)
# step 1296 - trloss = 4.383, (2.498 sec/step)
# step 1297 - trloss = 4.412, (2.500 sec/step)
# step 1298 - trloss = 4.395, (2.498 sec/step)
# step 1299 - trloss = 4.459, (2.499 sec/step)
# step 1300 - trloss = 4.351, (2.497 sec/step)
# stored done
# validateLoss = 4.591, (2.497 sec/step)
# step 1301 - trloss = 4.423, (2.499 sec/step)
# step 1302 - trloss = 4.442, (2.499 sec/step)
# step 1303 - trloss = 4.459, (2.498 sec/step)
# step 1304 - trloss = 4.508, (2.497 sec/step)
# step 1305 - trloss = 4.464, (2.497 sec/step)
# step 1306 - trloss = 4.424, (2.498 sec/step)
# step 1307 - trloss = 4.533, (2.497 sec/step)
# step 1308 - trloss = 4.539, (2.496 sec/step)
# step 1309 - trloss = 4.566, (2.497 sec/step)
# step 1310 - trloss = 4.443, (2.499 sec/step)
# step 1311 - trloss = 4.441, (2.498 sec/step)
# step 1312 - trloss = 4.662, (2.497 sec/step)
# step 1313 - trloss = 4.565, (2.499 sec/step)
# step 1314 - trloss = 4.459, (2.498 sec/step)
# step 1315 - trloss = 4.623, (2.499 sec/step)
# step 1316 - trloss = 4.634, (2.500 sec/step)
# step 1317 - trloss = 4.563, (2.499 sec/step)
# step 1318 - trloss = 4.597, (2.500 sec/step)
# step 1319 - trloss = 4.651, (2.501 sec/step)
# step 1320 - trloss = 4.564, (2.500 sec/step)
# step 1321 - trloss = 4.561, (2.502 sec/step)
# step 1322 - trloss = 4.519, (2.502 sec/step)
# step 1323 - trloss = 4.627, (2.501 sec/step)
# step 1324 - trloss = 4.498, (2.501 sec/step)
# step 1325 - trloss = 4.548, (2.500 sec/step)
# step 1326 - trloss = 4.425, (2.502 sec/step)
# step 1327 - trloss = 4.423, (2.500 sec/step)
# step 1328 - trloss = 4.565, (2.502 sec/step)
# step 1329 - trloss = 4.402, (2.502 sec/step)
# step 1330 - trloss = 4.395, (2.501 sec/step)
# step 1331 - trloss = 4.422, (2.500 sec/step)
# step 1332 - trloss = 4.424, (2.501 sec/step)
# step 1333 - trloss = 4.473, (2.503 sec/step)
# step 1334 - trloss = 4.362, (2.501 sec/step)
# step 1335 - trloss = 4.410, (2.501 sec/step)
# step 1336 - trloss = 4.447, (2.501 sec/step)
# step 1337 - trloss = 4.462, (2.502 sec/step)
# step 1338 - trloss = 4.516, (2.502 sec/step)
# step 1339 - trloss = 4.481, (2.501 sec/step)
# step 1340 - trloss = 4.424, (2.501 sec/step)
# step 1341 - trloss = 4.544, (2.501 sec/step)
# step 1342 - trloss = 4.511, (2.500 sec/step)
# step 1343 - trloss = 4.510, (2.501 sec/step)
# step 1344 - trloss = 4.447, (2.501 sec/step)
# step 1345 - trloss = 4.468, (2.499 sec/step)
# step 1346 - trloss = 4.656, (2.500 sec/step)
# step 1347 - trloss = 4.548, (2.501 sec/step)
# step 1348 - trloss = 4.496, (2.500 sec/step)
# step 1349 - trloss = 4.658, (2.502 sec/step)
# step 1350 - trloss = 4.626, (2.499 sec/step)
# stored done

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = bytes("<stripped %d bytes>"%max_const_size, 'utf-8')
                
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph().as_graph_def())
