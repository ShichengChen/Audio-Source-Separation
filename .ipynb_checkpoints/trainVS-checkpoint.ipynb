# %%
#import scipy
#rate,data = scipy.io.wavfile.read('./vocalSeparation/origin_mix.wav')
#scipy.io.wavfile.write('./vocalSeparation/morigin_mix.wav',rate,data)

# %%
#import soundfile as sf
#data, samplerate = sf.read('./vocalSeparation/pred_mix.wav', dtype='float32')
#data = librosa.resample(data.T, samplerate, 16000)

# %%
"""Training script for the WaveNet network on the VCTK corpus.

This script trains a network with the WaveNet using data from the VCTK corpus,
which can be freely downloaded at the following site (~10 GB):
http://homepages.inf.ed.ac.uk/jyamagis/page3/page58/page58.html
"""

from __future__ import print_function

import argparse
from datetime import datetime
import json
import os
import sys
import time
import numpy as np
import tensorflow as tf
from tensorflow.python.client import timeline
import soundfile as sf

from wavenetVS import WaveNetModel, AudioReader, optimizer_factory


'''import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"'''
# Out:
# 'import os\nos.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"\nos.environ["CUDA_VISIBLE_DEVICES"] = "0"'

# %%
BATCH_SIZE = 1
DATA_DIRECTORY = './vsCorpus'
LOGDIR_ROOT = './logdirVS'
CHECKPOINT_EVERY = 50
NUM_STEPS = int(1e4)
LEARNING_RATE = 1e-3
L2_REGULARIZATION_STRENGTH = 1e-5
WAVENET_PARAMS = './wavenet_params.json'
STARTED_DATESTRING = "{0:%Y-%m-%dT%H-%M-%S}".format(datetime.now())
SAMPLE_SIZE = 100000
#SILENCE_THRESHOLD = 0.3
SILENCE_THRESHOLD = 0
EPSILON = 0.001
MOMENTUM = 0.9
MAX_TO_KEEP = 5
METADATA = False

# %%
def get_arguments():
    def _str_to_bool(s):
        """Convert string to bool (in argparse context)."""
        if s.lower() not in ['true', 'false']:
            raise ValueError('Argument needs to be a '
                             'boolean, got {}'.format(s))
        return {'true': True, 'false': False}[s.lower()]

    parser = argparse.ArgumentParser(description='WaveNet example network')
    parser.add_argument('--batch_size', type=int, default=BATCH_SIZE,
                        help='How many wav files to process at once. Default: ' + str(BATCH_SIZE) + '.')
    parser.add_argument('--data_dir', type=str, default=DATA_DIRECTORY,
                        help='The directory containing the VCTK corpus.')
    parser.add_argument('--store_metadata', type=bool, default=METADATA,
                        help='Whether to store advanced debugging information '
                        '(execution time, memory consumption) for use with '
                        'TensorBoard. Default: ' + str(METADATA) + '.')
    parser.add_argument('--logdir', type=str, default=None,
                        help='Directory in which to store the logging '
                        'information for TensorBoard. '
                        'If the model already exists, it will restore '
                        'the state and will continue training. '
                        'Cannot use with --logdir_root and --restore_from.')
    parser.add_argument('--logdir_root', type=str, default=None,
                        help='Root directory to place the logging '
                        'output and generated model. These are stored '
                        'under the dated subdirectory of --logdir_root. '
                        'Cannot use with --logdir.')
    parser.add_argument('--restore_from', type=str, default=None,
                        help='Directory in which to restore the model from. '
                        'This creates the new model under the dated directory '
                        'in --logdir_root. '
                        'Cannot use with --logdir.')
    parser.add_argument('--checkpoint_every', type=int,
                        default=CHECKPOINT_EVERY,
                        help='How many steps to save each checkpoint after. Default: ' + str(CHECKPOINT_EVERY) + '.')
    parser.add_argument('--num_steps', type=int, default=NUM_STEPS,
                        help='Number of training steps. Default: ' + str(NUM_STEPS) + '.')
    parser.add_argument('--learning_rate', type=float, default=LEARNING_RATE,
                        help='Learning rate for training. Default: ' + str(LEARNING_RATE) + '.')
    parser.add_argument('--wavenet_params', type=str, default=WAVENET_PARAMS,
                        help='JSON file with the network parameters. Default: ' + WAVENET_PARAMS + '.')
    parser.add_argument('--sample_size', type=int, default=SAMPLE_SIZE,
                        help='Concatenate and cut audio samples to this many '
                        'samples. Default: ' + str(SAMPLE_SIZE) + '.')
    parser.add_argument('--l2_regularization_strength', type=float,
                        default=L2_REGULARIZATION_STRENGTH,
                        help='Coefficient in the L2 regularization. '
                        'Default: False')
    parser.add_argument('--silence_threshold', type=float,
                        default=SILENCE_THRESHOLD,
                        help='Volume threshold below which to trim the start '
                        'and the end from the training set samples. Default: ' + str(SILENCE_THRESHOLD) + '.')
    parser.add_argument('--optimizer', type=str, default='adam',
                        choices=optimizer_factory.keys(),
                        help='Select the optimizer specified by this option. Default: adam.')
    parser.add_argument('--momentum', type=float,
                        default=MOMENTUM, help='Specify the momentum to be '
                        'used by sgd or rmsprop optimizer. Ignored by the '
                        'adam optimizer. Default: ' + str(MOMENTUM) + '.')
    parser.add_argument('--histograms', type=_str_to_bool, default=False,
                        help='Whether to store histogram summaries. Default: False')
    parser.add_argument('--gc_channels', type=int, default=None,
                        help='Number of global condition channels. Default: None. Expecting: Int')
    parser.add_argument('--max_checkpoints', type=int, default=MAX_TO_KEEP,
                        help='Maximum amount of checkpoints that will be kept alive. Default: '
                             + str(MAX_TO_KEEP) + '.')
    return parser.parse_args([])

# %%
def save(saver, sess, logdir, step):
    model_name = 'model.ckpt'
    checkpoint_path = os.path.join(logdir, model_name)
    print('Storing checkpoint to {} ...'.format(logdir), end="")
    sys.stdout.flush()

    if not os.path.exists(logdir):
        os.makedirs(logdir)

    saver.save(sess, checkpoint_path, global_step=step)
    print(' Done.')

# %%
def load(saver, sess, logdir):
    print("Trying to restore saved checkpoints from {} ...".format(logdir),
          end="")

    ckpt = tf.train.get_checkpoint_state(logdir)
    if ckpt:
        print("  Checkpoint found: {}".format(ckpt.model_checkpoint_path))
        global_step = int(ckpt.model_checkpoint_path
                          .split('/')[-1]
                          .split('-')[-1])
        print("  Global step was: {}".format(global_step))
        print("  Restoring...", end="")
        saver.restore(sess, ckpt.model_checkpoint_path)
        print(" Done.")
        return global_step
    else:
        print(" No checkpoint found.")
        return None

# %%
def get_default_logdir(logdir_root):
    logdir = os.path.join(logdir_root, 'train', STARTED_DATESTRING)
    return logdir


def validate_directories(args):
    """Validate and arrange directory related arguments."""

    # Validation
    if args.logdir and args.logdir_root:
        raise ValueError("--logdir and --logdir_root cannot be "
                         "specified at the same time.")

    if args.logdir and args.restore_from:
        raise ValueError(
            "--logdir and --restore_from cannot be specified at the same "
            "time. This is to keep your previous model from unexpected "
            "overwrites.\n"
            "Use --logdir_root to specify the root of the directory which "
            "will be automatically created with current date and time, or use "
            "only --logdir to just continue the training from the last "
            "checkpoint.")

    # Arrangement
    logdir_root = args.logdir_root
    if logdir_root is None:
        logdir_root = LOGDIR_ROOT

    logdir = args.logdir
    if logdir is None:
        logdir = get_default_logdir(logdir_root)
        print('Using default logdir: {}'.format(logdir))

    restore_from = args.restore_from
    if restore_from is None:
        # args.logdir and args.restore_from are exclusive,
        # so it is guaranteed the logdir here is newly created.
        restore_from = logdir

    return {
        'logdir': logdir,
        'logdir_root': args.logdir_root,
        'restore_from': restore_from
    }

# %%
args = get_arguments()

try:
    directories = validate_directories(args)
except ValueError as e:
    print("Some arguments are wrong:")
    print(str(e))

logdir = directories['logdir']
restore_from = directories['restore_from']

# Even if we restored the model, we will treat it as new training
# if the trained model is written into an arbitrary location.
is_overwritten_training = logdir != restore_from

with open(args.wavenet_params, 'r') as f:
    wavenet_params = json.load(f)

# Create coordinator.
coord = tf.train.Coordinator()

# Load raw waveform from VCTK corpus.
with tf.name_scope('create_inputs'):
    # Allow silence trimming to be skipped by specifying a threshold near
    # zero.
    silence_threshold = args.silence_threshold if args.silence_threshold > \
                                                  EPSILON else None
    gc_enabled = args.gc_channels is not None
    reader = AudioReader(
        args.data_dir,
        coord,
        sample_rate=wavenet_params['sample_rate'],   #"sample_rate": 16000,
        gc_enabled=gc_enabled,
        receptive_field=WaveNetModel.calculate_receptive_field(wavenet_params["filter_width"],
                                                               wavenet_params["dilations"],
                                                               wavenet_params["scalar_input"],
                                                               wavenet_params["initial_filter_width"]),
        sample_size=args.sample_size,  #SAMPLE_SIZE = 100000
        silence_threshold=silence_threshold)
    traudio_batch = reader.trdequeue(args.batch_size)  #BATCH_SIZE = 1
    if gc_enabled:
        ##TODO train and val
        gc_id_batch = reader.dequeue_gc(args.batch_size)
    else:
        gc_id_batch = None

# Create network.
net = WaveNetModel(
    batch_size=args.batch_size,
    dilations=wavenet_params["dilations"],
    filter_width=wavenet_params["filter_width"],
    residual_channels=wavenet_params["residual_channels"],
    dilation_channels=wavenet_params["dilation_channels"],
    skip_channels=wavenet_params["skip_channels"],
    quantization_channels=wavenet_params["quantization_channels"],
    use_biases=wavenet_params["use_biases"],
    scalar_input=wavenet_params["scalar_input"],
    initial_filter_width=wavenet_params["initial_filter_width"],
    histograms=args.histograms,
    global_condition_channels=args.gc_channels,
    global_condition_cardinality=reader.gc_category_cardinality)

if args.l2_regularization_strength == 0:
    args.l2_regularization_strength = None
trloss = net.trloss(input_batch=traudio_batch,
                global_condition_batch=gc_id_batch,
                l2_regularization_strength=args.l2_regularization_strength)
optimizer = optimizer_factory[args.optimizer](
                learning_rate=args.learning_rate,
                momentum=args.momentum)
trainable = tf.trainable_variables()
optim = optimizer.minimize(trloss, var_list=trainable)

# Set up logging for TensorBoard.
writer = tf.summary.FileWriter(logdir)
writer.add_graph(tf.get_default_graph())
run_metadata = tf.RunMetadata()
summaries = tf.summary.merge_all()

# Set up session
config = tf.ConfigProto(log_device_placement=False)
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
#sess = tf.Session(config=tf.ConfigProto(log_device_placement=False))

vaudio_batch = reader.valbatch()
valloss = net.valloss(input_batch=vaudio_batch,
                global_condition_batch=gc_id_batch,
                l2_regularization_strength=args.l2_regularization_strength)
genfile = net.generateFile(input_batch=vaudio_batch,
                global_condition_batch=gc_id_batch,
                l2_regularization_strength=args.l2_regularization_strength)

init = tf.global_variables_initializer()
sess.run(init)

# Saver for storing checkpoints of the model.
saver = tf.train.Saver(var_list=tf.trainable_variables(), max_to_keep=args.max_checkpoints)

try:
    saved_global_step = load(saver, sess, restore_from)
    if is_overwritten_training or saved_global_step is None:
        # The first training step will be saved_global_step + 1,
        # therefore we put -1 here for new or overwritten trainings.
        saved_global_step = -1

except:
    print("Something went wrong while restoring checkpoint. "
          "We will terminate training to avoid accidentally overwriting "
          "the previous model.")
    raise

    
    
threads = tf.train.start_queue_runners(sess=sess, coord=coord)
reader.start_threads(sess)


step = None
last_saved_step = saved_global_step
minvalloss = 10000
try:
    for step in range(saved_global_step + 1, args.num_steps):
        start_time = time.time()
        if args.store_metadata and step % 50 == 0:
            # Slow run that stores extra information for debugging.
            print('Storing metadata')
            run_options = tf.RunOptions(
                trace_level=tf.RunOptions.FULL_TRACE)
            summary, trloss_value, _ = sess.run(
                [summaries, trloss, optim],
                options=run_options,
                run_metadata=run_metadata)
            writer.add_summary(summary, step)
            writer.add_run_metadata(run_metadata,
                                    'step_{:04d}'.format(step))
            tl = timeline.Timeline(run_metadata.step_stats)
            timeline_path = os.path.join(logdir, 'timeline.trace')
            with open(timeline_path, 'w') as f:
                f.write(tl.generate_chrome_trace_format(show_memory=True))
        else:
            summary, trloss_value, _ = sess.run([summaries, trloss, optim])
            writer.add_summary(summary, step)
        duration = time.time() - start_time
        print('step {:d} - trloss = {:.3f}, ({:.3f} sec/step)'
              .format(step, trloss_value, duration))
        
        
        if step % args.checkpoint_every == 0:
            ans = sess.run(genfile)
            #print(ans.shape)
            sf.write('./vsCorpus/ans/'+str(step)+'.wav',ans.reshape(-1),16000)
            print('stored done')
            valloss_value = sess.run(valloss)
            print('validateLoss = {:.3f}, ({:.3f} sec/step)'
              .format(valloss_value, time.time() - start_time))
            #if(valloss_value < minvalloss):
                #save(saver, sess, logdir, step)
                #last_saved_step = step
                #minvalloss = valloss_value

except KeyboardInterrupt:
    # Introduce a line break after ^C is displayed so save message
    # is on its own line.
    print()
finally:
    if step > last_saved_step:
        save(saver, sess, logdir, step)
    coord.request_stop()
    coord.join(threads)
# Out:
# Using default logdir: ./logdirVS/train/2018-06-06T00-08-54
# trdequeue
# val ['./vsCorpus/pred_mix.wav', './vsCorpus/pred_vocal.wav']
# raw_output Tensor("wavenet_2/postprocessing/Add_1:0", shape=(?, ?, 256), dtype=float32)
# ans0 (?,)
# Trying to restore saved checkpoints from ./logdirVS/train/2018-06-06T00-08-54 ... No checkpoint found.
# step 0 - trloss = 5.702, (18.824 sec/step)
# stored done
# validateLoss = 5.624, (18.824 sec/step)
# step 1 - trloss = 5.667, (2.497 sec/step)
# step 2 - trloss = 5.637, (2.487 sec/step)
# step 3 - trloss = 5.608, (2.487 sec/step)
# step 4 - trloss = 5.583, (2.488 sec/step)
# step 5 - trloss = 5.560, (2.487 sec/step)
# step 6 - trloss = 5.542, (2.487 sec/step)
# step 7 - trloss = 5.525, (2.489 sec/step)
# step 8 - trloss = 5.512, (2.499 sec/step)
# step 9 - trloss = 5.497, (2.495 sec/step)
# step 10 - trloss = 5.488, (2.495 sec/step)
# step 11 - trloss = 5.477, (2.494 sec/step)
# step 12 - trloss = 5.468, (2.500 sec/step)
# step 13 - trloss = 5.461, (2.496 sec/step)
# step 14 - trloss = 5.449, (2.497 sec/step)
# step 15 - trloss = 5.450, (2.506 sec/step)
# step 16 - trloss = 5.432, (2.497 sec/step)
# step 17 - trloss = 5.443, (2.497 sec/step)
# step 18 - trloss = 5.417, (2.497 sec/step)
# step 19 - trloss = 5.438, (2.498 sec/step)
# step 20 - trloss = 5.401, (2.498 sec/step)
# step 21 - trloss = 5.434, (2.509 sec/step)
# step 22 - trloss = 5.384, (2.498 sec/step)
# step 23 - trloss = 5.430, (2.498 sec/step)
# step 24 - trloss = 5.368, (2.497 sec/step)
# step 25 - trloss = 5.425, (2.498 sec/step)
# step 26 - trloss = 5.355, (2.495 sec/step)
# step 27 - trloss = 5.422, (2.497 sec/step)
# step 28 - trloss = 5.348, (2.508 sec/step)
# step 29 - trloss = 5.413, (2.499 sec/step)
# step 30 - trloss = 5.346, (2.500 sec/step)
# step 31 - trloss = 5.427, (2.498 sec/step)
# step 32 - trloss = 5.361, (2.498 sec/step)
# step 33 - trloss = 5.426, (2.497 sec/step)
# step 34 - trloss = 5.350, (2.496 sec/step)
# step 35 - trloss = 5.418, (2.497 sec/step)
# step 36 - trloss = 5.346, (2.506 sec/step)
# step 37 - trloss = 5.417, (2.497 sec/step)
# step 38 - trloss = 5.336, (2.497 sec/step)
# step 39 - trloss = 5.406, (2.496 sec/step)
# step 40 - trloss = 5.319, (2.497 sec/step)
# step 41 - trloss = 5.392, (2.496 sec/step)
# step 42 - trloss = 5.311, (2.508 sec/step)
# step 43 - trloss = 5.389, (2.498 sec/step)
# step 44 - trloss = 5.289, (2.499 sec/step)
# step 45 - trloss = 5.373, (2.501 sec/step)
# step 46 - trloss = 5.267, (2.499 sec/step)
# step 47 - trloss = 5.339, (2.498 sec/step)
# step 48 - trloss = 5.257, (2.498 sec/step)
# step 49 - trloss = 5.311, (2.500 sec/step)
# step 50 - trloss = 5.219, (2.499 sec/step)
# stored done
# validateLoss = 5.391, (2.499 sec/step)
# step 51 - trloss = 5.315, (2.513 sec/step)
# step 52 - trloss = 5.204, (2.499 sec/step)
# step 53 - trloss = 5.257, (2.498 sec/step)
# step 54 - trloss = 5.168, (2.502 sec/step)
# step 55 - trloss = 5.258, (2.500 sec/step)
# step 56 - trloss = 5.185, (2.498 sec/step)
# step 57 - trloss = 5.226, (2.499 sec/step)
# step 58 - trloss = 5.135, (2.500 sec/step)
# step 59 - trloss = 5.229, (2.502 sec/step)
# step 60 - trloss = 5.144, (2.501 sec/step)
# step 61 - trloss = 5.206, (2.501 sec/step)
# step 62 - trloss = 5.107, (2.501 sec/step)
# step 63 - trloss = 5.200, (2.503 sec/step)
# step 64 - trloss = 5.107, (2.501 sec/step)
# step 65 - trloss = 5.191, (2.501 sec/step)
# step 66 - trloss = 5.085, (2.516 sec/step)
# step 67 - trloss = 5.178, (2.501 sec/step)
# step 68 - trloss = 5.079, (2.505 sec/step)
# step 69 - trloss = 5.174, (2.504 sec/step)
# step 70 - trloss = 5.059, (2.501 sec/step)
# step 71 - trloss = 5.157, (2.507 sec/step)
# step 72 - trloss = 5.047, (2.502 sec/step)
# step 73 - trloss = 5.154, (2.517 sec/step)
# step 74 - trloss = 5.026, (2.502 sec/step)
# step 75 - trloss = 5.127, (2.502 sec/step)
# step 76 - trloss = 5.007, (2.503 sec/step)
# step 77 - trloss = 5.116, (2.501 sec/step)
# step 78 - trloss = 4.988, (2.501 sec/step)
# step 79 - trloss = 5.085, (2.503 sec/step)
# step 80 - trloss = 4.964, (2.502 sec/step)
# step 81 - trloss = 5.065, (2.504 sec/step)
# step 82 - trloss = 4.945, (2.502 sec/step)
# step 83 - trloss = 5.037, (2.502 sec/step)
# step 84 - trloss = 4.916, (2.501 sec/step)
# step 85 - trloss = 5.013, (2.501 sec/step)
# step 86 - trloss = 4.890, (2.501 sec/step)
# step 87 - trloss = 4.992, (2.509 sec/step)
# step 88 - trloss = 4.867, (2.512 sec/step)
# step 89 - trloss = 4.959, (2.501 sec/step)
# step 90 - trloss = 4.841, (2.502 sec/step)
# step 91 - trloss = 4.942, (2.501 sec/step)
# step 92 - trloss = 4.813, (2.502 sec/step)
# step 93 - trloss = 4.906, (2.502 sec/step)
# step 94 - trloss = 4.791, (2.501 sec/step)
# step 95 - trloss = 4.885, (2.503 sec/step)
# step 96 - trloss = 4.765, (2.512 sec/step)
# step 97 - trloss = 4.849, (2.502 sec/step)
# step 98 - trloss = 4.742, (2.501 sec/step)
# step 99 - trloss = 4.848, (2.500 sec/step)
# step 100 - trloss = 4.738, (2.501 sec/step)
# stored done
# validateLoss = 4.935, (2.501 sec/step)
# step 101 - trloss = 4.818, (2.502 sec/step)
# step 102 - trloss = 4.695, (2.502 sec/step)
# step 103 - trloss = 4.794, (2.501 sec/step)
# step 104 - trloss = 4.693, (2.506 sec/step)
# step 105 - trloss = 4.749, (2.501 sec/step)
# step 106 - trloss = 4.686, (2.509 sec/step)
# step 107 - trloss = 4.762, (2.503 sec/step)
# step 108 - trloss = 4.642, (2.501 sec/step)
# step 109 - trloss = 4.742, (2.502 sec/step)
# step 110 - trloss = 4.619, (2.510 sec/step)
# step 111 - trloss = 4.722, (2.502 sec/step)
# step 112 - trloss = 4.607, (2.501 sec/step)
# step 113 - trloss = 4.685, (2.503 sec/step)
# step 114 - trloss = 4.586, (2.503 sec/step)
# step 115 - trloss = 4.666, (2.501 sec/step)
# step 116 - trloss = 4.589, (2.502 sec/step)
# step 117 - trloss = 4.638, (2.507 sec/step)
# step 118 - trloss = 4.556, (2.501 sec/step)
# step 119 - trloss = 4.619, (2.500 sec/step)
# step 120 - trloss = 4.548, (2.508 sec/step)
# step 121 - trloss = 4.621, (2.501 sec/step)
# step 122 - trloss = 4.519, (2.499 sec/step)
# step 123 - trloss = 4.594, (2.498 sec/step)
# step 124 - trloss = 4.504, (2.499 sec/step)
# step 125 - trloss = 4.584, (2.501 sec/step)
# step 126 - trloss = 4.508, (2.503 sec/step)
# step 127 - trloss = 4.563, (2.500 sec/step)
# step 128 - trloss = 4.479, (2.499 sec/step)
# step 129 - trloss = 4.546, (2.498 sec/step)
# step 130 - trloss = 4.469, (2.499 sec/step)
# step 131 - trloss = 4.543, (2.499 sec/step)
# step 132 - trloss = 4.468, (2.499 sec/step)
# step 133 - trloss = 4.527, (2.499 sec/step)
# step 134 - trloss = 4.440, (2.499 sec/step)
# step 135 - trloss = 4.511, (2.500 sec/step)
# step 136 - trloss = 4.434, (2.500 sec/step)
# step 137 - trloss = 4.501, (2.501 sec/step)
# step 138 - trloss = 4.428, (2.501 sec/step)
# step 139 - trloss = 4.516, (2.498 sec/step)
# step 140 - trloss = 4.425, (2.503 sec/step)
# step 141 - trloss = 4.488, (2.503 sec/step)
# step 142 - trloss = 4.402, (2.500 sec/step)
# step 143 - trloss = 4.472, (2.499 sec/step)
# step 144 - trloss = 4.393, (2.500 sec/step)
# step 145 - trloss = 4.456, (2.500 sec/step)
# step 146 - trloss = 4.388, (2.502 sec/step)
# step 147 - trloss = 4.472, (2.508 sec/step)
# step 148 - trloss = 4.384, (2.500 sec/step)
# step 149 - trloss = 4.449, (2.503 sec/step)
# step 150 - trloss = 4.364, (2.500 sec/step)
# stored done
# validateLoss = 4.808, (2.500 sec/step)
# step 151 - trloss = 4.433, (2.513 sec/step)
# step 152 - trloss = 4.357, (2.501 sec/step)
# step 153 - trloss = 4.422, (2.499 sec/step)
# step 154 - trloss = 4.351, (2.499 sec/step)
# step 155 - trloss = 4.436, (2.499 sec/step)
# step 156 - trloss = 4.354, (2.499 sec/step)
# step 157 - trloss = 4.422, (2.499 sec/step)
# step 158 - trloss = 4.332, (2.501 sec/step)
# step 159 - trloss = 4.405, (2.503 sec/step)
# step 160 - trloss = 4.341, (2.501 sec/step)
# step 161 - trloss = 4.396, (2.501 sec/step)
# step 162 - trloss = 4.314, (2.501 sec/step)
# step 163 - trloss = 4.397, (2.501 sec/step)
# step 164 - trloss = 4.331, (2.501 sec/step)
# step 165 - trloss = 4.411, (2.501 sec/step)
# step 166 - trloss = 4.303, (2.511 sec/step)
# step 167 - trloss = 4.377, (2.502 sec/step)
# step 168 - trloss = 4.320, (2.502 sec/step)
# step 169 - trloss = 4.365, (2.505 sec/step)
# step 170 - trloss = 4.294, (2.503 sec/step)
# step 171 - trloss = 4.391, (2.503 sec/step)
# step 172 - trloss = 4.311, (2.503 sec/step)
# step 173 - trloss = 4.396, (2.502 sec/step)
# step 174 - trloss = 4.350, (2.504 sec/step)
# step 175 - trloss = 4.351, (2.502 sec/step)
# step 176 - trloss = 4.305, (2.503 sec/step)
# step 177 - trloss = 4.426, (2.502 sec/step)
# step 178 - trloss = 4.275, (2.506 sec/step)
# step 179 - trloss = 4.383, (2.514 sec/step)
# step 180 - trloss = 4.304, (2.509 sec/step)
# step 181 - trloss = 4.355, (2.502 sec/step)
# step 182 - trloss = 4.325, (2.504 sec/step)
# step 183 - trloss = 4.333, (2.506 sec/step)
# step 184 - trloss = 4.290, (2.502 sec/step)
# step 185 - trloss = 4.323, (2.509 sec/step)
# step 186 - trloss = 4.291, (2.502 sec/step)
# step 187 - trloss = 4.327, (2.503 sec/step)
# step 188 - trloss = 4.266, (2.501 sec/step)
# step 189 - trloss = 4.317, (2.503 sec/step)
# step 190 - trloss = 4.264, (2.501 sec/step)
# step 191 - trloss = 4.325, (2.504 sec/step)
# step 192 - trloss = 4.246, (2.504 sec/step)
# step 193 - trloss = 4.310, (2.503 sec/step)
# step 194 - trloss = 4.243, (2.502 sec/step)
# step 195 - trloss = 4.315, (2.501 sec/step)
# step 196 - trloss = 4.232, (2.501 sec/step)
# step 197 - trloss = 4.300, (2.500 sec/step)
# step 198 - trloss = 4.229, (2.502 sec/step)
# step 199 - trloss = 4.305, (2.502 sec/step)
# step 200 - trloss = 4.223, (2.502 sec/step)
# stored done
# validateLoss = 4.776, (2.502 sec/step)
# step 201 - trloss = 4.286, (2.513 sec/step)
# step 202 - trloss = 4.224, (2.500 sec/step)
# step 203 - trloss = 4.281, (2.502 sec/step)
# step 204 - trloss = 4.220, (2.503 sec/step)
# step 205 - trloss = 4.267, (2.501 sec/step)
# step 206 - trloss = 4.218, (2.501 sec/step)
# step 207 - trloss = 4.268, (2.500 sec/step)
# step 208 - trloss = 4.217, (2.502 sec/step)
# step 209 - trloss = 4.277, (2.500 sec/step)
# step 210 - trloss = 4.204, (2.502 sec/step)
# step 211 - trloss = 4.258, (2.502 sec/step)
# step 212 - trloss = 4.188, (2.503 sec/step)
# step 213 - trloss = 4.257, (2.502 sec/step)
# step 214 - trloss = 4.219, (2.501 sec/step)
# step 215 - trloss = 4.269, (2.502 sec/step)
# step 216 - trloss = 4.183, (2.500 sec/step)
# step 217 - trloss = 4.239, (2.501 sec/step)
# step 218 - trloss = 4.181, (2.500 sec/step)
# step 219 - trloss = 4.273, (2.502 sec/step)
# step 220 - trloss = 4.182, (2.501 sec/step)
# step 221 - trloss = 4.229, (2.500 sec/step)
# step 222 - trloss = 4.171, (2.501 sec/step)
# step 223 - trloss = 4.237, (2.501 sec/step)
# step 224 - trloss = 4.156, (2.501 sec/step)
# step 225 - trloss = 4.224, (2.501 sec/step)
# step 226 - trloss = 4.163, (2.501 sec/step)
# step 227 - trloss = 4.234, (2.504 sec/step)
# step 228 - trloss = 4.145, (2.502 sec/step)
# step 229 - trloss = 4.213, (2.505 sec/step)
# step 230 - trloss = 4.156, (2.501 sec/step)
# step 231 - trloss = 4.215, (2.502 sec/step)
# step 232 - trloss = 4.139, (2.501 sec/step)
# step 233 - trloss = 4.214, (2.501 sec/step)
# step 234 - trloss = 4.144, (2.502 sec/step)
# step 235 - trloss = 4.214, (2.501 sec/step)
# step 236 - trloss = 4.130, (2.502 sec/step)
# step 237 - trloss = 4.199, (2.502 sec/step)
# step 238 - trloss = 4.141, (2.508 sec/step)
# step 239 - trloss = 4.195, (2.502 sec/step)
# step 240 - trloss = 4.115, (2.502 sec/step)
# step 241 - trloss = 4.188, (2.514 sec/step)
# step 242 - trloss = 4.133, (2.507 sec/step)
# step 243 - trloss = 4.220, (2.502 sec/step)
# step 244 - trloss = 4.121, (2.502 sec/step)
# step 245 - trloss = 4.174, (2.502 sec/step)
# step 246 - trloss = 4.111, (2.502 sec/step)
# step 247 - trloss = 4.186, (2.500 sec/step)
# step 248 - trloss = 4.104, (2.501 sec/step)
# step 249 - trloss = 4.166, (2.501 sec/step)
# step 250 - trloss = 4.103, (2.501 sec/step)
# stored done
# validateLoss = 4.795, (2.501 sec/step)
# step 251 - trloss = 4.208, (2.501 sec/step)
# step 252 - trloss = 4.182, (2.502 sec/step)
# step 253 - trloss = 4.397, (2.501 sec/step)
# step 254 - trloss = 4.149, (2.501 sec/step)
# step 255 - trloss = 4.304, (2.500 sec/step)
# step 256 - trloss = 4.246, (2.502 sec/step)
# step 257 - trloss = 4.236, (2.509 sec/step)
# step 258 - trloss = 4.209, (2.502 sec/step)
# step 259 - trloss = 4.201, (2.502 sec/step)
# step 260 - trloss = 4.210, (2.502 sec/step)
# step 261 - trloss = 4.176, (2.502 sec/step)
# step 262 - trloss = 4.163, (2.502 sec/step)
# step 263 - trloss = 4.184, (2.502 sec/step)
# step 264 - trloss = 4.140, (2.501 sec/step)
# step 265 - trloss = 4.189, (2.502 sec/step)
# step 266 - trloss = 4.107, (2.502 sec/step)
# step 267 - trloss = 4.192, (2.502 sec/step)
# step 268 - trloss = 4.099, (2.503 sec/step)
# step 269 - trloss = 4.168, (2.504 sec/step)
# step 270 - trloss = 4.097, (2.502 sec/step)
# step 271 - trloss = 4.153, (2.501 sec/step)
# step 272 - trloss = 4.093, (2.502 sec/step)
# step 273 - trloss = 4.141, (2.503 sec/step)
# step 274 - trloss = 4.084, (2.503 sec/step)
# step 275 - trloss = 4.134, (2.502 sec/step)
# step 276 - trloss = 4.072, (2.502 sec/step)
# step 277 - trloss = 4.134, (2.501 sec/step)
# step 278 - trloss = 4.066, (2.502 sec/step)
# step 279 - trloss = 4.126, (2.502 sec/step)
# step 280 - trloss = 4.057, (2.504 sec/step)
# step 281 - trloss = 4.124, (2.512 sec/step)
# step 282 - trloss = 4.048, (2.501 sec/step)
# step 283 - trloss = 4.118, (2.500 sec/step)
# step 284 - trloss = 4.047, (2.507 sec/step)
# step 285 - trloss = 4.111, (2.500 sec/step)
# step 286 - trloss = 4.040, (2.501 sec/step)
# step 287 - trloss = 4.102, (2.501 sec/step)
# step 288 - trloss = 4.036, (2.508 sec/step)
# step 289 - trloss = 4.101, (2.500 sec/step)
# step 290 - trloss = 4.026, (2.500 sec/step)
# step 291 - trloss = 4.095, (2.500 sec/step)
# step 292 - trloss = 4.026, (2.499 sec/step)
# step 293 - trloss = 4.093, (2.501 sec/step)
# step 294 - trloss = 4.022, (2.499 sec/step)
# step 295 - trloss = 4.091, (2.508 sec/step)
# step 296 - trloss = 4.016, (2.501 sec/step)
# step 297 - trloss = 4.079, (2.500 sec/step)
# step 298 - trloss = 4.010, (2.511 sec/step)
# step 299 - trloss = 4.086, (2.498 sec/step)
# step 300 - trloss = 4.026, (2.499 sec/step)
# stored done
# validateLoss = 5.014, (2.499 sec/step)
# step 301 - trloss = 4.100, (2.498 sec/step)
# step 302 - trloss = 4.042, (2.499 sec/step)
# step 303 - trloss = 4.086, (2.502 sec/step)
# step 304 - trloss = 3.999, (2.501 sec/step)
# step 305 - trloss = 4.094, (2.500 sec/step)
# step 306 - trloss = 4.085, (2.501 sec/step)
# step 307 - trloss = 4.227, (2.508 sec/step)
# step 308 - trloss = 4.018, (2.501 sec/step)
# step 309 - trloss = 4.139, (2.501 sec/step)
# step 310 - trloss = 4.093, (2.500 sec/step)
# step 311 - trloss = 4.108, (2.503 sec/step)
# step 312 - trloss = 4.126, (2.501 sec/step)
# step 313 - trloss = 4.066, (2.503 sec/step)
# step 314 - trloss = 4.104, (2.502 sec/step)
# step 315 - trloss = 4.080, (2.502 sec/step)
# step 316 - trloss = 4.059, (2.502 sec/step)
# step 317 - trloss = 4.078, (2.502 sec/step)
# step 318 - trloss = 4.038, (2.503 sec/step)
# step 319 - trloss = 4.056, (2.502 sec/step)
# step 320 - trloss = 4.025, (2.505 sec/step)
# step 321 - trloss = 4.060, (2.511 sec/step)
# step 322 - trloss = 4.003, (2.503 sec/step)
# step 323 - trloss = 4.058, (2.502 sec/step)
# step 324 - trloss = 3.992, (2.505 sec/step)
# step 325 - trloss = 4.050, (2.501 sec/step)
# step 326 - trloss = 3.990, (2.503 sec/step)
# step 327 - trloss = 4.039, (2.501 sec/step)
# step 328 - trloss = 3.977, (2.502 sec/step)
# step 329 - trloss = 4.042, (2.500 sec/step)
# step 330 - trloss = 3.966, (2.501 sec/step)
# step 331 - trloss = 4.029, (2.501 sec/step)
# step 332 - trloss = 3.962, (2.501 sec/step)
# step 333 - trloss = 4.034, (2.503 sec/step)
# step 334 - trloss = 3.952, (2.502 sec/step)
# step 335 - trloss = 4.022, (2.501 sec/step)
# step 336 - trloss = 3.951, (2.509 sec/step)
# step 337 - trloss = 4.021, (2.501 sec/step)
# step 338 - trloss = 3.946, (2.501 sec/step)
# step 339 - trloss = 4.011, (2.501 sec/step)
# step 340 - trloss = 3.950, (2.500 sec/step)
# step 341 - trloss = 4.020, (2.501 sec/step)
# step 342 - trloss = 3.941, (2.502 sec/step)
# step 343 - trloss = 4.003, (2.499 sec/step)
# step 344 - trloss = 3.932, (2.501 sec/step)
# step 345 - trloss = 4.009, (2.500 sec/step)
# step 346 - trloss = 3.933, (2.498 sec/step)
# step 347 - trloss = 3.995, (2.498 sec/step)
# step 348 - trloss = 3.922, (2.499 sec/step)
# step 349 - trloss = 3.996, (2.500 sec/step)
# step 350 - trloss = 3.922, (2.499 sec/step)
# stored done
# validateLoss = 5.005, (2.499 sec/step)
# step 351 - trloss = 3.993, (2.500 sec/step)
# step 352 - trloss = 3.917, (2.500 sec/step)
# step 353 - trloss = 3.979, (2.499 sec/step)
# step 354 - trloss = 3.910, (2.499 sec/step)
# step 355 - trloss = 3.986, (2.499 sec/step)
# step 356 - trloss = 3.919, (2.498 sec/step)
# step 357 - trloss = 3.991, (2.500 sec/step)
# step 358 - trloss = 3.908, (2.500 sec/step)
# step 359 - trloss = 3.967, (2.499 sec/step)
# step 360 - trloss = 3.908, (2.500 sec/step)
# step 361 - trloss = 4.018, (2.498 sec/step)
# step 362 - trloss = 3.978, (2.499 sec/step)
# step 363 - trloss = 4.020, (2.499 sec/step)
# step 364 - trloss = 3.901, (2.498 sec/step)
# step 365 - trloss = 4.033, (2.501 sec/step)
# step 366 - trloss = 3.932, (2.500 sec/step)
# step 367 - trloss = 3.991, (2.512 sec/step)
# step 368 - trloss = 3.904, (2.502 sec/step)
# step 369 - trloss = 3.981, (2.500 sec/step)
# step 370 - trloss = 3.900, (2.501 sec/step)
# step 371 - trloss = 3.984, (2.504 sec/step)
# step 372 - trloss = 3.898, (2.502 sec/step)
# step 373 - trloss = 3.955, (2.509 sec/step)
# step 374 - trloss = 3.899, (2.501 sec/step)
# step 375 - trloss = 3.954, (2.502 sec/step)
# step 376 - trloss = 3.882, (2.501 sec/step)
# step 377 - trloss = 3.951, (2.502 sec/step)
# step 378 - trloss = 3.880, (2.502 sec/step)
# step 379 - trloss = 3.944, (2.501 sec/step)
# step 380 - trloss = 3.871, (2.503 sec/step)
# step 381 - trloss = 3.961, (2.501 sec/step)
# step 382 - trloss = 3.878, (2.502 sec/step)
# step 383 - trloss = 3.949, (2.503 sec/step)
# step 384 - trloss = 3.874, (2.501 sec/step)
# step 385 - trloss = 3.958, (2.503 sec/step)
# step 386 - trloss = 3.867, (2.501 sec/step)
# step 387 - trloss = 3.937, (2.500 sec/step)
# step 388 - trloss = 3.869, (2.501 sec/step)
# step 389 - trloss = 3.929, (2.501 sec/step)
# step 390 - trloss = 3.854, (2.501 sec/step)
# step 391 - trloss = 3.929, (2.501 sec/step)
# step 392 - trloss = 3.845, (2.502 sec/step)
# step 393 - trloss = 3.929, (2.501 sec/step)
# step 394 - trloss = 3.841, (2.502 sec/step)
# step 395 - trloss = 3.928, (2.500 sec/step)
# step 396 - trloss = 3.838, (2.501 sec/step)
# step 397 - trloss = 3.921, (2.511 sec/step)
# step 398 - trloss = 3.848, (2.501 sec/step)
# step 399 - trloss = 3.922, (2.508 sec/step)
# step 400 - trloss = 3.847, (2.501 sec/step)
# stored done
# validateLoss = 5.158, (2.501 sec/step)
# step 401 - trloss = 3.926, (2.517 sec/step)
# step 402 - trloss = 3.842, (2.501 sec/step)
# step 403 - trloss = 3.927, (2.502 sec/step)
# step 404 - trloss = 3.848, (2.501 sec/step)
# step 405 - trloss = 3.924, (2.502 sec/step)
# step 406 - trloss = 3.859, (2.502 sec/step)
# step 407 - trloss = 3.939, (2.501 sec/step)
# step 408 - trloss = 3.914, (2.502 sec/step)
# step 409 - trloss = 3.997, (2.502 sec/step)
# step 410 - trloss = 3.884, (2.501 sec/step)
# step 411 - trloss = 3.933, (2.500 sec/step)
# step 412 - trloss = 3.947, (2.503 sec/step)
# step 413 - trloss = 3.897, (2.507 sec/step)
# step 414 - trloss = 3.896, (2.501 sec/step)
# step 415 - trloss = 3.942, (2.501 sec/step)
# step 416 - trloss = 3.822, (2.501 sec/step)
# step 417 - trloss = 3.969, (2.501 sec/step)
# step 418 - trloss = 3.849, (2.500 sec/step)
# step 419 - trloss = 3.913, (2.509 sec/step)
# step 420 - trloss = 3.856, (2.499 sec/step)
# step 421 - trloss = 3.886, (2.500 sec/step)
# step 422 - trloss = 3.839, (2.500 sec/step)
# step 423 - trloss = 3.884, (2.510 sec/step)
# step 424 - trloss = 3.813, (2.501 sec/step)
# step 425 - trloss = 3.888, (2.500 sec/step)
# step 426 - trloss = 3.799, (2.500 sec/step)
# step 427 - trloss = 3.875, (2.500 sec/step)
# step 428 - trloss = 3.801, (2.503 sec/step)
# step 429 - trloss = 3.852, (2.504 sec/step)
# step 430 - trloss = 3.792, (2.503 sec/step)
# step 431 - trloss = 3.855, (2.502 sec/step)
# step 432 - trloss = 3.773, (2.503 sec/step)
# step 433 - trloss = 3.852, (2.503 sec/step)
# step 434 - trloss = 3.767, (2.502 sec/step)
# step 435 - trloss = 3.842, (2.502 sec/step)
# step 436 - trloss = 3.770, (2.504 sec/step)
# step 437 - trloss = 3.838, (2.503 sec/step)
# step 438 - trloss = 3.774, (2.503 sec/step)
# step 439 - trloss = 3.877, (2.503 sec/step)
# step 440 - trloss = 3.815, (2.504 sec/step)
# step 441 - trloss = 3.890, (2.503 sec/step)
# step 442 - trloss = 3.783, (2.503 sec/step)
# step 443 - trloss = 3.856, (2.513 sec/step)
# step 444 - trloss = 3.861, (2.504 sec/step)
# step 445 - trloss = 3.893, (2.504 sec/step)
# step 446 - trloss = 3.819, (2.504 sec/step)
# step 447 - trloss = 3.892, (2.502 sec/step)
# step 448 - trloss = 3.803, (2.503 sec/step)
# step 449 - trloss = 3.893, (2.510 sec/step)
# step 450 - trloss = 3.805, (2.510 sec/step)
# stored done
# validateLoss = 5.333, (2.510 sec/step)
# step 451 - trloss = 3.864, (2.511 sec/step)
# step 452 - trloss = 3.775, (2.504 sec/step)
# step 453 - trloss = 3.873, (2.503 sec/step)
# step 454 - trloss = 3.743, (2.502 sec/step)
# step 455 - trloss = 3.862, (2.503 sec/step)
# step 456 - trloss = 3.745, (2.502 sec/step)
# step 457 - trloss = 3.842, (2.504 sec/step)
# step 458 - trloss = 3.750, (2.503 sec/step)
# step 459 - trloss = 3.839, (2.502 sec/step)
# step 460 - trloss = 3.739, (2.503 sec/step)
# step 461 - trloss = 3.845, (2.501 sec/step)
# step 462 - trloss = 3.723, (2.502 sec/step)
# step 463 - trloss = 3.833, (2.501 sec/step)
# step 464 - trloss = 3.728, (2.502 sec/step)
# step 465 - trloss = 3.815, (2.500 sec/step)
# step 466 - trloss = 3.721, (2.504 sec/step)
# step 467 - trloss = 3.805, (2.501 sec/step)
# step 468 - trloss = 3.716, (2.499 sec/step)
# step 469 - trloss = 3.800, (2.499 sec/step)
# step 470 - trloss = 3.715, (2.498 sec/step)
# step 471 - trloss = 3.789, (2.498 sec/step)
# step 472 - trloss = 3.712, (2.498 sec/step)
# step 473 - trloss = 3.785, (2.497 sec/step)
# step 474 - trloss = 3.704, (2.498 sec/step)
# step 475 - trloss = 3.777, (2.496 sec/step)
# step 476 - trloss = 3.708, (2.497 sec/step)
# step 477 - trloss = 3.764, (2.496 sec/step)
# step 478 - trloss = 3.704, (2.506 sec/step)
# step 479 - trloss = 3.761, (2.496 sec/step)
# step 480 - trloss = 3.697, (2.495 sec/step)
# step 481 - trloss = 3.750, (2.496 sec/step)
# step 482 - trloss = 3.695, (2.495 sec/step)
# step 483 - trloss = 3.752, (2.495 sec/step)
# step 484 - trloss = 3.684, (2.496 sec/step)
# step 485 - trloss = 3.750, (2.495 sec/step)
# step 486 - trloss = 3.677, (2.496 sec/step)
# step 487 - trloss = 3.743, (2.496 sec/step)
# step 488 - trloss = 3.671, (2.496 sec/step)
# step 489 - trloss = 3.738, (2.496 sec/step)
# step 490 - trloss = 3.671, (2.496 sec/step)
# step 491 - trloss = 3.741, (2.498 sec/step)
# step 492 - trloss = 3.662, (2.497 sec/step)
# step 493 - trloss = 3.738, (2.500 sec/step)
# step 494 - trloss = 3.658, (2.498 sec/step)
# step 495 - trloss = 3.733, (2.500 sec/step)
# step 496 - trloss = 3.668, (2.499 sec/step)
# step 497 - trloss = 3.736, (2.500 sec/step)
# step 498 - trloss = 3.673, (2.500 sec/step)
# step 499 - trloss = 3.735, (2.501 sec/step)
# step 500 - trloss = 3.650, (2.499 sec/step)
# stored done
# validateLoss = 5.399, (2.499 sec/step)
# step 501 - trloss = 3.721, (2.502 sec/step)
# step 502 - trloss = 3.685, (2.502 sec/step)
# step 503 - trloss = 3.790, (2.501 sec/step)
# step 504 - trloss = 3.771, (2.501 sec/step)
# step 505 - trloss = 3.746, (2.506 sec/step)
# step 506 - trloss = 3.658, (2.502 sec/step)
# step 507 - trloss = 3.822, (2.503 sec/step)
# step 508 - trloss = 3.717, (2.502 sec/step)
# step 509 - trloss = 3.735, (2.503 sec/step)
# step 510 - trloss = 3.679, (2.504 sec/step)
# step 511 - trloss = 3.746, (2.503 sec/step)
# step 512 - trloss = 3.673, (2.502 sec/step)
# step 513 - trloss = 3.714, (2.503 sec/step)
# step 514 - trloss = 3.695, (2.504 sec/step)
# step 515 - trloss = 3.749, (2.503 sec/step)
# step 516 - trloss = 3.697, (2.501 sec/step)
# step 517 - trloss = 3.729, (2.502 sec/step)
# step 518 - trloss = 3.669, (2.511 sec/step)
# step 519 - trloss = 3.757, (2.502 sec/step)
# step 520 - trloss = 3.630, (2.510 sec/step)
# step 521 - trloss = 3.742, (2.500 sec/step)
# step 522 - trloss = 3.633, (2.501 sec/step)
# step 523 - trloss = 3.714, (2.502 sec/step)
# step 524 - trloss = 3.624, (2.503 sec/step)
# step 525 - trloss = 3.702, (2.502 sec/step)
# step 526 - trloss = 3.625, (2.507 sec/step)
# step 527 - trloss = 3.671, (2.502 sec/step)
# step 528 - trloss = 3.621, (2.502 sec/step)
# step 529 - trloss = 3.672, (2.502 sec/step)
# step 530 - trloss = 3.606, (2.501 sec/step)
# step 531 - trloss = 3.672, (2.501 sec/step)
# step 532 - trloss = 3.600, (2.507 sec/step)
# step 533 - trloss = 3.679, (2.510 sec/step)
# step 534 - trloss = 3.585, (2.501 sec/step)
# step 535 - trloss = 3.680, (2.501 sec/step)
# step 536 - trloss = 3.591, (2.500 sec/step)
# step 537 - trloss = 3.664, (2.500 sec/step)
# step 538 - trloss = 3.591, (2.500 sec/step)
# step 539 - trloss = 3.655, (2.500 sec/step)
# step 540 - trloss = 3.597, (2.500 sec/step)
# step 541 - trloss = 3.641, (2.499 sec/step)
# step 542 - trloss = 3.580, (2.503 sec/step)
# step 543 - trloss = 3.639, (2.500 sec/step)
# step 544 - trloss = 3.584, (2.500 sec/step)
# step 545 - trloss = 3.643, (2.500 sec/step)
# step 546 - trloss = 3.559, (2.501 sec/step)
# step 547 - trloss = 3.628, (2.502 sec/step)
# step 548 - trloss = 3.564, (2.500 sec/step)
# step 549 - trloss = 3.634, (2.499 sec/step)
# step 550 - trloss = 3.572, (2.500 sec/step)
# stored done
# validateLoss = 5.421, (2.500 sec/step)
# step 551 - trloss = 3.627, (2.500 sec/step)
# step 552 - trloss = 3.545, (2.500 sec/step)
# step 553 - trloss = 3.630, (2.499 sec/step)
# step 554 - trloss = 3.569, (2.500 sec/step)
# step 555 - trloss = 3.649, (2.500 sec/step)
# step 556 - trloss = 3.562, (2.502 sec/step)
# step 557 - trloss = 3.606, (2.501 sec/step)
# step 558 - trloss = 3.556, (2.500 sec/step)
# step 559 - trloss = 3.639, (2.500 sec/step)
# step 560 - trloss = 3.589, (2.498 sec/step)
# step 561 - trloss = 3.657, (2.499 sec/step)
# step 562 - trloss = 3.524, (2.501 sec/step)
# step 563 - trloss = 3.634, (2.500 sec/step)
# step 564 - trloss = 3.584, (2.501 sec/step)
# step 565 - trloss = 3.648, (2.500 sec/step)
# step 566 - trloss = 3.552, (2.500 sec/step)
# step 567 - trloss = 3.625, (2.511 sec/step)
# step 568 - trloss = 3.557, (2.503 sec/step)
# step 569 - trloss = 3.592, (2.501 sec/step)
# step 570 - trloss = 3.535, (2.502 sec/step)
# step 571 - trloss = 3.705, (2.499 sec/step)
# step 572 - trloss = 3.654, (2.501 sec/step)
# step 573 - trloss = 3.631, (2.500 sec/step)
# step 574 - trloss = 3.522, (2.507 sec/step)
# step 575 - trloss = 3.698, (2.501 sec/step)
# step 576 - trloss = 3.580, (2.500 sec/step)
# step 577 - trloss = 3.589, (2.501 sec/step)
# step 578 - trloss = 3.555, (2.502 sec/step)
# step 579 - trloss = 3.626, (2.501 sec/step)
# step 580 - trloss = 3.506, (2.501 sec/step)
# step 581 - trloss = 3.624, (2.501 sec/step)
# step 582 - trloss = 3.546, (2.501 sec/step)
# step 583 - trloss = 3.569, (2.501 sec/step)
# step 584 - trloss = 3.531, (2.500 sec/step)
# step 585 - trloss = 3.598, (2.501 sec/step)
# step 586 - trloss = 3.497, (2.500 sec/step)
# step 587 - trloss = 3.605, (2.502 sec/step)
# step 588 - trloss = 3.503, (2.501 sec/step)
# step 589 - trloss = 3.562, (2.501 sec/step)
# step 590 - trloss = 3.510, (2.502 sec/step)
# step 591 - trloss = 3.577, (2.499 sec/step)
# step 592 - trloss = 3.492, (2.501 sec/step)
# step 593 - trloss = 3.560, (2.499 sec/step)
# step 594 - trloss = 3.505, (2.501 sec/step)
# step 595 - trloss = 3.556, (2.500 sec/step)
# step 596 - trloss = 3.510, (2.502 sec/step)
# step 597 - trloss = 3.602, (2.501 sec/step)
# step 598 - trloss = 3.497, (2.501 sec/step)
# step 599 - trloss = 3.623, (2.500 sec/step)
# step 600 - trloss = 3.534, (2.499 sec/step)
# stored done
# validateLoss = 5.462, (2.499 sec/step)
# step 601 - trloss = 3.600, (2.511 sec/step)
# step 602 - trloss = 3.511, (2.506 sec/step)
# step 603 - trloss = 3.614, (2.501 sec/step)
# step 604 - trloss = 3.469, (2.501 sec/step)
# step 605 - trloss = 3.623, (2.502 sec/step)
# step 606 - trloss = 3.518, (2.502 sec/step)
# step 607 - trloss = 3.572, (2.502 sec/step)
# step 608 - trloss = 3.487, (2.501 sec/step)
# step 609 - trloss = 3.581, (2.500 sec/step)
# step 610 - trloss = 3.534, (2.499 sec/step)
# step 611 - trloss = 3.575, (2.502 sec/step)
# step 612 - trloss = 3.455, (2.501 sec/step)
# step 613 - trloss = 3.554, (2.510 sec/step)
# step 614 - trloss = 3.510, (2.499 sec/step)
# step 615 - trloss = 3.519, (2.499 sec/step)
# step 616 - trloss = 3.451, (2.500 sec/step)
# step 617 - trloss = 3.570, (2.500 sec/step)
# step 618 - trloss = 3.432, (2.500 sec/step)
# step 619 - trloss = 3.531, (2.499 sec/step)
# step 620 - trloss = 3.473, (2.499 sec/step)
# step 621 - trloss = 3.505, (2.500 sec/step)
# step 622 - trloss = 3.431, (2.499 sec/step)
# step 623 - trloss = 3.527, (2.499 sec/step)
# step 624 - trloss = 3.418, (2.499 sec/step)
# step 625 - trloss = 3.505, (2.501 sec/step)
# step 626 - trloss = 3.442, (2.501 sec/step)
# step 627 - trloss = 3.473, (2.498 sec/step)
# step 628 - trloss = 3.434, (2.510 sec/step)
# step 629 - trloss = 3.499, (2.501 sec/step)
# step 630 - trloss = 3.395, (2.500 sec/step)
# step 631 - trloss = 3.488, (2.499 sec/step)
# step 632 - trloss = 3.418, (2.502 sec/step)
# step 633 - trloss = 3.464, (2.502 sec/step)
# step 634 - trloss = 3.396, (2.501 sec/step)
# step 635 - trloss = 3.497, (2.507 sec/step)
# step 636 - trloss = 3.388, (2.502 sec/step)
# step 637 - trloss = 3.464, (2.502 sec/step)
# step 638 - trloss = 3.410, (2.504 sec/step)
# step 639 - trloss = 3.458, (2.503 sec/step)
# step 640 - trloss = 3.381, (2.503 sec/step)
# step 641 - trloss = 3.490, (2.504 sec/step)
# step 642 - trloss = 3.396, (2.504 sec/step)
# step 643 - trloss = 3.447, (2.503 sec/step)
# step 644 - trloss = 3.392, (2.503 sec/step)
# step 645 - trloss = 3.461, (2.503 sec/step)
# step 646 - trloss = 3.369, (2.502 sec/step)
# step 647 - trloss = 3.459, (2.503 sec/step)
# step 648 - trloss = 3.392, (2.503 sec/step)
# step 649 - trloss = 3.429, (2.504 sec/step)
# step 650 - trloss = 3.370, (2.502 sec/step)
# stored done
# validateLoss = 5.951, (2.502 sec/step)
# step 651 - trloss = 3.445, (2.503 sec/step)
# step 652 - trloss = 3.370, (2.502 sec/step)
# step 653 - trloss = 3.444, (2.503 sec/step)
# step 654 - trloss = 3.385, (2.503 sec/step)
# step 655 - trloss = 3.430, (2.502 sec/step)
# step 656 - trloss = 3.360, (2.502 sec/step)
# step 657 - trloss = 3.449, (2.503 sec/step)
# step 658 - trloss = 3.439, (2.503 sec/step)
# step 659 - trloss = 3.462, (2.508 sec/step)
# step 660 - trloss = 3.359, (2.502 sec/step)
# step 661 - trloss = 3.437, (2.501 sec/step)
# step 662 - trloss = 3.410, (2.499 sec/step)
# step 663 - trloss = 3.443, (2.501 sec/step)
# step 664 - trloss = 3.412, (2.500 sec/step)
# step 665 - trloss = 3.416, (2.500 sec/step)
# step 666 - trloss = 3.387, (2.502 sec/step)
# step 667 - trloss = 3.461, (2.501 sec/step)
# step 668 - trloss = 3.374, (2.501 sec/step)
# step 669 - trloss = 3.409, (2.501 sec/step)
# step 670 - trloss = 3.334, (2.502 sec/step)
# step 671 - trloss = 3.420, (2.503 sec/step)
# step 672 - trloss = 3.337, (2.501 sec/step)
# step 673 - trloss = 3.378, (2.501 sec/step)
# step 674 - trloss = 3.321, (2.502 sec/step)
# step 675 - trloss = 3.388, (2.499 sec/step)
# step 676 - trloss = 3.305, (2.500 sec/step)
# step 677 - trloss = 3.368, (2.501 sec/step)
# step 678 - trloss = 3.300, (2.501 sec/step)
# step 679 - trloss = 3.373, (2.500 sec/step)
# step 680 - trloss = 3.289, (2.500 sec/step)
# step 681 - trloss = 3.348, (2.501 sec/step)
# step 682 - trloss = 3.288, (2.501 sec/step)
# step 683 - trloss = 3.361, (2.501 sec/step)
# step 684 - trloss = 3.289, (2.502 sec/step)
# step 685 - trloss = 3.351, (2.500 sec/step)
# step 686 - trloss = 3.274, (2.499 sec/step)
# step 687 - trloss = 3.346, (2.500 sec/step)
# step 688 - trloss = 3.291, (2.503 sec/step)
# step 689 - trloss = 3.358, (2.501 sec/step)
# step 690 - trloss = 3.293, (2.501 sec/step)
# step 691 - trloss = 3.367, (2.502 sec/step)
# step 692 - trloss = 3.281, (2.500 sec/step)
# step 693 - trloss = 3.351, (2.500 sec/step)
# step 694 - trloss = 3.312, (2.501 sec/step)
# step 695 - trloss = 3.411, (2.500 sec/step)
# step 696 - trloss = 3.353, (2.500 sec/step)
# step 697 - trloss = 3.374, (2.501 sec/step)
# step 698 - trloss = 3.315, (2.500 sec/step)
# step 699 - trloss = 3.515, (2.499 sec/step)
# step 700 - trloss = 3.363, (2.504 sec/step)
# stored done
# validateLoss = 5.794, (2.504 sec/step)
# step 701 - trloss = 3.401, (2.502 sec/step)
# step 702 - trloss = 3.356, (2.506 sec/step)
# step 703 - trloss = 3.401, (2.501 sec/step)
# step 704 - trloss = 3.332, (2.499 sec/step)
# step 705 - trloss = 3.401, (2.501 sec/step)
# step 706 - trloss = 3.337, (2.499 sec/step)
# step 707 - trloss = 3.366, (2.501 sec/step)
# step 708 - trloss = 3.335, (2.499 sec/step)
# step 709 - trloss = 3.455, (2.499 sec/step)
# step 710 - trloss = 3.297, (2.498 sec/step)
# step 711 - trloss = 3.432, (2.498 sec/step)
# step 712 - trloss = 3.297, (2.497 sec/step)
# step 713 - trloss = 3.453, (2.498 sec/step)
# step 714 - trloss = 3.293, (2.500 sec/step)
# step 715 - trloss = 3.435, (2.498 sec/step)
# step 716 - trloss = 3.287, (2.498 sec/step)
# step 717 - trloss = 3.426, (2.500 sec/step)
# step 718 - trloss = 3.269, (2.499 sec/step)
# step 719 - trloss = 3.429, (2.499 sec/step)
# step 720 - trloss = 3.291, (2.498 sec/step)
# step 721 - trloss = 3.396, (2.500 sec/step)
# step 722 - trloss = 3.305, (2.499 sec/step)
# step 723 - trloss = 3.387, (2.505 sec/step)
# step 724 - trloss = 3.309, (2.499 sec/step)
# step 725 - trloss = 3.388, (2.499 sec/step)
# step 726 - trloss = 3.323, (2.500 sec/step)
# step 727 - trloss = 3.368, (2.501 sec/step)
# step 728 - trloss = 3.344, (2.500 sec/step)
# step 729 - trloss = 3.356, (2.501 sec/step)
# step 730 - trloss = 3.326, (2.502 sec/step)
# step 731 - trloss = 3.328, (2.500 sec/step)
# step 732 - trloss = 3.302, (2.501 sec/step)
# step 733 - trloss = 3.328, (2.502 sec/step)
# step 734 - trloss = 3.272, (2.501 sec/step)
# step 735 - trloss = 3.308, (2.503 sec/step)
# step 736 - trloss = 3.266, (2.501 sec/step)
# step 737 - trloss = 3.299, (2.503 sec/step)
# step 738 - trloss = 3.247, (2.503 sec/step)
# step 739 - trloss = 3.285, (2.502 sec/step)
# step 740 - trloss = 3.227, (2.501 sec/step)
# step 741 - trloss = 3.283, (2.502 sec/step)
# step 742 - trloss = 3.204, (2.501 sec/step)
# step 743 - trloss = 3.276, (2.509 sec/step)
# step 744 - trloss = 3.188, (2.501 sec/step)
# step 745 - trloss = 3.263, (2.501 sec/step)
# step 746 - trloss = 3.182, (2.502 sec/step)
# step 747 - trloss = 3.248, (2.501 sec/step)
# step 748 - trloss = 3.171, (2.501 sec/step)
# step 749 - trloss = 3.236, (2.501 sec/step)
# step 750 - trloss = 3.163, (2.501 sec/step)
# stored done
# validateLoss = 6.086, (2.501 sec/step)
# step 751 - trloss = 3.229, (2.500 sec/step)
# step 752 - trloss = 3.154, (2.499 sec/step)
# step 753 - trloss = 3.219, (2.498 sec/step)
# step 754 - trloss = 3.146, (2.498 sec/step)
# step 755 - trloss = 3.213, (2.499 sec/step)
# step 756 - trloss = 3.136, (2.496 sec/step)
# step 757 - trloss = 3.206, (2.498 sec/step)
# step 758 - trloss = 3.129, (2.499 sec/step)
# step 759 - trloss = 3.200, (2.497 sec/step)
# step 760 - trloss = 3.124, (2.496 sec/step)
# step 761 - trloss = 3.191, (2.495 sec/step)
# step 762 - trloss = 3.116, (2.497 sec/step)
# step 763 - trloss = 3.181, (2.498 sec/step)
# step 764 - trloss = 3.113, (2.497 sec/step)
# step 765 - trloss = 3.177, (2.497 sec/step)
# step 766 - trloss = 3.116, (2.496 sec/step)
# step 767 - trloss = 3.181, (2.495 sec/step)
# step 768 - trloss = 3.119, (2.498 sec/step)
# step 769 - trloss = 3.173, (2.499 sec/step)
# step 770 - trloss = 3.098, (2.497 sec/step)
# step 771 - trloss = 3.161, (2.497 sec/step)
# step 772 - trloss = 3.122, (2.498 sec/step)
# step 773 - trloss = 3.249, (2.498 sec/step)
# step 774 - trloss = 3.269, (2.498 sec/step)
# step 775 - trloss = 3.245, (2.497 sec/step)
# step 776 - trloss = 3.095, (2.499 sec/step)
# step 777 - trloss = 3.223, (2.498 sec/step)
# step 778 - trloss = 3.312, (2.499 sec/step)
# step 779 - trloss = 3.273, (2.498 sec/step)
# step 780 - trloss = 3.096, (2.497 sec/step)
# step 781 - trloss = 3.234, (2.498 sec/step)
# step 782 - trloss = 3.177, (2.499 sec/step)
# step 783 - trloss = 3.150, (2.498 sec/step)
# step 784 - trloss = 3.166, (2.499 sec/step)
# step 785 - trloss = 3.232, (2.498 sec/step)
# step 786 - trloss = 3.084, (2.501 sec/step)
# step 787 - trloss = 3.215, (2.501 sec/step)
# step 788 - trloss = 3.143, (2.501 sec/step)
# step 789 - trloss = 3.167, (2.502 sec/step)
# step 790 - trloss = 3.148, (2.500 sec/step)
# step 791 - trloss = 3.198, (2.501 sec/step)
# step 792 - trloss = 3.117, (2.501 sec/step)
# step 793 - trloss = 3.166, (2.501 sec/step)
# step 794 - trloss = 3.151, (2.502 sec/step)
# step 795 - trloss = 3.150, (2.502 sec/step)
# step 796 - trloss = 3.096, (2.500 sec/step)
# step 797 - trloss = 3.171, (2.502 sec/step)
# step 798 - trloss = 3.070, (2.502 sec/step)
# step 799 - trloss = 3.176, (2.501 sec/step)
# step 800 - trloss = 3.079, (2.502 sec/step)
# stored done
# validateLoss = 6.234, (2.502 sec/step)
# step 801 - trloss = 3.137, (2.502 sec/step)
# step 802 - trloss = 3.075, (2.502 sec/step)
# step 803 - trloss = 3.170, (2.503 sec/step)
# step 804 - trloss = 3.078, (2.503 sec/step)
# step 805 - trloss = 3.119, (2.502 sec/step)
# step 806 - trloss = 3.066, (2.501 sec/step)
# step 807 - trloss = 3.129, (2.502 sec/step)
# step 808 - trloss = 3.116, (2.502 sec/step)
# step 809 - trloss = 3.117, (2.502 sec/step)
# step 810 - trloss = 3.055, (2.501 sec/step)
# step 811 - trloss = 3.117, (2.500 sec/step)
# step 812 - trloss = 3.094, (2.500 sec/step)
# step 813 - trloss = 3.152, (2.502 sec/step)
# step 814 - trloss = 3.027, (2.501 sec/step)
# step 815 - trloss = 3.109, (2.501 sec/step)
# step 816 - trloss = 3.082, (2.501 sec/step)
# step 817 - trloss = 3.170, (2.502 sec/step)
# step 818 - trloss = 3.037, (2.501 sec/step)
# step 819 - trloss = 3.096, (2.501 sec/step)
# step 820 - trloss = 3.081, (2.502 sec/step)
# step 821 - trloss = 3.131, (2.501 sec/step)
# step 822 - trloss = 3.031, (2.502 sec/step)
# step 823 - trloss = 3.097, (2.501 sec/step)
# step 824 - trloss = 3.054, (2.502 sec/step)
# step 825 - trloss = 3.107, (2.501 sec/step)
# step 826 - trloss = 3.031, (2.503 sec/step)
# step 827 - trloss = 3.087, (2.502 sec/step)
# step 828 - trloss = 3.034, (2.502 sec/step)
# step 829 - trloss = 3.099, (2.502 sec/step)
# step 830 - trloss = 3.024, (2.501 sec/step)
# step 831 - trloss = 3.103, (2.501 sec/step)
# step 832 - trloss = 3.019, (2.502 sec/step)
# step 833 - trloss = 3.071, (2.501 sec/step)
# step 834 - trloss = 3.024, (2.503 sec/step)
# step 835 - trloss = 3.075, (2.504 sec/step)
# step 836 - trloss = 2.994, (2.501 sec/step)
# step 837 - trloss = 3.071, (2.502 sec/step)
# step 838 - trloss = 3.007, (2.501 sec/step)
# step 839 - trloss = 3.043, (2.501 sec/step)
# step 840 - trloss = 2.986, (2.502 sec/step)
# step 841 - trloss = 3.064, (2.502 sec/step)
# step 842 - trloss = 2.988, (2.501 sec/step)
# step 843 - trloss = 3.014, (2.503 sec/step)
# step 844 - trloss = 2.988, (2.501 sec/step)
# step 845 - trloss = 3.049, (2.499 sec/step)
# step 846 - trloss = 2.971, (2.500 sec/step)
# step 847 - trloss = 3.008, (2.501 sec/step)
# step 848 - trloss = 2.977, (2.504 sec/step)
# step 849 - trloss = 3.055, (2.501 sec/step)
# step 850 - trloss = 2.948, (2.500 sec/step)
# stored done
# validateLoss = 6.447, (2.500 sec/step)
# step 851 - trloss = 3.027, (2.501 sec/step)
# step 852 - trloss = 2.976, (2.502 sec/step)
# step 853 - trloss = 3.030, (2.500 sec/step)
# step 854 - trloss = 2.946, (2.501 sec/step)
# step 855 - trloss = 3.016, (2.501 sec/step)
# step 856 - trloss = 2.956, (2.501 sec/step)
# step 857 - trloss = 2.997, (2.499 sec/step)
# step 858 - trloss = 2.963, (2.499 sec/step)
# step 859 - trloss = 3.044, (2.500 sec/step)
# step 860 - trloss = 2.970, (2.499 sec/step)
# step 861 - trloss = 2.978, (2.500 sec/step)
# step 862 - trloss = 2.958, (2.507 sec/step)
# step 863 - trloss = 3.059, (2.500 sec/step)
# step 864 - trloss = 2.975, (2.501 sec/step)
# step 865 - trloss = 2.989, (2.501 sec/step)
# step 866 - trloss = 2.969, (2.500 sec/step)
# step 867 - trloss = 3.104, (2.501 sec/step)
# step 868 - trloss = 2.967, (2.501 sec/step)
# step 869 - trloss = 3.014, (2.503 sec/step)
# step 870 - trloss = 2.991, (2.500 sec/step)
# step 871 - trloss = 3.016, (2.509 sec/step)
# step 872 - trloss = 2.949, (2.501 sec/step)
# step 873 - trloss = 3.045, (2.503 sec/step)
# step 874 - trloss = 2.932, (2.503 sec/step)
# step 875 - trloss = 2.982, (2.503 sec/step)
# step 876 - trloss = 2.960, (2.504 sec/step)
# step 877 - trloss = 2.999, (2.504 sec/step)
# step 878 - trloss = 2.906, (2.503 sec/step)
# step 879 - trloss = 2.956, (2.504 sec/step)
# step 880 - trloss = 2.951, (2.505 sec/step)
# step 881 - trloss = 2.958, (2.504 sec/step)
# step 882 - trloss = 2.903, (2.509 sec/step)
# step 883 - trloss = 2.948, (2.503 sec/step)
# step 884 - trloss = 2.883, (2.502 sec/step)
# step 885 - trloss = 2.962, (2.503 sec/step)
# step 886 - trloss = 2.893, (2.504 sec/step)
# step 887 - trloss = 2.934, (2.502 sec/step)
# step 888 - trloss = 2.860, (2.503 sec/step)
# step 889 - trloss = 2.968, (2.502 sec/step)
# step 890 - trloss = 2.899, (2.503 sec/step)
# step 891 - trloss = 2.923, (2.502 sec/step)
# step 892 - trloss = 2.843, (2.502 sec/step)
# step 893 - trloss = 2.962, (2.504 sec/step)
# step 894 - trloss = 2.919, (2.502 sec/step)
# step 895 - trloss = 2.933, (2.502 sec/step)
# step 896 - trloss = 2.852, (2.502 sec/step)
# step 897 - trloss = 2.941, (2.502 sec/step)
# step 898 - trloss = 2.896, (2.501 sec/step)
# step 899 - trloss = 2.934, (2.500 sec/step)
# step 900 - trloss = 2.846, (2.501 sec/step)
# stored done
# validateLoss = 6.531, (2.501 sec/step)
# step 901 - trloss = 2.908, (2.501 sec/step)
# step 902 - trloss = 2.884, (2.499 sec/step)
# step 903 - trloss = 2.938, (2.499 sec/step)
# step 904 - trloss = 2.848, (2.499 sec/step)
# step 905 - trloss = 2.909, (2.500 sec/step)
# step 906 - trloss = 2.863, (2.498 sec/step)
# step 907 - trloss = 2.974, (2.505 sec/step)
# step 908 - trloss = 2.831, (2.498 sec/step)
# step 909 - trloss = 2.935, (2.500 sec/step)
# step 910 - trloss = 2.874, (2.501 sec/step)
# step 911 - trloss = 2.895, (2.502 sec/step)
# step 912 - trloss = 2.831, (2.501 sec/step)
# step 913 - trloss = 2.918, (2.501 sec/step)
# step 914 - trloss = 2.841, (2.500 sec/step)
# step 915 - trloss = 2.872, (2.501 sec/step)
# step 916 - trloss = 2.813, (2.502 sec/step)
# step 917 - trloss = 2.905, (2.502 sec/step)
# step 918 - trloss = 2.803, (2.501 sec/step)
# step 919 - trloss = 2.843, (2.500 sec/step)
# step 920 - trloss = 2.840, (2.501 sec/step)
# step 921 - trloss = 2.873, (2.502 sec/step)
# step 922 - trloss = 2.769, (2.503 sec/step)
# step 923 - trloss = 2.862, (2.502 sec/step)
# step 924 - trloss = 2.807, (2.501 sec/step)
# step 925 - trloss = 2.871, (2.500 sec/step)
# step 926 - trloss = 2.792, (2.500 sec/step)
# step 927 - trloss = 2.823, (2.501 sec/step)
# step 928 - trloss = 2.810, (2.501 sec/step)
# step 929 - trloss = 2.878, (2.501 sec/step)
# step 930 - trloss = 2.756, (2.502 sec/step)
# step 931 - trloss = 2.879, (2.501 sec/step)
# step 932 - trloss = 2.783, (2.498 sec/step)
# step 933 - trloss = 2.827, (2.499 sec/step)
# step 934 - trloss = 2.763, (2.500 sec/step)
# step 935 - trloss = 2.829, (2.501 sec/step)
# step 936 - trloss = 2.796, (2.499 sec/step)
# step 937 - trloss = 2.823, (2.501 sec/step)
# step 938 - trloss = 2.731, (2.501 sec/step)
# step 939 - trloss = 2.839, (2.501 sec/step)
# step 940 - trloss = 2.768, (2.500 sec/step)
# step 941 - trloss = 2.790, (2.501 sec/step)
# step 942 - trloss = 2.743, (2.500 sec/step)
# step 943 - trloss = 2.811, (2.501 sec/step)
# step 944 - trloss = 2.743, (2.501 sec/step)
# step 945 - trloss = 2.835, (2.500 sec/step)
# step 946 - trloss = 2.718, (2.501 sec/step)
# step 947 - trloss = 2.829, (2.501 sec/step)
# step 948 - trloss = 2.771, (2.501 sec/step)
# step 949 - trloss = 2.780, (2.500 sec/step)
# step 950 - trloss = 2.730, (2.501 sec/step)
# stored done
# validateLoss = 7.107, (2.501 sec/step)
# step 951 - trloss = 2.819, (2.498 sec/step)
# step 952 - trloss = 2.750, (2.500 sec/step)
# step 953 - trloss = 2.796, (2.498 sec/step)
# step 954 - trloss = 2.707, (2.498 sec/step)
# step 955 - trloss = 2.803, (2.506 sec/step)
# step 956 - trloss = 2.737, (2.499 sec/step)
# step 957 - trloss = 2.762, (2.499 sec/step)
# step 958 - trloss = 2.718, (2.499 sec/step)
# step 959 - trloss = 2.811, (2.498 sec/step)
# step 960 - trloss = 2.754, (2.497 sec/step)
# step 961 - trloss = 2.804, (2.499 sec/step)
# step 962 - trloss = 2.719, (2.500 sec/step)
# step 963 - trloss = 2.796, (2.498 sec/step)
# step 964 - trloss = 2.767, (2.499 sec/step)
# step 965 - trloss = 2.774, (2.499 sec/step)
# step 966 - trloss = 2.717, (2.498 sec/step)
# step 967 - trloss = 2.769, (2.500 sec/step)
# step 968 - trloss = 2.756, (2.499 sec/step)
# step 969 - trloss = 2.764, (2.498 sec/step)
# step 970 - trloss = 2.726, (2.498 sec/step)
# step 971 - trloss = 2.768, (2.499 sec/step)
# step 972 - trloss = 2.702, (2.498 sec/step)
# step 973 - trloss = 2.737, (2.499 sec/step)
# step 974 - trloss = 2.718, (2.500 sec/step)
# step 975 - trloss = 2.838, (2.499 sec/step)
# step 976 - trloss = 2.739, (2.498 sec/step)
# step 977 - trloss = 2.713, (2.500 sec/step)
# step 978 - trloss = 2.702, (2.498 sec/step)
# step 979 - trloss = 2.843, (2.499 sec/step)
# step 980 - trloss = 2.752, (2.499 sec/step)
# step 981 - trloss = 2.740, (2.500 sec/step)
# step 982 - trloss = 2.693, (2.500 sec/step)
# step 983 - trloss = 2.842, (2.499 sec/step)
# step 984 - trloss = 2.727, (2.501 sec/step)
# step 985 - trloss = 2.753, (2.500 sec/step)
# step 986 - trloss = 2.726, (2.500 sec/step)
# step 987 - trloss = 2.730, (2.499 sec/step)
# step 988 - trloss = 2.667, (2.505 sec/step)
# step 989 - trloss = 2.745, (2.500 sec/step)
# step 990 - trloss = 2.720, (2.501 sec/step)
# step 991 - trloss = 2.706, (2.500 sec/step)
# step 992 - trloss = 2.651, (2.500 sec/step)
# step 993 - trloss = 2.769, (2.502 sec/step)
# step 994 - trloss = 2.669, (2.500 sec/step)
# step 995 - trloss = 2.666, (2.499 sec/step)
# step 996 - trloss = 2.652, (2.500 sec/step)
# step 997 - trloss = 2.716, (2.499 sec/step)
# step 998 - trloss = 2.620, (2.500 sec/step)
# step 999 - trloss = 2.656, (2.499 sec/step)
# step 1000 - trloss = 2.640, (2.498 sec/step)
# stored done
# validateLoss = 7.227, (2.498 sec/step)
# step 1001 - trloss = 2.702, (2.499 sec/step)
# step 1002 - trloss = 2.602, (2.497 sec/step)
# step 1003 - trloss = 2.659, (2.499 sec/step)
# step 1004 - trloss = 2.628, (2.497 sec/step)
# step 1005 - trloss = 2.647, (2.498 sec/step)
# step 1006 - trloss = 2.596, (2.498 sec/step)
# step 1007 - trloss = 2.679, (2.499 sec/step)
# step 1008 - trloss = 2.590, (2.500 sec/step)
# step 1009 - trloss = 2.619, (2.501 sec/step)
# step 1010 - trloss = 2.590, (2.499 sec/step)
# step 1011 - trloss = 2.717, (2.501 sec/step)
# step 1012 - trloss = 2.608, (2.501 sec/step)
# step 1013 - trloss = 2.624, (2.503 sec/step)
# step 1014 - trloss = 2.595, (2.502 sec/step)
# step 1015 - trloss = 2.703, (2.503 sec/step)
# step 1016 - trloss = 2.608, (2.504 sec/step)
# step 1017 - trloss = 2.634, (2.502 sec/step)
# step 1018 - trloss = 2.595, (2.502 sec/step)
# step 1019 - trloss = 2.685, (2.503 sec/step)
# step 1020 - trloss = 2.624, (2.502 sec/step)
# step 1021 - trloss = 2.639, (2.503 sec/step)
# step 1022 - trloss = 2.612, (2.502 sec/step)
# step 1023 - trloss = 2.646, (2.502 sec/step)
# step 1024 - trloss = 2.575, (2.502 sec/step)
# step 1025 - trloss = 2.680, (2.503 sec/step)
# step 1026 - trloss = 2.610, (2.502 sec/step)
# step 1027 - trloss = 2.658, (2.503 sec/step)
# step 1028 - trloss = 2.582, (2.503 sec/step)
# step 1029 - trloss = 2.643, (2.503 sec/step)
# step 1030 - trloss = 2.596, (2.502 sec/step)
# step 1031 - trloss = 2.612, (2.500 sec/step)
# step 1032 - trloss = 2.575, (2.501 sec/step)
# step 1033 - trloss = 2.680, (2.502 sec/step)
# step 1034 - trloss = 2.573, (2.502 sec/step)
# step 1035 - trloss = 2.629, (2.504 sec/step)
# step 1036 - trloss = 2.597, (2.501 sec/step)
# step 1037 - trloss = 2.688, (2.503 sec/step)
# step 1038 - trloss = 2.550, (2.502 sec/step)
# step 1039 - trloss = 2.590, (2.501 sec/step)
# step 1040 - trloss = 2.619, (2.501 sec/step)
# step 1041 - trloss = 2.579, (2.502 sec/step)
# step 1042 - trloss = 2.539, (2.500 sec/step)
# step 1043 - trloss = 2.596, (2.502 sec/step)
# step 1044 - trloss = 2.533, (2.502 sec/step)
# step 1045 - trloss = 2.603, (2.501 sec/step)
# step 1046 - trloss = 2.495, (2.499 sec/step)
# step 1047 - trloss = 2.597, (2.499 sec/step)
# step 1048 - trloss = 2.518, (2.507 sec/step)
# step 1049 - trloss = 2.560, (2.501 sec/step)
# step 1050 - trloss = 2.506, (2.499 sec/step)
# stored done
# validateLoss = 7.403, (2.499 sec/step)
# step 1051 - trloss = 2.557, (2.501 sec/step)
# step 1052 - trloss = 2.518, (2.500 sec/step)
# step 1053 - trloss = 2.531, (2.501 sec/step)
# step 1054 - trloss = 2.495, (2.501 sec/step)
# step 1055 - trloss = 2.535, (2.500 sec/step)
# step 1056 - trloss = 2.484, (2.501 sec/step)
# step 1057 - trloss = 2.564, (2.502 sec/step)
# step 1058 - trloss = 2.477, (2.508 sec/step)
# ...
# step 14843 - trloss = 1.975, (2.501 sec/step)
# step 14844 - trloss = 1.997, (2.502 sec/step)
# step 14845 - trloss = 1.939, (2.501 sec/step)
# step 14846 - trloss = 1.986, (2.501 sec/step)
# step 14847 - trloss = 1.974, (2.501 sec/step)
# step 14848 - trloss = 1.959, (2.499 sec/step)
# step 14849 - trloss = 1.967, (2.499 sec/step)
# step 14850 - trloss = 1.992, (2.499 sec/step)
# stored done
# validateLoss = 21.872, (2.499 sec/step)
# step 14851 - trloss = 1.961, (2.501 sec/step)
# step 14852 - trloss = 1.975, (2.499 sec/step)
# step 14853 - trloss = 1.967, (2.499 sec/step)
# step 14854 - trloss = 1.983, (2.498 sec/step)
# step 14855 - trloss = 1.974, (2.499 sec/step)
# step 14856 - trloss = 1.983, (2.498 sec/step)
# step 14857 - trloss = 1.983, (2.496 sec/step)
# step 14858 - trloss = 1.982, (2.497 sec/step)
# step 14859 - trloss = 1.955, (2.498 sec/step)
# step 14860 - trloss = 1.995, (2.498 sec/step)
# step 14861 - trloss = 1.993, (2.497 sec/step)
# step 14862 - trloss = 1.958, (2.496 sec/step)
# step 14863 - trloss = 1.997, (2.497 sec/step)
# step 14864 - trloss = 2.003, (2.497 sec/step)
# step 14865 - trloss = 1.934, (2.495 sec/step)
# step 14866 - trloss = 2.002, (2.495 sec/step)
# step 14867 - trloss = 2.013, (2.495 sec/step)
# step 14868 - trloss = 1.940, (2.494 sec/step)
# step 14869 - trloss = 2.002, (2.495 sec/step)
# step 14870 - trloss = 2.016, (2.495 sec/step)
# step 14871 - trloss = 1.924, (2.495 sec/step)
# step 14872 - trloss = 2.001, (2.495 sec/step)
# step 14873 - trloss = 2.016, (2.496 sec/step)
# step 14874 - trloss = 1.943, (2.502 sec/step)
# step 14875 - trloss = 2.018, (2.496 sec/step)
# step 14876 - trloss = 2.008, (2.496 sec/step)
# step 14877 - trloss = 1.936, (2.497 sec/step)
# step 14878 - trloss = 2.008, (2.497 sec/step)
# step 14879 - trloss = 1.994, (2.497 sec/step)
# step 14880 - trloss = 1.967, (2.498 sec/step)
# step 14881 - trloss = 2.022, (2.498 sec/step)
# step 14882 - trloss = 1.982, (2.498 sec/step)
# step 14883 - trloss = 1.958, (2.501 sec/step)
# step 14884 - trloss = 2.009, (2.503 sec/step)
# step 14885 - trloss = 1.955, (2.501 sec/step)
# step 14886 - trloss = 1.987, (2.501 sec/step)
# step 14887 - trloss = 2.012, (2.500 sec/step)
# step 14888 - trloss = 1.943, (2.501 sec/step)
# step 14889 - trloss = 1.973, (2.502 sec/step)
# step 14890 - trloss = 2.001, (2.500 sec/step)
# step 14891 - trloss = 1.921, (2.501 sec/step)
# step 14892 - trloss = 1.981, (2.501 sec/step)
# step 14893 - trloss = 1.989, (2.502 sec/step)
# step 14894 - trloss = 1.937, (2.501 sec/step)
# step 14895 - trloss = 1.973, (2.501 sec/step)
# step 14896 - trloss = 1.989, (2.502 sec/step)
# step 14897 - trloss = 1.932, (2.501 sec/step)
# step 14898 - trloss = 1.974, (2.502 sec/step)
# step 14899 - trloss = 1.963, (2.502 sec/step)
# step 14900 - trloss = 1.965, (2.501 sec/step)
# stored done
# validateLoss = 22.571, (2.501 sec/step)
# step 14901 - trloss = 1.981, (2.502 sec/step)
# step 14902 - trloss = 1.955, (2.501 sec/step)
# step 14903 - trloss = 1.966, (2.502 sec/step)
# step 14904 - trloss = 1.984, (2.502 sec/step)
# step 14905 - trloss = 1.925, (2.512 sec/step)
# step 14906 - trloss = 1.980, (2.502 sec/step)
# step 14907 - trloss = 1.998, (2.502 sec/step)
# step 14908 - trloss = 1.929, (2.502 sec/step)
# step 14909 - trloss = 1.967, (2.501 sec/step)
# step 14910 - trloss = 1.992, (2.501 sec/step)
# step 14911 - trloss = 1.914, (2.502 sec/step)
# step 14912 - trloss = 1.964, (2.509 sec/step)
# step 14913 - trloss = 1.989, (2.502 sec/step)
# step 14914 - trloss = 1.933, (2.501 sec/step)
# step 14915 - trloss = 1.964, (2.500 sec/step)
# step 14916 - trloss = 1.970, (2.500 sec/step)
# step 14917 - trloss = 1.923, (2.501 sec/step)
# step 14918 - trloss = 1.972, (2.500 sec/step)
# step 14919 - trloss = 1.961, (2.500 sec/step)
# step 14920 - trloss = 1.937, (2.499 sec/step)
# step 14921 - trloss = 1.981, (2.502 sec/step)
# step 14922 - trloss = 1.955, (2.501 sec/step)
# step 14923 - trloss = 1.919, (2.498 sec/step)
# step 14924 - trloss = 1.990, (2.499 sec/step)
# step 14925 - trloss = 1.953, (2.500 sec/step)
# step 14926 - trloss = 1.933, (2.499 sec/step)
# step 14927 - trloss = 1.992, (2.500 sec/step)
# step 14928 - trloss = 1.961, (2.499 sec/step)
# step 14929 - trloss = 1.925, (2.500 sec/step)
# step 14930 - trloss = 1.982, (2.501 sec/step)
# step 14931 - trloss = 1.947, (2.501 sec/step)
# step 14932 - trloss = 1.941, (2.501 sec/step)
# step 14933 - trloss = 1.985, (2.504 sec/step)
# step 14934 - trloss = 1.953, (2.500 sec/step)
# step 14935 - trloss = 1.931, (2.500 sec/step)
# step 14936 - trloss = 1.981, (2.508 sec/step)
# step 14937 - trloss = 1.937, (2.502 sec/step)
# step 14938 - trloss = 1.941, (2.501 sec/step)
# step 14939 - trloss = 1.994, (2.501 sec/step)
# step 14940 - trloss = 1.944, (2.504 sec/step)
# step 14941 - trloss = 1.929, (2.503 sec/step)
# step 14942 - trloss = 1.974, (2.503 sec/step)
# step 14943 - trloss = 1.933, (2.503 sec/step)
# step 14944 - trloss = 1.940, (2.503 sec/step)
# step 14945 - trloss = 1.974, (2.502 sec/step)
# step 14946 - trloss = 1.933, (2.502 sec/step)
# step 14947 - trloss = 1.932, (2.502 sec/step)
# step 14948 - trloss = 1.974, (2.503 sec/step)
# step 14949 - trloss = 1.921, (2.503 sec/step)
# step 14950 - trloss = 1.943, (2.501 sec/step)
# stored done
# validateLoss = 22.371, (2.501 sec/step)
# step 14951 - trloss = 1.974, (2.502 sec/step)
# step 14952 - trloss = 1.932, (2.500 sec/step)
# step 14953 - trloss = 1.937, (2.501 sec/step)
# step 14954 - trloss = 1.959, (2.502 sec/step)
# step 14955 - trloss = 1.921, (2.502 sec/step)
# step 14956 - trloss = 1.942, (2.501 sec/step)
# step 14957 - trloss = 1.942, (2.501 sec/step)
# step 14958 - trloss = 1.926, (2.499 sec/step)
# step 14959 - trloss = 1.945, (2.499 sec/step)
# step 14960 - trloss = 1.948, (2.498 sec/step)
# step 14961 - trloss = 1.909, (2.498 sec/step)
# step 14962 - trloss = 1.947, (2.497 sec/step)
# step 14963 - trloss = 1.953, (2.499 sec/step)
# step 14964 - trloss = 1.924, (2.498 sec/step)
# step 14965 - trloss = 1.935, (2.498 sec/step)
# step 14966 - trloss = 1.943, (2.500 sec/step)
# step 14967 - trloss = 1.923, (2.499 sec/step)
# step 14968 - trloss = 1.943, (2.500 sec/step)
# step 14969 - trloss = 1.938, (2.502 sec/step)
# step 14970 - trloss = 1.924, (2.501 sec/step)
# step 14971 - trloss = 1.931, (2.500 sec/step)
# step 14972 - trloss = 1.960, (2.502 sec/step)
# step 14973 - trloss = 1.933, (2.500 sec/step)
# step 14974 - trloss = 1.942, (2.502 sec/step)
# step 14975 - trloss = 1.939, (2.502 sec/step)
# step 14976 - trloss = 1.960, (2.500 sec/step)
# step 14977 - trloss = 1.943, (2.501 sec/step)
# step 14978 - trloss = 1.933, (2.499 sec/step)
# step 14979 - trloss = 1.931, (2.502 sec/step)
# step 14980 - trloss = 1.959, (2.500 sec/step)
# step 14981 - trloss = 1.936, (2.501 sec/step)
# step 14982 - trloss = 1.948, (2.506 sec/step)
# step 14983 - trloss = 1.943, (2.501 sec/step)
# step 14984 - trloss = 1.942, (2.501 sec/step)
# step 14985 - trloss = 1.980, (2.503 sec/step)
# step 14986 - trloss = 1.975, (2.500 sec/step)
# step 14987 - trloss = 1.942, (2.501 sec/step)
# step 14988 - trloss = 1.985, (2.499 sec/step)
# step 14989 - trloss = 1.981, (2.501 sec/step)
# step 14990 - trloss = 1.979, (2.502 sec/step)
# step 14991 - trloss = 2.013, (2.505 sec/step)
# step 14992 - trloss = 1.977, (2.501 sec/step)
# step 14993 - trloss = 1.947, (2.501 sec/step)
# step 14994 - trloss = 2.053, (2.501 sec/step)
# step 14995 - trloss = 2.005, (2.502 sec/step)
# step 14996 - trloss = 1.947, (2.500 sec/step)
# step 14997 - trloss = 2.055, (2.500 sec/step)
# step 14998 - trloss = 1.992, (2.501 sec/step)
# step 14999 - trloss = 2.006, (2.499 sec/step)
# step 15000 - trloss = 2.048, (2.498 sec/step)
# stored done
# validateLoss = 22.667, (2.498 sec/step)
# step 15001 - trloss = 1.942, (2.499 sec/step)
# step 15002 - trloss = 1.994, (2.498 sec/step)
# step 15003 - trloss = 2.080, (2.498 sec/step)
# step 15004 - trloss = 1.997, (2.499 sec/step)
# step 15005 - trloss = 2.070, (2.499 sec/step)
# step 15006 - trloss = 2.010, (2.498 sec/step)
# step 15007 - trloss = 1.976, (2.498 sec/step)
# step 15008 - trloss = 2.110, (2.499 sec/step)
# step 15009 - trloss = 1.988, (2.499 sec/step)
# step 15010 - trloss = 1.955, (2.499 sec/step)
# step 15011 - trloss = 2.045, (2.499 sec/step)
# step 15012 - trloss = 1.995, (2.498 sec/step)
# step 15013 - trloss = 2.027, (2.498 sec/step)
# step 15014 - trloss = 1.970, (2.500 sec/step)
# step 15015 - trloss = 1.954, (2.500 sec/step)
# step 15016 - trloss = 2.031, (2.500 sec/step)
# step 15017 - trloss = 1.979, (2.501 sec/step)
# step 15018 - trloss = 1.963, (2.500 sec/step)
# step 15019 - trloss = 1.963, (2.501 sec/step)
# step 15020 - trloss = 1.983, (2.502 sec/step)
# step 15021 - trloss = 2.014, (2.502 sec/step)
# step 15022 - trloss = 1.964, (2.501 sec/step)
# step 15023 - trloss = 1.942, (2.505 sec/step)
# step 15024 - trloss = 2.018, (2.503 sec/step)
# step 15025 - trloss = 1.971, (2.502 sec/step)
# step 15026 - trloss = 1.991, (2.502 sec/step)
# step 15027 - trloss = 1.947, (2.501 sec/step)
# step 15028 - trloss = 1.960, (2.501 sec/step)
# step 15029 - trloss = 2.052, (2.502 sec/step)
# step 15030 - trloss = 1.985, (2.501 sec/step)
# step 15031 - trloss = 1.959, (2.503 sec/step)
# step 15032 - trloss = 1.995, (2.501 sec/step)
# step 15033 - trloss = 1.989, (2.502 sec/step)
# step 15034 - trloss = 2.049, (2.501 sec/step)
# step 15035 - trloss = 1.994, (2.500 sec/step)
# step 15036 - trloss = 1.935, (2.502 sec/step)
# step 15037 - trloss = 2.061, (2.501 sec/step)
# step 15038 - trloss = 2.013, (2.507 sec/step)
# step 15039 - trloss = 1.990, (2.501 sec/step)
# step 15040 - trloss = 1.966, (2.500 sec/step)
# step 15041 - trloss = 1.978, (2.501 sec/step)
# step 15042 - trloss = 2.013, (2.500 sec/step)
# step 15043 - trloss = 1.953, (2.500 sec/step)
# step 15044 - trloss = 1.931, (2.501 sec/step)
# step 15045 - trloss = 1.990, (2.501 sec/step)
# step 15046 - trloss = 1.989, (2.501 sec/step)
# step 15047 - trloss = 1.972, (2.500 sec/step)
# step 15048 - trloss = 1.930, (2.501 sec/step)
# step 15049 - trloss = 1.970, (2.498 sec/step)
# step 15050 - trloss = 2.014, (2.498 sec/step)
# stored done
# validateLoss = 22.599, (2.498 sec/step)
# step 15051 - trloss = 1.958, (2.499 sec/step)
# step 15052 - trloss = 1.926, (2.499 sec/step)
# step 15053 - trloss = 1.985, (2.497 sec/step)
# step 15054 - trloss = 1.991, (2.497 sec/step)
# step 15055 - trloss = 2.004, (2.498 sec/step)
# step 15056 - trloss = 1.933, (2.497 sec/step)
# step 15057 - trloss = 1.973, (2.496 sec/step)
# step 15058 - trloss = 2.008, (2.498 sec/step)
# step 15059 - trloss = 1.965, (2.497 sec/step)
# step 15060 - trloss = 1.936, (2.497 sec/step)
# step 15061 - trloss = 1.949, (2.496 sec/step)
# step 15062 - trloss = 2.003, (2.498 sec/step)
# step 15063 - trloss = 1.999, (2.497 sec/step)
# step 15064 - trloss = 1.931, (2.500 sec/step)
# step 15065 - trloss = 1.948, (2.499 sec/step)
# step 15066 - trloss = 2.046, (2.499 sec/step)
# step 15067 - trloss = 1.955, (2.500 sec/step)
# step 15068 - trloss = 1.926, (2.499 sec/step)
# step 15069 - trloss = 1.946, (2.500 sec/step)
# step 15070 - trloss = 2.004, (2.502 sec/step)
# step 15071 - trloss = 1.987, (2.503 sec/step)
# step 15072 - trloss = 1.919, (2.502 sec/step)
# step 15073 - trloss = 1.949, (2.501 sec/step)
# step 15074 - trloss = 2.024, (2.501 sec/step)
# step 15075 - trloss = 1.975, (2.509 sec/step)
# step 15076 - trloss = 1.929, (2.501 sec/step)
# step 15077 - trloss = 1.962, (2.501 sec/step)
# step 15078 - trloss = 2.039, (2.502 sec/step)
# step 15079 - trloss = 2.014, (2.503 sec/step)
# step 15080 - trloss = 1.924, (2.502 sec/step)
# step 15081 - trloss = 1.977, (2.500 sec/step)
# step 15082 - trloss = 2.081, (2.500 sec/step)
# step 15083 - trloss = 1.994, (2.501 sec/step)
# step 15084 - trloss = 1.938, (2.501 sec/step)
# step 15085 - trloss = 1.991, (2.500 sec/step)
# step 15086 - trloss = 2.054, (2.501 sec/step)
# step 15087 - trloss = 2.000, (2.502 sec/step)
# step 15088 - trloss = 1.935, (2.501 sec/step)
# step 15089 - trloss = 2.034, (2.502 sec/step)
# step 15090 - trloss = 2.072, (2.502 sec/step)
# step 15091 - trloss = 1.966, (2.502 sec/step)
# step 15092 - trloss = 1.976, (2.508 sec/step)
# step 15093 - trloss = 2.113, (2.500 sec/step)
# step 15094 - trloss = 2.017, (2.507 sec/step)
# step 15095 - trloss = 2.048, (2.500 sec/step)
# step 15096 - trloss = 2.041, (2.500 sec/step)
# step 15097 - trloss = 2.036, (2.499 sec/step)
# step 15098 - trloss = 2.082, (2.498 sec/step)
# step 15099 - trloss = 2.089, (2.508 sec/step)
# step 15100 - trloss = 2.011, (2.500 sec/step)
# stored done
# validateLoss = 22.758, (2.500 sec/step)
# step 15101 - trloss = 2.123, (2.500 sec/step)
# step 15102 - trloss = 2.102, (2.499 sec/step)
# step 15103 - trloss = 2.009, (2.498 sec/step)
# step 15104 - trloss = 2.058, (2.498 sec/step)
# step 15105 - trloss = 2.194, (2.498 sec/step)
# step 15106 - trloss = 2.045, (2.499 sec/step)
# step 15107 - trloss = 2.004, (2.499 sec/step)
# step 15108 - trloss = 2.229, (2.500 sec/step)
# step 15109 - trloss = 2.130, (2.500 sec/step)
# step 15110 - trloss = 2.057, (2.507 sec/step)
# step 15111 - trloss = 2.298, (2.501 sec/step)
# step 15112 - trloss = 2.166, (2.500 sec/step)
# step 15113 - trloss = 2.167, (2.500 sec/step)
# step 15114 - trloss = 2.263, (2.501 sec/step)
# step 15115 - trloss = 2.109, (2.500 sec/step)
# step 15116 - trloss = 2.294, (2.501 sec/step)
# step 15117 - trloss = 2.230, (2.501 sec/step)
# step 15118 - trloss = 2.140, (2.501 sec/step)
# step 15119 - trloss = 2.408, (2.502 sec/step)
# step 15120 - trloss = 2.100, (2.500 sec/step)
# step 15121 - trloss = 2.200, (2.501 sec/step)
# step 15122 - trloss = 2.313, (2.502 sec/step)
# step 15123 - trloss = 2.206, (2.501 sec/step)
# step 15124 - trloss = 2.227, (2.502 sec/step)
# step 15125 - trloss = 2.353, (2.503 sec/step)
# step 15126 - trloss = 2.146, (2.499 sec/step)
# step 15127 - trloss = 2.114, (2.501 sec/step)
# step 15128 - trloss = 2.168, (2.501 sec/step)
# step 15129 - trloss = 2.099, (2.501 sec/step)
# step 15130 - trloss = 2.069, (2.501 sec/step)
# step 15131 - trloss = 2.131, (2.502 sec/step)
# step 15132 - trloss = 2.140, (2.500 sec/step)
# step 15133 - trloss = 2.067, (2.500 sec/step)
# step 15134 - trloss = 2.196, (2.500 sec/step)
# step 15135 - trloss = 2.189, (2.499 sec/step)
# step 15136 - trloss = 2.023, (2.501 sec/step)
# step 15137 - trloss = 2.196, (2.499 sec/step)
# step 15138 - trloss = 2.069, (2.498 sec/step)
# step 15139 - trloss = 2.068, (2.500 sec/step)
# step 15140 - trloss = 2.091, (2.499 sec/step)
# step 15141 - trloss = 2.072, (2.500 sec/step)
# step 15142 - trloss = 2.051, (2.499 sec/step)
# step 15143 - trloss = 2.057, (2.499 sec/step)
# step 15144 - trloss = 2.088, (2.498 sec/step)
# step 15145 - trloss = 2.057, (2.506 sec/step)
# step 15146 - trloss = 2.023, (2.499 sec/step)
# step 15147 - trloss = 2.094, (2.499 sec/step)
# step 15148 - trloss = 2.010, (2.496 sec/step)
# step 15149 - trloss = 2.031, (2.497 sec/step)
# step 15150 - trloss = 2.047, (2.504 sec/step)
# stored done
# validateLoss = 22.509, (2.504 sec/step)
# step 15151 - trloss = 2.001, (2.498 sec/step)
# step 15152 - trloss = 2.025, (2.498 sec/step)
# step 15153 - trloss = 2.001, (2.497 sec/step)
# step 15154 - trloss = 2.103, (2.498 sec/step)
# step 15155 - trloss = 1.988, (2.499 sec/step)
# step 15156 - trloss = 2.075, (2.499 sec/step)
# step 15157 - trloss = 2.101, (2.498 sec/step)
# step 15158 - trloss = 1.972, (2.499 sec/step)
# step 15159 - trloss = 2.068, (2.499 sec/step)
# step 15160 - trloss = 2.029, (2.500 sec/step)
# step 15161 - trloss = 2.000, (2.500 sec/step)
# step 15162 - trloss = 1.987, (2.500 sec/step)
# step 15163 - trloss = 2.027, (2.501 sec/step)
# step 15164 - trloss = 1.974, (2.501 sec/step)
# step 15165 - trloss = 1.946, (2.508 sec/step)
# step 15166 - trloss = 2.048, (2.501 sec/step)
# step 15167 - trloss = 1.945, (2.501 sec/step)
# step 15168 - trloss = 1.986, (2.502 sec/step)
# step 15169 - trloss = 1.993, (2.503 sec/step)
# step 15170 - trloss = 2.018, (2.502 sec/step)
# step 15171 - trloss = 1.947, (2.503 sec/step)
# step 15172 - trloss = 2.019, (2.512 sec/step)
# step 15173 - trloss = 2.004, (2.505 sec/step)
# step 15174 - trloss = 1.967, (2.502 sec/step)
# step 15175 - trloss = 1.975, (2.502 sec/step)
# step 15176 - trloss = 2.094, (2.503 sec/step)
# step 15177 - trloss = 1.946, (2.502 sec/step)
# step 15178 - trloss = 2.049, (2.502 sec/step)
# step 15179 - trloss = 2.059, (2.503 sec/step)
# step 15180 - trloss = 2.009, (2.503 sec/step)
# step 15181 - trloss = 2.031, (2.502 sec/step)

# %%
from IPython.display import clear_output, Image, display, HTML

def strip_consts(graph_def, max_const_size=32):
    """Strip large constant values from graph_def."""
    strip_def = tf.GraphDef()
    for n0 in graph_def.node:
        n = strip_def.node.add() 
        n.MergeFrom(n0)
        if n.op == 'Const':
            tensor = n.attr['value'].tensor
            size = len(tensor.tensor_content)
            if size > max_const_size:
                tensor.tensor_content = bytes("<stripped %d bytes>"%max_const_size, 'utf-8')
                
    return strip_def

def show_graph(graph_def, max_const_size=32):
    """Visualize TensorFlow graph."""
    if hasattr(graph_def, 'as_graph_def'):
        graph_def = graph_def.as_graph_def()
    strip_def = strip_consts(graph_def, max_const_size=max_const_size)
    code = """
        <script>
          function load() {{
            document.getElementById("{id}").pbtxt = {data};
          }}
        </script>
        <link rel="import" href="https://tensorboard.appspot.com/tf-graph-basic.build.html" onload=load()>
        <div style="height:600px">
          <tf-graph-basic id="{id}"></tf-graph-basic>
        </div>
    """.format(data=repr(str(strip_def)), id='graph'+str(np.random.rand()))

    iframe = """
        <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="{}"></iframe>
    """.format(code.replace('"', '&quot;'))
    display(HTML(iframe))

# %%
show_graph(tf.get_default_graph().as_graph_def())
