# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import torch.utils.data as utils
import librosa
import soundfile as sf
import time
import os

# %%
sampleSize=150000
sample_rate=16000
quantization_channels=256
dilations=[2**i for i in range(9)]*3
skipDim=512
residualDim=32
filterSize=3

# %%
#os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
use_cuda = torch.cuda.is_available()
torch.manual_seed(1)
device = torch.device("cuda" if use_cuda else "cpu")
#device = 'cpu'
torch.set_default_tensor_type('torch.cuda.FloatTensor')
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
def mu_law_encode(audio, quantization_channels=quantization_channels):
    '''Quantizes waveform amplitudes.'''
    mu = (quantization_channels - 1)*1.0
    # Perform mu-law companding transformation (ITU-T, 1988).
    # Minimum operation is here to deal with rare large amplitudes caused
    # by resampling.
    safe_audio_abs = np.minimum(np.abs(audio), 1.0)
    magnitude = np.log1p(mu * safe_audio_abs) / np.log1p(mu)
    signal = np.sign(audio) * magnitude
    # Quantize signal to the specified number of levels.
    #if(forX):return signal
    return ((signal + 1) / 2 * mu + 0.5).astype(int)
def mu_law_decode(output, quantization_channels=quantization_channels):
    '''Recovers waveform from quantized values.'''
    mu = quantization_channels - 1
    # Map values back to [-1, 1].
    signal = 2 * ((output*1.0) / mu) - 1
    # Perform inverse of mu-law transformation.
    magnitude = (1 / mu) * ((1 + mu)**np.abs(signal) - 1)
    return np.sign(signal) * magnitude

# %%
def readAudio(name):
    audio0, samplerate = sf.read(name, dtype='float32')
    return librosa.resample(audio0.T, samplerate, sample_rate).reshape(-1)
p=['./vsCorpus/origin_mix.wav','./vsCorpus/origin_vocal.wav',
   './vsCorpus/origin_mix.wav','./vsCorpus/origin_vocal.wav','./vsCorpus/pred_mix.wav']
xtrain,ytrain,xval,yval,xtest=readAudio(p[0]),readAudio(p[1]),readAudio(p[2]),readAudio(p[3]),readAudio(p[4])
assert((xtrain==xval).all())
assert((ytrain==yval).all())
assert((xtrain != ytrain).any())
#xtrain,ytrain,xval,yval=xtrain[:-sampleSize],ytrain[:-sampleSize],xval[-sampleSize:],yval[-sampleSize:]
xtrain,ytrain,xval,yval=xtrain[:-sampleSize],ytrain[:-sampleSize],xval[:sampleSize],yval[:sampleSize]
xtrain,xval,xtest=xtrain.reshape(1,1,-1),xval.reshape(1,1,-1),xtest.reshape(1,1,-1)
ytrain,yval=ytrain.reshape(1,-1),yval.reshape(1,-1)

# %%
xmean,xstd = xtrain.mean(),xtrain.std()
xtrain=(xtrain-xmean)/xstd
xval=(xval-xmean)/xstd
xtest=(xtest-xmean)/xstd
ytrain,yval=mu_law_encode(ytrain),mu_law_encode(yval)

# %%
xtrain,ytrain,xval,yval,xtest = torch.from_numpy(xtrain).type(torch.float32),\
                                torch.from_numpy(ytrain).type(torch.LongTensor),\
                                torch.from_numpy(xval).type(torch.float32),\
                                torch.from_numpy(yval).type(torch.LongTensor),\
                                torch.from_numpy(xtest).type(torch.float32)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        sd,qd,rd = skipDim,quantization_channels,residualDim
        self.causal = nn.Conv1d(in_channels=1,out_channels=rd,kernel_size=3,padding=1)
        self.layer=dict()
        for i, d in enumerate(dilations):
            self.layer['tanh'+str(i)] = nn.Conv1d(in_channels=rd,out_channels=rd,kernel_size=3,padding=d,dilation=d)
            self.layer['sigmoid'+str(i)] = nn.Conv1d(in_channels=rd,out_channels=rd,kernel_size=3,padding=d,dilation=d)
            self.layer['skip'+str(i)] = nn.Conv1d(in_channels=rd,out_channels=sd,kernel_size=1,padding=0)
            self.layer['dense'+str(i)] = nn.Conv1d(in_channels=rd,out_channels=rd,kernel_size=1,padding=0)
        self.post1 = nn.Conv1d(in_channels=sd,out_channels=sd,kernel_size=1,padding=0)
        self.post2 = nn.Conv1d(in_channels=sd,out_channels=qd,kernel_size=1,padding=0)
        self.tanh,self.sigmoid = nn.Tanh(),nn.Sigmoid()

    def forward(self, x):
        x = self.causal(x)
        #print('x.shape',x.shape)
        skip_connections = torch.zeros([1,skipDim,x.shape[2]],dtype=torch.float32,device=device)
        #skip_connections = []
        #print('skip_connections',skip_connections.shape)
        for i, dilation in enumerate(dilations):
            xinput = x.clone()
            x1 = self.tanh(self.layer['tanh'+str(i)](x))
            #print('tanh.shape',x1.shape)
            x2 = self.sigmoid(self.layer['sigmoid'+str(i)](x))
            #print('sigmoid.shape',x2.shape)
            x = x1*x2
            #print('multi',x3.shape)
            skip_connections += self.layer['skip'+str(i)](x)
            #print(skip_connections.cpu()[:,:,:10])
            #cur =self.layer['skip'+str(i)](x3)
            #skip_connections.append(cur)
            #print('skip.shape',self.layer['skip'+str(i)](x).shape)
            x = self.layer['dense'+str(i)](x)
            #print('dense.shape',x.shape)
            x += xinput
        #skip_connections = torch.cat(skip_connections,dim=0)
        #skip_connections = torch.sum(skip_connections,dim=0,keepdim=True)
        x = self.post2(F.relu(self.post1(F.relu(skip_connections))))
        return x

model = Net().cuda()
criterion = nn.CrossEntropyLoss().cuda()
#optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)
optimizer = optim.Adam(model.parameters(),weight_decay=1e-5)

# %%
#torch.sum(c,dim=0,keepdim=True)

# %%
#model = torch.load('torchmodel0.681600')

# %%
def val():
    model.eval()
    startval_time = time.time()
    with torch.no_grad():
        data, target = xval.to(device), yval.to(device)
        output = model(data)
        #print(output.shape)
        #print(output[:,:,:10])
        val_loss = criterion(output, target).item()
    print('\nval set:  {:.4f}, ({:.3f} sec/step)\n'.format(val_loss,time.time()-startval_time))

def test():
    model.eval()
    startval_time = time.time()
    with torch.no_grad():
        output = model(xtest.to(device))
        pred = output.max(1, keepdim=True)[1].cpu().numpy().reshape(-1)
        ans = mu_law_decode(pred)
        sf.write('./vsCorpus/resultxte.wav', ans, sample_rate)
        
        output = model(xtrain[:,:,:sampleSize].to(device))
        pred = output.max(1, keepdim=True)[1].cpu().numpy().reshape(-1)
        ans = mu_law_decode(pred)
        sf.write('./vsCorpus/resultxtr.wav', ans, sample_rate)
        print('stored done\n')
    
def train(epoch):
    model.train()
    #idx = np.arange(xtrain.shape[-1] - 2 * sampleSize)
    #np.random.shuffle(idx)
    idx = np.array([0]*100000)
    for i, ind in enumerate(idx):
        start_time = time.time()
        data, target = xtrain[:,:,ind:ind+sampleSize].to(device), ytrain[:,ind:ind+sampleSize].to(device)
        output = model(data)
        #print(output.shape)
        #print(output[:,:,:10])
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print('Train Epoch: {} [{}/{} ({:.0f}%)] Loss: {:.6f} , ({:.3f} sec/step)'.format(
                epoch, i, len(idx),100. * i / len(idx), loss.item(),time.time() - start_time))
        if i % 100 == 0:
            val()
            test()
            torch.save(model, 'loss3.94')

# %%
for epoch in range(1000):
    train(epoch)
    test()
# Out:
# Train Epoch: 0 [0/100000 (0%)] Loss: 5.559445 , (1.757 sec/step)
#
# val set:  5.4981, (0.677 sec/step)
#
# stored done
#
# Train Epoch: 0 [1/100000 (0%)] Loss: 5.498137 , (1.746 sec/step)
# Train Epoch: 0 [2/100000 (0%)] Loss: 5.442373 , (1.751 sec/step)
# Train Epoch: 0 [3/100000 (0%)] Loss: 5.388351 , (1.747 sec/step)
# Train Epoch: 0 [4/100000 (0%)] Loss: 5.340143 , (1.750 sec/step)
# Train Epoch: 0 [5/100000 (0%)] Loss: 5.297835 , (1.748 sec/step)
# Train Epoch: 0 [6/100000 (0%)] Loss: 5.258235 , (1.748 sec/step)
# Train Epoch: 0 [7/100000 (0%)] Loss: 5.219187 , (1.748 sec/step)
# Train Epoch: 0 [8/100000 (0%)] Loss: 5.180876 , (1.749 sec/step)
# Train Epoch: 0 [9/100000 (0%)] Loss: 5.145457 , (1.750 sec/step)
# Train Epoch: 0 [10/100000 (0%)] Loss: 5.113795 , (1.750 sec/step)
# Train Epoch: 0 [11/100000 (0%)] Loss: 5.085248 , (1.749 sec/step)
# Train Epoch: 0 [12/100000 (0%)] Loss: 5.058821 , (1.750 sec/step)
# Train Epoch: 0 [13/100000 (0%)] Loss: 5.033510 , (1.753 sec/step)
# Train Epoch: 0 [14/100000 (0%)] Loss: 5.008384 , (1.754 sec/step)
# Train Epoch: 0 [15/100000 (0%)] Loss: 4.983163 , (1.754 sec/step)
# Train Epoch: 0 [16/100000 (0%)] Loss: 4.958333 , (1.754 sec/step)
# Train Epoch: 0 [17/100000 (0%)] Loss: 4.934500 , (1.755 sec/step)
# Train Epoch: 0 [18/100000 (0%)] Loss: 4.911452 , (1.755 sec/step)
# Train Epoch: 0 [19/100000 (0%)] Loss: 4.888411 , (1.752 sec/step)
# Train Epoch: 0 [20/100000 (0%)] Loss: 4.865621 , (1.756 sec/step)
# Train Epoch: 0 [21/100000 (0%)] Loss: 4.843948 , (1.754 sec/step)
# Train Epoch: 0 [22/100000 (0%)] Loss: 4.823605 , (1.755 sec/step)
# Train Epoch: 0 [23/100000 (0%)] Loss: 4.804430 , (1.754 sec/step)
# Train Epoch: 0 [24/100000 (0%)] Loss: 4.786958 , (1.756 sec/step)
# Train Epoch: 0 [25/100000 (0%)] Loss: 4.771406 , (1.757 sec/step)
# Train Epoch: 0 [26/100000 (0%)] Loss: 4.757083 , (1.756 sec/step)
# Train Epoch: 0 [27/100000 (0%)] Loss: 4.743572 , (1.757 sec/step)
# Train Epoch: 0 [28/100000 (0%)] Loss: 4.730828 , (1.756 sec/step)
# Train Epoch: 0 [29/100000 (0%)] Loss: 4.718555 , (1.756 sec/step)
# Train Epoch: 0 [30/100000 (0%)] Loss: 4.706491 , (1.756 sec/step)
# Train Epoch: 0 [31/100000 (0%)] Loss: 4.694742 , (1.756 sec/step)
# Train Epoch: 0 [32/100000 (0%)] Loss: 4.683586 , (1.758 sec/step)
# Train Epoch: 0 [33/100000 (0%)] Loss: 4.673155 , (1.756 sec/step)
# Train Epoch: 0 [34/100000 (0%)] Loss: 4.663564 , (1.757 sec/step)
# Train Epoch: 0 [35/100000 (0%)] Loss: 4.654751 , (1.757 sec/step)
# Train Epoch: 0 [36/100000 (0%)] Loss: 4.646320 , (1.757 sec/step)
# Train Epoch: 0 [37/100000 (0%)] Loss: 4.638098 , (1.759 sec/step)
# Train Epoch: 0 [38/100000 (0%)] Loss: 4.630239 , (1.757 sec/step)
# Train Epoch: 0 [39/100000 (0%)] Loss: 4.622830 , (1.758 sec/step)
# Train Epoch: 0 [40/100000 (0%)] Loss: 4.615687 , (1.760 sec/step)
# Train Epoch: 0 [41/100000 (0%)] Loss: 4.608788 , (1.759 sec/step)
# Train Epoch: 0 [42/100000 (0%)] Loss: 4.602182 , (1.758 sec/step)
# Train Epoch: 0 [43/100000 (0%)] Loss: 4.595901 , (1.758 sec/step)
# Train Epoch: 0 [44/100000 (0%)] Loss: 4.590016 , (1.758 sec/step)
# Train Epoch: 0 [45/100000 (0%)] Loss: 4.584381 , (1.756 sec/step)
# Train Epoch: 0 [46/100000 (0%)] Loss: 4.579106 , (1.760 sec/step)
# Train Epoch: 0 [47/100000 (0%)] Loss: 4.574015 , (1.759 sec/step)
# Train Epoch: 0 [48/100000 (0%)] Loss: 4.569075 , (1.758 sec/step)
# Train Epoch: 0 [49/100000 (0%)] Loss: 4.564342 , (1.760 sec/step)
# Train Epoch: 0 [50/100000 (0%)] Loss: 4.559710 , (1.758 sec/step)
# Train Epoch: 0 [51/100000 (0%)] Loss: 4.555229 , (1.760 sec/step)
# Train Epoch: 0 [52/100000 (0%)] Loss: 4.550961 , (1.758 sec/step)
# Train Epoch: 0 [53/100000 (0%)] Loss: 4.546828 , (1.760 sec/step)
# Train Epoch: 0 [54/100000 (0%)] Loss: 4.542875 , (1.760 sec/step)
# Train Epoch: 0 [55/100000 (0%)] Loss: 4.539032 , (1.760 sec/step)
# Train Epoch: 0 [56/100000 (0%)] Loss: 4.535228 , (1.758 sec/step)
# Train Epoch: 0 [57/100000 (0%)] Loss: 4.531525 , (1.759 sec/step)
# Train Epoch: 0 [58/100000 (0%)] Loss: 4.527874 , (1.760 sec/step)
# Train Epoch: 0 [59/100000 (0%)] Loss: 4.524335 , (1.762 sec/step)
# Train Epoch: 0 [60/100000 (0%)] Loss: 4.520846 , (1.762 sec/step)
# Train Epoch: 0 [61/100000 (0%)] Loss: 4.517453 , (1.760 sec/step)
# Train Epoch: 0 [62/100000 (0%)] Loss: 4.514094 , (1.763 sec/step)
# Train Epoch: 0 [63/100000 (0%)] Loss: 4.510778 , (1.758 sec/step)
# Train Epoch: 0 [64/100000 (0%)] Loss: 4.507497 , (1.763 sec/step)
# Train Epoch: 0 [65/100000 (0%)] Loss: 4.504274 , (1.760 sec/step)
# Train Epoch: 0 [66/100000 (0%)] Loss: 4.501152 , (1.760 sec/step)
# Train Epoch: 0 [67/100000 (0%)] Loss: 4.498023 , (1.760 sec/step)
# Train Epoch: 0 [68/100000 (0%)] Loss: 4.494898 , (1.759 sec/step)
# Train Epoch: 0 [69/100000 (0%)] Loss: 4.491883 , (1.760 sec/step)
# Train Epoch: 0 [70/100000 (0%)] Loss: 4.488799 , (1.760 sec/step)
# Train Epoch: 0 [71/100000 (0%)] Loss: 4.485647 , (1.762 sec/step)
# Train Epoch: 0 [72/100000 (0%)] Loss: 4.482616 , (1.760 sec/step)
# Train Epoch: 0 [73/100000 (0%)] Loss: 4.479592 , (1.761 sec/step)
# Train Epoch: 0 [74/100000 (0%)] Loss: 4.476664 , (1.763 sec/step)
# Train Epoch: 0 [75/100000 (0%)] Loss: 4.473722 , (1.762 sec/step)
# Train Epoch: 0 [76/100000 (0%)] Loss: 4.470829 , (1.762 sec/step)
# Train Epoch: 0 [77/100000 (0%)] Loss: 4.468017 , (1.761 sec/step)
# Train Epoch: 0 [78/100000 (0%)] Loss: 4.465179 , (1.763 sec/step)
# Train Epoch: 0 [79/100000 (0%)] Loss: 4.462471 , (1.763 sec/step)
# Train Epoch: 0 [80/100000 (0%)] Loss: 4.459912 , (1.762 sec/step)
# Train Epoch: 0 [81/100000 (0%)] Loss: 4.457408 , (1.762 sec/step)
# Train Epoch: 0 [82/100000 (0%)] Loss: 4.454912 , (1.762 sec/step)
# Train Epoch: 0 [83/100000 (0%)] Loss: 4.452063 , (1.764 sec/step)
# Train Epoch: 0 [84/100000 (0%)] Loss: 4.448940 , (1.764 sec/step)
# Train Epoch: 0 [85/100000 (0%)] Loss: 4.446051 , (1.763 sec/step)
# Train Epoch: 0 [86/100000 (0%)] Loss: 4.443528 , (1.763 sec/step)
# Train Epoch: 0 [87/100000 (0%)] Loss: 4.441271 , (1.764 sec/step)
# Train Epoch: 0 [88/100000 (0%)] Loss: 4.438922 , (1.763 sec/step)
# Train Epoch: 0 [89/100000 (0%)] Loss: 4.436283 , (1.762 sec/step)
# Train Epoch: 0 [90/100000 (0%)] Loss: 4.433526 , (1.762 sec/step)
# Train Epoch: 0 [91/100000 (0%)] Loss: 4.430851 , (1.761 sec/step)
# Train Epoch: 0 [92/100000 (0%)] Loss: 4.428457 , (1.765 sec/step)
# Train Epoch: 0 [93/100000 (0%)] Loss: 4.426241 , (1.763 sec/step)
# Train Epoch: 0 [94/100000 (0%)] Loss: 4.424010 , (1.764 sec/step)
# Train Epoch: 0 [95/100000 (0%)] Loss: 4.421606 , (1.761 sec/step)
# Train Epoch: 0 [96/100000 (0%)] Loss: 4.419035 , (1.763 sec/step)
# Train Epoch: 0 [97/100000 (0%)] Loss: 4.416464 , (1.762 sec/step)
# Train Epoch: 0 [98/100000 (0%)] Loss: 4.414034 , (1.762 sec/step)
# Train Epoch: 0 [99/100000 (0%)] Loss: 4.411805 , (1.761 sec/step)
# Train Epoch: 0 [100/100000 (0%)] Loss: 4.409748 , (1.762 sec/step)
#
# val set:  4.4078, (0.680 sec/step)
#
# stored done
#
# Train Epoch: 0 [101/100000 (0%)] Loss: 4.407783 , (1.765 sec/step)
# Train Epoch: 0 [102/100000 (0%)] Loss: 4.405789 , (1.766 sec/step)
# Train Epoch: 0 [103/100000 (0%)] Loss: 4.403694 , (1.763 sec/step)
# Train Epoch: 0 [104/100000 (0%)] Loss: 4.401302 , (1.764 sec/step)
# Train Epoch: 0 [105/100000 (0%)] Loss: 4.398759 , (1.763 sec/step)
# Train Epoch: 0 [106/100000 (0%)] Loss: 4.396327 , (1.765 sec/step)
# Train Epoch: 0 [107/100000 (0%)] Loss: 4.394268 , (1.766 sec/step)
# Train Epoch: 0 [108/100000 (0%)] Loss: 4.392422 , (1.766 sec/step)
# Train Epoch: 0 [109/100000 (0%)] Loss: 4.390443 , (1.764 sec/step)
# Train Epoch: 0 [110/100000 (0%)] Loss: 4.388087 , (1.765 sec/step)
# Train Epoch: 0 [111/100000 (0%)] Loss: 4.385543 , (1.762 sec/step)
# Train Epoch: 0 [112/100000 (0%)] Loss: 4.383237 , (1.762 sec/step)
# Train Epoch: 0 [113/100000 (0%)] Loss: 4.381335 , (1.764 sec/step)
# Train Epoch: 0 [114/100000 (0%)] Loss: 4.379637 , (1.765 sec/step)
# Train Epoch: 0 [115/100000 (0%)] Loss: 4.377814 , (1.762 sec/step)
# Train Epoch: 0 [116/100000 (0%)] Loss: 4.375656 , (1.766 sec/step)
# Train Epoch: 0 [117/100000 (0%)] Loss: 4.373276 , (1.766 sec/step)
# Train Epoch: 0 [118/100000 (0%)] Loss: 4.370982 , (1.764 sec/step)
# Train Epoch: 0 [119/100000 (0%)] Loss: 4.368979 , (1.763 sec/step)
# Train Epoch: 0 [120/100000 (0%)] Loss: 4.367213 , (1.766 sec/step)
# Train Epoch: 0 [121/100000 (0%)] Loss: 4.365499 , (1.765 sec/step)
# Train Epoch: 0 [122/100000 (0%)] Loss: 4.363676 , (1.764 sec/step)
# Train Epoch: 0 [123/100000 (0%)] Loss: 4.361681 , (1.765 sec/step)
# Train Epoch: 0 [124/100000 (0%)] Loss: 4.359631 , (1.763 sec/step)
# Train Epoch: 0 [125/100000 (0%)] Loss: 4.357696 , (1.764 sec/step)
# Train Epoch: 0 [126/100000 (0%)] Loss: 4.356101 , (1.763 sec/step)
# Train Epoch: 0 [127/100000 (0%)] Loss: 4.354869 , (1.766 sec/step)
# Train Epoch: 0 [128/100000 (0%)] Loss: 4.353656 , (1.764 sec/step)
# Train Epoch: 0 [129/100000 (0%)] Loss: 4.351756 , (1.766 sec/step)
# Train Epoch: 0 [130/100000 (0%)] Loss: 4.348727 , (1.765 sec/step)
# Train Epoch: 0 [131/100000 (0%)] Loss: 4.345860 , (1.766 sec/step)
# Train Epoch: 0 [132/100000 (0%)] Loss: 4.344182 , (1.762 sec/step)
# Train Epoch: 0 [133/100000 (0%)] Loss: 4.343230 , (1.764 sec/step)
# Train Epoch: 0 [134/100000 (0%)] Loss: 4.341830 , (1.767 sec/step)
# Train Epoch: 0 [135/100000 (0%)] Loss: 4.339398 , (1.763 sec/step)
# Train Epoch: 0 [136/100000 (0%)] Loss: 4.336822 , (1.767 sec/step)
# Train Epoch: 0 [137/100000 (0%)] Loss: 4.335057 , (1.766 sec/step)
# Train Epoch: 0 [138/100000 (0%)] Loss: 4.333845 , (1.765 sec/step)
# Train Epoch: 0 [139/100000 (0%)] Loss: 4.332374 , (1.764 sec/step)
# Train Epoch: 0 [140/100000 (0%)] Loss: 4.330263 , (1.764 sec/step)
# Train Epoch: 0 [141/100000 (0%)] Loss: 4.327985 , (1.765 sec/step)
# Train Epoch: 0 [142/100000 (0%)] Loss: 4.326147 , (1.763 sec/step)
# Train Epoch: 0 [143/100000 (0%)] Loss: 4.324725 , (1.763 sec/step)
# Train Epoch: 0 [144/100000 (0%)] Loss: 4.323275 , (1.765 sec/step)
# Train Epoch: 0 [145/100000 (0%)] Loss: 4.321477 , (1.764 sec/step)
# Train Epoch: 0 [146/100000 (0%)] Loss: 4.319452 , (1.764 sec/step)
# Train Epoch: 0 [147/100000 (0%)] Loss: 4.317518 , (1.764 sec/step)
# Train Epoch: 0 [148/100000 (0%)] Loss: 4.315886 , (1.766 sec/step)
# Train Epoch: 0 [149/100000 (0%)] Loss: 4.314553 , (1.765 sec/step)
# Train Epoch: 0 [150/100000 (0%)] Loss: 4.313519 , (1.764 sec/step)
# Train Epoch: 0 [151/100000 (0%)] Loss: 4.312824 , (1.762 sec/step)
# Train Epoch: 0 [152/100000 (0%)] Loss: 4.312597 , (1.765 sec/step)
# Train Epoch: 0 [153/100000 (0%)] Loss: 4.312064 , (1.763 sec/step)
# Train Epoch: 0 [154/100000 (0%)] Loss: 4.309950 , (1.765 sec/step)
# Train Epoch: 0 [155/100000 (0%)] Loss: 4.306446 , (1.764 sec/step)
# Train Epoch: 0 [156/100000 (0%)] Loss: 4.303658 , (1.764 sec/step)
# Train Epoch: 0 [157/100000 (0%)] Loss: 4.302764 , (1.762 sec/step)
# Train Epoch: 0 [158/100000 (0%)] Loss: 4.301900 , (1.764 sec/step)
# Train Epoch: 0 [159/100000 (0%)] Loss: 4.299574 , (1.761 sec/step)
# Train Epoch: 0 [160/100000 (0%)] Loss: 4.297194 , (1.762 sec/step)
# Train Epoch: 0 [161/100000 (0%)] Loss: 4.296054 , (1.762 sec/step)
# Train Epoch: 0 [162/100000 (0%)] Loss: 4.294958 , (1.766 sec/step)
# Train Epoch: 0 [163/100000 (0%)] Loss: 4.292790 , (1.763 sec/step)
# Train Epoch: 0 [164/100000 (0%)] Loss: 4.290800 , (1.764 sec/step)
# Train Epoch: 0 [165/100000 (0%)] Loss: 4.289772 , (1.764 sec/step)
# Train Epoch: 0 [166/100000 (0%)] Loss: 4.288513 , (1.764 sec/step)
# Train Epoch: 0 [167/100000 (0%)] Loss: 4.286423 , (1.763 sec/step)
# Train Epoch: 0 [168/100000 (0%)] Loss: 4.284497 , (1.765 sec/step)
# Train Epoch: 0 [169/100000 (0%)] Loss: 4.283413 , (1.762 sec/step)
# Train Epoch: 0 [170/100000 (0%)] Loss: 4.282297 , (1.762 sec/step)
# Train Epoch: 0 [171/100000 (0%)] Loss: 4.280426 , (1.765 sec/step)
# Train Epoch: 0 [172/100000 (0%)] Loss: 4.278430 , (1.765 sec/step)
# Train Epoch: 0 [173/100000 (0%)] Loss: 4.277027 , (1.764 sec/step)
# Train Epoch: 0 [174/100000 (0%)] Loss: 4.275975 , (1.763 sec/step)
# Train Epoch: 0 [175/100000 (0%)] Loss: 4.274525 , (1.765 sec/step)
# Train Epoch: 0 [176/100000 (0%)] Loss: 4.272635 , (1.764 sec/step)
# Train Epoch: 0 [177/100000 (0%)] Loss: 4.270930 , (1.765 sec/step)
# Train Epoch: 0 [178/100000 (0%)] Loss: 4.269615 , (1.764 sec/step)
# Train Epoch: 0 [179/100000 (0%)] Loss: 4.268325 , (1.764 sec/step)
# Train Epoch: 0 [180/100000 (0%)] Loss: 4.266764 , (1.765 sec/step)
# Train Epoch: 0 [181/100000 (0%)] Loss: 4.265079 , (1.765 sec/step)
# Train Epoch: 0 [182/100000 (0%)] Loss: 4.263552 , (1.764 sec/step)
# Train Epoch: 0 [183/100000 (0%)] Loss: 4.262165 , (1.765 sec/step)
# Train Epoch: 0 [184/100000 (0%)] Loss: 4.260766 , (1.764 sec/step)
# Train Epoch: 0 [185/100000 (0%)] Loss: 4.259242 , (1.765 sec/step)
# Train Epoch: 0 [186/100000 (0%)] Loss: 4.257601 , (1.766 sec/step)
# Train Epoch: 0 [187/100000 (0%)] Loss: 4.256004 , (1.765 sec/step)
# Train Epoch: 0 [188/100000 (0%)] Loss: 4.254514 , (1.765 sec/step)
# Train Epoch: 0 [189/100000 (0%)] Loss: 4.253090 , (1.765 sec/step)
# Train Epoch: 0 [190/100000 (0%)] Loss: 4.251665 , (1.766 sec/step)
# Train Epoch: 0 [191/100000 (0%)] Loss: 4.250181 , (1.763 sec/step)
# Train Epoch: 0 [192/100000 (0%)] Loss: 4.248637 , (1.767 sec/step)
# Train Epoch: 0 [193/100000 (0%)] Loss: 4.247083 , (1.762 sec/step)
# Train Epoch: 0 [194/100000 (0%)] Loss: 4.245573 , (1.763 sec/step)
# Train Epoch: 0 [195/100000 (0%)] Loss: 4.244139 , (1.765 sec/step)
# Train Epoch: 0 [196/100000 (0%)] Loss: 4.242811 , (1.764 sec/step)
# Train Epoch: 0 [197/100000 (0%)] Loss: 4.241661 , (1.766 sec/step)
# Train Epoch: 0 [198/100000 (0%)] Loss: 4.240886 , (1.763 sec/step)
# Train Epoch: 0 [199/100000 (0%)] Loss: 4.240741 , (1.765 sec/step)
# Train Epoch: 0 [200/100000 (0%)] Loss: 4.241476 , (1.764 sec/step)
#
# val set:  4.2420, (0.681 sec/step)
#
# stored done
#
# Train Epoch: 0 [201/100000 (0%)] Loss: 4.241959 , (1.764 sec/step)
# Train Epoch: 0 [202/100000 (0%)] Loss: 4.240039 , (1.763 sec/step)
# Train Epoch: 0 [203/100000 (0%)] Loss: 4.235149 , (1.762 sec/step)
# Train Epoch: 0 [204/100000 (0%)] Loss: 4.231445 , (1.764 sec/step)
# Train Epoch: 0 [205/100000 (0%)] Loss: 4.231471 , (1.763 sec/step)
# Train Epoch: 0 [206/100000 (0%)] Loss: 4.232005 , (1.763 sec/step)
# Train Epoch: 0 [207/100000 (0%)] Loss: 4.229522 , (1.763 sec/step)
# Train Epoch: 0 [208/100000 (0%)] Loss: 4.225848 , (1.766 sec/step)
# Train Epoch: 0 [209/100000 (0%)] Loss: 4.224741 , (1.764 sec/step)
# Train Epoch: 0 [210/100000 (0%)] Loss: 4.225111 , (1.763 sec/step)
# Train Epoch: 0 [211/100000 (0%)] Loss: 4.223519 , (1.762 sec/step)
# Train Epoch: 0 [212/100000 (0%)] Loss: 4.220446 , (1.765 sec/step)
# Train Epoch: 0 [213/100000 (0%)] Loss: 4.218847 , (1.762 sec/step)
# Train Epoch: 0 [214/100000 (0%)] Loss: 4.218643 , (1.763 sec/step)
# Train Epoch: 0 [215/100000 (0%)] Loss: 4.217411 , (1.764 sec/step)
# Train Epoch: 0 [216/100000 (0%)] Loss: 4.214955 , (1.764 sec/step)
# Train Epoch: 0 [217/100000 (0%)] Loss: 4.213330 , (1.762 sec/step)
# Train Epoch: 0 [218/100000 (0%)] Loss: 4.212726 , (1.765 sec/step)
# Train Epoch: 0 [219/100000 (0%)] Loss: 4.211532 , (1.762 sec/step)
# Train Epoch: 0 [220/100000 (0%)] Loss: 4.209467 , (1.763 sec/step)
# Train Epoch: 0 [221/100000 (0%)] Loss: 4.207757 , (1.763 sec/step)
# Train Epoch: 0 [222/100000 (0%)] Loss: 4.206809 , (1.763 sec/step)
# Train Epoch: 0 [223/100000 (0%)] Loss: 4.205743 , (1.762 sec/step)
# Train Epoch: 0 [224/100000 (0%)] Loss: 4.204051 , (1.765 sec/step)
# Train Epoch: 0 [225/100000 (0%)] Loss: 4.202311 , (1.763 sec/step)
# Train Epoch: 0 [226/100000 (0%)] Loss: 4.201054 , (1.764 sec/step)
# Train Epoch: 0 [227/100000 (0%)] Loss: 4.199997 , (1.764 sec/step)
# Train Epoch: 0 [228/100000 (0%)] Loss: 4.198634 , (1.765 sec/step)
# Train Epoch: 0 [229/100000 (0%)] Loss: 4.196989 , (1.762 sec/step)
# Train Epoch: 0 [230/100000 (0%)] Loss: 4.195494 , (1.762 sec/step)
# Train Epoch: 0 [231/100000 (0%)] Loss: 4.194308 , (1.763 sec/step)
# Train Epoch: 0 [232/100000 (0%)] Loss: 4.193176 , (1.765 sec/step)
# Train Epoch: 0 [233/100000 (0%)] Loss: 4.191871 , (1.764 sec/step)
# Train Epoch: 0 [234/100000 (0%)] Loss: 4.190542 , (1.762 sec/step)
# Train Epoch: 0 [235/100000 (0%)] Loss: 4.189487 , (1.762 sec/step)
# Train Epoch: 0 [236/100000 (0%)] Loss: 4.188892 , (1.765 sec/step)
# Train Epoch: 0 [237/100000 (0%)] Loss: 4.188738 , (1.763 sec/step)
# Train Epoch: 0 [238/100000 (0%)] Loss: 4.188468 , (1.763 sec/step)
# Train Epoch: 0 [239/100000 (0%)] Loss: 4.187561 , (1.763 sec/step)
# Train Epoch: 0 [240/100000 (0%)] Loss: 4.185144 , (1.761 sec/step)
# Train Epoch: 0 [241/100000 (0%)] Loss: 4.181964 , (1.762 sec/step)
# Train Epoch: 0 [242/100000 (0%)] Loss: 4.179529 , (1.762 sec/step)
# Train Epoch: 0 [243/100000 (0%)] Loss: 4.178494 , (1.763 sec/step)
# Train Epoch: 0 [244/100000 (0%)] Loss: 4.178163 , (1.762 sec/step)
# Train Epoch: 0 [245/100000 (0%)] Loss: 4.177335 , (1.764 sec/step)
# Train Epoch: 0 [246/100000 (0%)] Loss: 4.175538 , (1.764 sec/step)
# Train Epoch: 0 [247/100000 (0%)] Loss: 4.173343 , (1.765 sec/step)
# Train Epoch: 0 [248/100000 (0%)] Loss: 4.171615 , (1.762 sec/step)
# Train Epoch: 0 [249/100000 (0%)] Loss: 4.170575 , (1.764 sec/step)
# Train Epoch: 0 [250/100000 (0%)] Loss: 4.169700 , (1.762 sec/step)
# Train Epoch: 0 [251/100000 (0%)] Loss: 4.168477 , (1.763 sec/step)
# Train Epoch: 0 [252/100000 (0%)] Loss: 4.166845 , (1.763 sec/step)
# Train Epoch: 0 [253/100000 (0%)] Loss: 4.165152 , (1.762 sec/step)
# Train Epoch: 0 [254/100000 (0%)] Loss: 4.163736 , (1.761 sec/step)
# Train Epoch: 0 [255/100000 (0%)] Loss: 4.162576 , (1.761 sec/step)
# Train Epoch: 0 [256/100000 (0%)] Loss: 4.161426 , (1.765 sec/step)
# Train Epoch: 0 [257/100000 (0%)] Loss: 4.160090 , (1.765 sec/step)
# Train Epoch: 0 [258/100000 (0%)] Loss: 4.158616 , (1.767 sec/step)
# Train Epoch: 0 [259/100000 (0%)] Loss: 4.157163 , (1.763 sec/step)
# Train Epoch: 0 [260/100000 (0%)] Loss: 4.155822 , (1.762 sec/step)
# Train Epoch: 0 [261/100000 (0%)] Loss: 4.154564 , (1.764 sec/step)
# Train Epoch: 0 [262/100000 (0%)] Loss: 4.153301 , (1.764 sec/step)
# Train Epoch: 0 [263/100000 (0%)] Loss: 4.151989 , (1.762 sec/step)
# Train Epoch: 0 [264/100000 (0%)] Loss: 4.150606 , (1.764 sec/step)
# Train Epoch: 0 [265/100000 (0%)] Loss: 4.149207 , (1.763 sec/step)
# Train Epoch: 0 [266/100000 (0%)] Loss: 4.147842 , (1.762 sec/step)
# Train Epoch: 0 [267/100000 (0%)] Loss: 4.146534 , (1.763 sec/step)
# Train Epoch: 0 [268/100000 (0%)] Loss: 4.145270 , (1.762 sec/step)
# Train Epoch: 0 [269/100000 (0%)] Loss: 4.144027 , (1.762 sec/step)
# Train Epoch: 0 [270/100000 (0%)] Loss: 4.142776 , (1.764 sec/step)
# Train Epoch: 0 [271/100000 (0%)] Loss: 4.141489 , (1.762 sec/step)
# Train Epoch: 0 [272/100000 (0%)] Loss: 4.140153 , (1.765 sec/step)
# Train Epoch: 0 [273/100000 (0%)] Loss: 4.138774 , (1.762 sec/step)
# Train Epoch: 0 [274/100000 (0%)] Loss: 4.137396 , (1.766 sec/step)
# Train Epoch: 0 [275/100000 (0%)] Loss: 4.136037 , (1.761 sec/step)
# Train Epoch: 0 [276/100000 (0%)] Loss: 4.134717 , (1.763 sec/step)
# Train Epoch: 0 [277/100000 (0%)] Loss: 4.133400 , (1.763 sec/step)
# Train Epoch: 0 [278/100000 (0%)] Loss: 4.132101 , (1.765 sec/step)
# Train Epoch: 0 [279/100000 (0%)] Loss: 4.130815 , (1.763 sec/step)
# Train Epoch: 0 [280/100000 (0%)] Loss: 4.129570 , (1.765 sec/step)
# Train Epoch: 0 [281/100000 (0%)] Loss: 4.128362 , (1.763 sec/step)
# Train Epoch: 0 [282/100000 (0%)] Loss: 4.127242 , (1.763 sec/step)
# Train Epoch: 0 [283/100000 (0%)] Loss: 4.126201 , (1.762 sec/step)
# Train Epoch: 0 [284/100000 (0%)] Loss: 4.125286 , (1.763 sec/step)
# Train Epoch: 0 [285/100000 (0%)] Loss: 4.124413 , (1.763 sec/step)
# Train Epoch: 0 [286/100000 (0%)] Loss: 4.123587 , (1.763 sec/step)
# Train Epoch: 0 [287/100000 (0%)] Loss: 4.122733 , (1.765 sec/step)
# Train Epoch: 0 [288/100000 (0%)] Loss: 4.121916 , (1.763 sec/step)
# Train Epoch: 0 [289/100000 (0%)] Loss: 4.121656 , (1.764 sec/step)
# Train Epoch: 0 [290/100000 (0%)] Loss: 4.122041 , (1.762 sec/step)
# Train Epoch: 0 [291/100000 (0%)] Loss: 4.122680 , (1.763 sec/step)
# Train Epoch: 0 [292/100000 (0%)] Loss: 4.121639 , (1.764 sec/step)
# Train Epoch: 0 [293/100000 (0%)] Loss: 4.117208 , (1.764 sec/step)
# Train Epoch: 0 [294/100000 (0%)] Loss: 4.112387 , (1.762 sec/step)
# Train Epoch: 0 [295/100000 (0%)] Loss: 4.111248 , (1.761 sec/step)
# Train Epoch: 0 [296/100000 (0%)] Loss: 4.112692 , (1.765 sec/step)
# Train Epoch: 0 [297/100000 (0%)] Loss: 4.112313 , (1.760 sec/step)
# Train Epoch: 0 [298/100000 (0%)] Loss: 4.108951 , (1.764 sec/step)
# Train Epoch: 0 [299/100000 (0%)] Loss: 4.106183 , (1.762 sec/step)
# Train Epoch: 0 [300/100000 (0%)] Loss: 4.105753 , (1.765 sec/step)
#
# val set:  4.1056, (0.681 sec/step)
#
# stored done
#
# Train Epoch: 0 [301/100000 (0%)] Loss: 4.105605 , (1.761 sec/step)
# Train Epoch: 0 [302/100000 (0%)] Loss: 4.103862 , (1.762 sec/step)
# Train Epoch: 0 [303/100000 (0%)] Loss: 4.101822 , (1.761 sec/step)
# Train Epoch: 0 [304/100000 (0%)] Loss: 4.100877 , (1.762 sec/step)
# Train Epoch: 0 [305/100000 (0%)] Loss: 4.099948 , (1.762 sec/step)
# Train Epoch: 0 [306/100000 (0%)] Loss: 4.098232 , (1.760 sec/step)
# Train Epoch: 0 [307/100000 (0%)] Loss: 4.096686 , (1.763 sec/step)
# Train Epoch: 0 [308/100000 (0%)] Loss: 4.095950 , (1.761 sec/step)
# Train Epoch: 0 [309/100000 (0%)] Loss: 4.095115 , (1.761 sec/step)
# Train Epoch: 0 [310/100000 (0%)] Loss: 4.093394 , (1.759 sec/step)
# Train Epoch: 0 [311/100000 (0%)] Loss: 4.091685 , (1.760 sec/step)
# Train Epoch: 0 [312/100000 (0%)] Loss: 4.090711 , (1.762 sec/step)
# Train Epoch: 0 [313/100000 (0%)] Loss: 4.089886 , (1.762 sec/step)
# Train Epoch: 0 [314/100000 (0%)] Loss: 4.088586 , (1.759 sec/step)
# Train Epoch: 0 [315/100000 (0%)] Loss: 4.087102 , (1.761 sec/step)
# Train Epoch: 0 [316/100000 (0%)] Loss: 4.085931 , (1.761 sec/step)
# Train Epoch: 0 [317/100000 (0%)] Loss: 4.084886 , (1.761 sec/step)
# Train Epoch: 0 [318/100000 (0%)] Loss: 4.083630 , (1.762 sec/step)
# Train Epoch: 0 [319/100000 (0%)] Loss: 4.082335 , (1.761 sec/step)
# Train Epoch: 0 [320/100000 (0%)] Loss: 4.081291 , (1.762 sec/step)
# Train Epoch: 0 [321/100000 (0%)] Loss: 4.080556 , (1.762 sec/step)
# Train Epoch: 0 [322/100000 (0%)] Loss: 4.080087 , (1.763 sec/step)
# Train Epoch: 0 [323/100000 (0%)] Loss: 4.080227 , (1.763 sec/step)
# Train Epoch: 0 [324/100000 (0%)] Loss: 4.081179 , (1.760 sec/step)
# Train Epoch: 0 [325/100000 (0%)] Loss: 4.083189 , (1.761 sec/step)
# Train Epoch: 0 [326/100000 (0%)] Loss: 4.083538 , (1.763 sec/step)
# Train Epoch: 0 [327/100000 (0%)] Loss: 4.079721 , (1.763 sec/step)
# Train Epoch: 0 [328/100000 (0%)] Loss: 4.073570 , (1.761 sec/step)
# Train Epoch: 0 [329/100000 (0%)] Loss: 4.070947 , (1.762 sec/step)
# Train Epoch: 0 [330/100000 (0%)] Loss: 4.072421 , (1.763 sec/step)
# Train Epoch: 0 [331/100000 (0%)] Loss: 4.073361 , (1.763 sec/step)
# Train Epoch: 0 [332/100000 (0%)] Loss: 4.070623 , (1.763 sec/step)
# Train Epoch: 0 [333/100000 (0%)] Loss: 4.066755 , (1.762 sec/step)
# Train Epoch: 0 [334/100000 (0%)] Loss: 4.065784 , (1.763 sec/step)
# Train Epoch: 0 [335/100000 (0%)] Loss: 4.066584 , (1.762 sec/step)
# Train Epoch: 0 [336/100000 (0%)] Loss: 4.065635 , (1.763 sec/step)
# Train Epoch: 0 [337/100000 (0%)] Loss: 4.062799 , (1.763 sec/step)
# Train Epoch: 0 [338/100000 (0%)] Loss: 4.060830 , (1.764 sec/step)
# Train Epoch: 0 [339/100000 (0%)] Loss: 4.060683 , (1.763 sec/step)
# Train Epoch: 0 [340/100000 (0%)] Loss: 4.060379 , (1.762 sec/step)
# Train Epoch: 0 [341/100000 (0%)] Loss: 4.058527 , (1.761 sec/step)
# Train Epoch: 0 [342/100000 (0%)] Loss: 4.056487 , (1.760 sec/step)
# Train Epoch: 0 [343/100000 (0%)] Loss: 4.055579 , (1.759 sec/step)
# Train Epoch: 0 [344/100000 (0%)] Loss: 4.055141 , (1.764 sec/step)
# Train Epoch: 0 [345/100000 (0%)] Loss: 4.053999 , (1.763 sec/step)
# Train Epoch: 0 [346/100000 (0%)] Loss: 4.052261 , (1.761 sec/step)
# Train Epoch: 0 [347/100000 (0%)] Loss: 4.050950 , (1.761 sec/step)
# Train Epoch: 0 [348/100000 (0%)] Loss: 4.050183 , (1.763 sec/step)
# Train Epoch: 0 [349/100000 (0%)] Loss: 4.049313 , (1.763 sec/step)
# Train Epoch: 0 [350/100000 (0%)] Loss: 4.047996 , (1.762 sec/step)
# Train Epoch: 0 [351/100000 (0%)] Loss: 4.046581 , (1.761 sec/step)
# Train Epoch: 0 [352/100000 (0%)] Loss: 4.045468 , (1.763 sec/step)
# Train Epoch: 0 [353/100000 (0%)] Loss: 4.044555 , (1.762 sec/step)
# Train Epoch: 0 [354/100000 (0%)] Loss: 4.043512 , (1.762 sec/step)
# Train Epoch: 0 [355/100000 (0%)] Loss: 4.042271 , (1.762 sec/step)
# Train Epoch: 0 [356/100000 (0%)] Loss: 4.041021 , (1.763 sec/step)
# Train Epoch: 0 [357/100000 (0%)] Loss: 4.039908 , (1.761 sec/step)
# Train Epoch: 0 [358/100000 (0%)] Loss: 4.038887 , (1.764 sec/step)
# Train Epoch: 0 [359/100000 (0%)] Loss: 4.037816 , (1.763 sec/step)
# Train Epoch: 0 [360/100000 (0%)] Loss: 4.036647 , (1.763 sec/step)
# Train Epoch: 0 [361/100000 (0%)] Loss: 4.035456 , (1.763 sec/step)
# Train Epoch: 0 [362/100000 (0%)] Loss: 4.034317 , (1.762 sec/step)
# Train Epoch: 0 [363/100000 (0%)] Loss: 4.033224 , (1.762 sec/step)
# Train Epoch: 0 [364/100000 (0%)] Loss: 4.032143 , (1.762 sec/step)
# Train Epoch: 0 [365/100000 (0%)] Loss: 4.031044 , (1.764 sec/step)
# Train Epoch: 0 [366/100000 (0%)] Loss: 4.029937 , (1.766 sec/step)
# Train Epoch: 0 [367/100000 (0%)] Loss: 4.028862 , (1.761 sec/step)
# Train Epoch: 0 [368/100000 (0%)] Loss: 4.027878 , (1.763 sec/step)
# Train Epoch: 0 [369/100000 (0%)] Loss: 4.027083 , (1.762 sec/step)
# Train Epoch: 0 [370/100000 (0%)] Loss: 4.026558 , (1.763 sec/step)
# Train Epoch: 0 [371/100000 (0%)] Loss: 4.026597 , (1.765 sec/step)
# Train Epoch: 0 [372/100000 (0%)] Loss: 4.027184 , (1.764 sec/step)
# Train Epoch: 0 [373/100000 (0%)] Loss: 4.028557 , (1.764 sec/step)
# Train Epoch: 0 [374/100000 (0%)] Loss: 4.029040 , (1.762 sec/step)
# Train Epoch: 0 [375/100000 (0%)] Loss: 4.027379 , (1.764 sec/step)
# Train Epoch: 0 [376/100000 (0%)] Loss: 4.022845 , (1.767 sec/step)
# Train Epoch: 0 [377/100000 (0%)] Loss: 4.018386 , (1.761 sec/step)
# Train Epoch: 0 [378/100000 (0%)] Loss: 4.016893 , (1.760 sec/step)
# Train Epoch: 0 [379/100000 (0%)] Loss: 4.017789 , (1.762 sec/step)
# Train Epoch: 0 [380/100000 (0%)] Loss: 4.018344 , (1.761 sec/step)
# Train Epoch: 0 [381/100000 (0%)] Loss: 4.016536 , (1.761 sec/step)
# Train Epoch: 0 [382/100000 (0%)] Loss: 4.013386 , (1.763 sec/step)
# Train Epoch: 0 [383/100000 (0%)] Loss: 4.011309 , (1.764 sec/step)
# Train Epoch: 0 [384/100000 (0%)] Loss: 4.010996 , (1.761 sec/step)
# Train Epoch: 0 [385/100000 (0%)] Loss: 4.011020 , (1.762 sec/step)
# Train Epoch: 0 [386/100000 (0%)] Loss: 4.009886 , (1.763 sec/step)
# Train Epoch: 0 [387/100000 (0%)] Loss: 4.007790 , (1.763 sec/step)
# Train Epoch: 0 [388/100000 (0%)] Loss: 4.005989 , (1.765 sec/step)
# Train Epoch: 0 [389/100000 (0%)] Loss: 4.005106 , (1.762 sec/step)
# Train Epoch: 0 [390/100000 (0%)] Loss: 4.004583 , (1.762 sec/step)
# Train Epoch: 0 [391/100000 (0%)] Loss: 4.003645 , (1.763 sec/step)
# Train Epoch: 0 [392/100000 (0%)] Loss: 4.002194 , (1.762 sec/step)
# Train Epoch: 0 [393/100000 (0%)] Loss: 4.000672 , (1.760 sec/step)
# Train Epoch: 0 [394/100000 (0%)] Loss: 3.999484 , (1.761 sec/step)
# Train Epoch: 0 [395/100000 (0%)] Loss: 3.998598 , (1.763 sec/step)
# Train Epoch: 0 [396/100000 (0%)] Loss: 3.997711 , (1.764 sec/step)
# Train Epoch: 0 [397/100000 (0%)] Loss: 3.996605 , (1.764 sec/step)
# Train Epoch: 0 [398/100000 (0%)] Loss: 3.995325 , (1.763 sec/step)
# Train Epoch: 0 [399/100000 (0%)] Loss: 3.994061 , (1.762 sec/step)
# Train Epoch: 0 [400/100000 (0%)] Loss: 3.992945 , (1.763 sec/step)
#
# val set:  3.9919, (0.681 sec/step)
#
# stored done
#
# Train Epoch: 0 [401/100000 (0%)] Loss: 3.991942 , (1.761 sec/step)
# Train Epoch: 0 [402/100000 (0%)] Loss: 3.990934 , (1.762 sec/step)
# Train Epoch: 0 [403/100000 (0%)] Loss: 3.989850 , (1.762 sec/step)
# Train Epoch: 0 [404/100000 (0%)] Loss: 3.988695 , (1.763 sec/step)
# Train Epoch: 0 [405/100000 (0%)] Loss: 3.987525 , (1.764 sec/step)
# Train Epoch: 0 [406/100000 (0%)] Loss: 3.986389 , (1.762 sec/step)
# Train Epoch: 0 [407/100000 (0%)] Loss: 3.985296 , (1.764 sec/step)
# Train Epoch: 0 [408/100000 (0%)] Loss: 3.984227 , (1.763 sec/step)
# Train Epoch: 0 [409/100000 (0%)] Loss: 3.983157 , (1.760 sec/step)
# Train Epoch: 0 [410/100000 (0%)] Loss: 3.982081 , (1.763 sec/step)
# Train Epoch: 0 [411/100000 (0%)] Loss: 3.980995 , (1.762 sec/step)
# Train Epoch: 0 [412/100000 (0%)] Loss: 3.979893 , (1.762 sec/step)
# Train Epoch: 0 [413/100000 (0%)] Loss: 3.978772 , (1.760 sec/step)
# Train Epoch: 0 [414/100000 (0%)] Loss: 3.977636 , (1.764 sec/step)
# Train Epoch: 0 [415/100000 (0%)] Loss: 3.976510 , (1.763 sec/step)
# Train Epoch: 0 [416/100000 (0%)] Loss: 3.975408 , (1.763 sec/step)
# Train Epoch: 0 [417/100000 (0%)] Loss: 3.974333 , (1.762 sec/step)
# Train Epoch: 0 [418/100000 (0%)] Loss: 3.973287 , (1.760 sec/step)
# Train Epoch: 0 [419/100000 (0%)] Loss: 3.972267 , (1.762 sec/step)
# Train Epoch: 0 [420/100000 (0%)] Loss: 3.971286 , (1.762 sec/step)
# Train Epoch: 0 [421/100000 (0%)] Loss: 3.970388 , (1.764 sec/step)
# Train Epoch: 0 [422/100000 (0%)] Loss: 3.969637 , (1.761 sec/step)
# Train Epoch: 0 [423/100000 (0%)] Loss: 3.969218 , (1.760 sec/step)
# Train Epoch: 0 [424/100000 (0%)] Loss: 3.969288 , (1.765 sec/step)
# Train Epoch: 0 [425/100000 (0%)] Loss: 3.970308 , (1.762 sec/step)
# Train Epoch: 0 [426/100000 (0%)] Loss: 3.971801 , (1.761 sec/step)
# Train Epoch: 0 [427/100000 (0%)] Loss: 3.973433 , (1.763 sec/step)
# Train Epoch: 0 [428/100000 (0%)] Loss: 3.971328 , (1.763 sec/step)
# Train Epoch: 0 [429/100000 (0%)] Loss: 3.966292 , (1.763 sec/step)
# Train Epoch: 0 [430/100000 (0%)] Loss: 3.960921 , (1.765 sec/step)
# Train Epoch: 0 [431/100000 (0%)] Loss: 3.959512 , (1.763 sec/step)
# Train Epoch: 0 [432/100000 (0%)] Loss: 3.961316 , (1.763 sec/step)
# Train Epoch: 0 [433/100000 (0%)] Loss: 3.962073 , (1.763 sec/step)
# Train Epoch: 0 [434/100000 (0%)] Loss: 3.959789 , (1.763 sec/step)
# Train Epoch: 0 [435/100000 (0%)] Loss: 3.955796 , (1.764 sec/step)
# Train Epoch: 0 [436/100000 (0%)] Loss: 3.953883 , (1.763 sec/step)
# Train Epoch: 0 [437/100000 (0%)] Loss: 3.954363 , (1.763 sec/step)
# Train Epoch: 0 [438/100000 (0%)] Loss: 3.954521 , (1.765 sec/step)
# Train Epoch: 0 [439/100000 (0%)] Loss: 3.952738 , (1.763 sec/step)
# Train Epoch: 0 [440/100000 (0%)] Loss: 3.949990 , (1.762 sec/step)
# Train Epoch: 0 [441/100000 (0%)] Loss: 3.948505 , (1.762 sec/step)
# Train Epoch: 0 [442/100000 (0%)] Loss: 3.948378 , (1.760 sec/step)
# Train Epoch: 0 [443/100000 (0%)] Loss: 3.947904 , (1.762 sec/step)
# Train Epoch: 0 [444/100000 (0%)] Loss: 3.946265 , (1.763 sec/step)
# Train Epoch: 0 [445/100000 (0%)] Loss: 3.944231 , (1.764 sec/step)
# Train Epoch: 0 [446/100000 (0%)] Loss: 3.942997 , (1.763 sec/step)
# Train Epoch: 0 [447/100000 (0%)] Loss: 3.942493 , (1.761 sec/step)
# Train Epoch: 0 [448/100000 (0%)] Loss: 3.941726 , (1.764 sec/step)
# Train Epoch: 0 [449/100000 (0%)] Loss: 3.940293 , (1.763 sec/step)
# Train Epoch: 0 [450/100000 (0%)] Loss: 3.938634 , (1.765 sec/step)
# Train Epoch: 0 [451/100000 (0%)] Loss: 3.937422 , (1.764 sec/step)
# Train Epoch: 0 [452/100000 (0%)] Loss: 3.936629 , (1.762 sec/step)
# Train Epoch: 0 [453/100000 (0%)] Loss: 3.935778 , (1.764 sec/step)
# Train Epoch: 0 [454/100000 (0%)] Loss: 3.934595 , (1.764 sec/step)
# Train Epoch: 0 [455/100000 (0%)] Loss: 3.933279 , (1.763 sec/step)
# Train Epoch: 0 [456/100000 (0%)] Loss: 3.932176 , (1.763 sec/step)
# Train Epoch: 0 [457/100000 (0%)] Loss: 3.931456 , (1.763 sec/step)
# Train Epoch: 0 [458/100000 (0%)] Loss: 3.930900 , (1.764 sec/step)
# Train Epoch: 0 [459/100000 (0%)] Loss: 3.930458 , (1.764 sec/step)
# Train Epoch: 0 [460/100000 (0%)] Loss: 3.929890 , (1.763 sec/step)
# Train Epoch: 0 [461/100000 (0%)] Loss: 3.929324 , (1.764 sec/step)
# Train Epoch: 0 [462/100000 (0%)] Loss: 3.928034 , (1.762 sec/step)
# Train Epoch: 0 [463/100000 (0%)] Loss: 3.926582 , (1.766 sec/step)
# Train Epoch: 0 [464/100000 (0%)] Loss: 3.924687 , (1.766 sec/step)
# Train Epoch: 0 [465/100000 (0%)] Loss: 3.923047 , (1.764 sec/step)
# Train Epoch: 0 [466/100000 (0%)] Loss: 3.921604 , (1.764 sec/step)
# Train Epoch: 0 [467/100000 (0%)] Loss: 3.920560 , (1.764 sec/step)
# Train Epoch: 0 [468/100000 (0%)] Loss: 3.919802 , (1.764 sec/step)
# Train Epoch: 0 [469/100000 (0%)] Loss: 3.919113 , (1.765 sec/step)
# Train Epoch: 0 [470/100000 (0%)] Loss: 3.918438 , (1.765 sec/step)
# Train Epoch: 0 [471/100000 (0%)] Loss: 3.917663 , (1.763 sec/step)
# Train Epoch: 0 [472/100000 (0%)] Loss: 3.917307 , (1.765 sec/step)
# Train Epoch: 0 [473/100000 (0%)] Loss: 3.917555 , (1.762 sec/step)
# Train Epoch: 0 [474/100000 (0%)] Loss: 3.918576 , (1.766 sec/step)
# Train Epoch: 0 [475/100000 (0%)] Loss: 3.920105 , (1.764 sec/step)
# Train Epoch: 0 [476/100000 (0%)] Loss: 3.920041 , (1.765 sec/step)
# Train Epoch: 0 [477/100000 (0%)] Loss: 3.917439 , (1.764 sec/step)
# Train Epoch: 0 [478/100000 (0%)] Loss: 3.912730 , (1.765 sec/step)
# Train Epoch: 0 [479/100000 (0%)] Loss: 3.908717 , (1.764 sec/step)
# Train Epoch: 0 [480/100000 (0%)] Loss: 3.907541 , (1.766 sec/step)
# Train Epoch: 0 [481/100000 (0%)] Loss: 3.908340 , (1.765 sec/step)
# Train Epoch: 0 [482/100000 (0%)] Loss: 3.908804 , (1.766 sec/step)
# Train Epoch: 0 [483/100000 (0%)] Loss: 3.907346 , (1.765 sec/step)
# Train Epoch: 0 [484/100000 (0%)] Loss: 3.904573 , (1.767 sec/step)
# Train Epoch: 0 [485/100000 (0%)] Loss: 3.902450 , (1.765 sec/step)
# Train Epoch: 0 [486/100000 (0%)] Loss: 3.901671 , (1.768 sec/step)
# Train Epoch: 0 [487/100000 (0%)] Loss: 3.901458 , (1.766 sec/step)
# Train Epoch: 0 [488/100000 (0%)] Loss: 3.900774 , (1.763 sec/step)
# Train Epoch: 0 [489/100000 (0%)] Loss: 3.899306 , (1.767 sec/step)
# Train Epoch: 0 [490/100000 (0%)] Loss: 3.897680 , (1.765 sec/step)
# Train Epoch: 0 [491/100000 (0%)] Loss: 3.896512 , (1.766 sec/step)

# %%
#model = torch.load('torchmodel')
